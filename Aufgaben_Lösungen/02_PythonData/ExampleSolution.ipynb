# %% [markdown]
# ## 1. Prepare the data
#
# 1. download the openbeer database from https://openbeerdb.com/, "openbeerdb_csv.zip". (You may assemble the link before. But the idea is that after publishing a notebook/code it works as a standalone solution and no further interactions are needed from the user)
# 1. unzip the csv in Python

# %%
import requests
import zipfile

# standalone download/upload in jupyter notebook of csv-files
print('Start downloading beer data file...')
url = 'https://openbeerdb.com/files/openbeerdb_csv.zip'
pathZip = 'openbeerdb_csv.zip'

file = requests.get(url)

open(pathZip, 'wb').write(file.content)

print('Download successful...')

# extract the zip in your directory
extract_path = './'
with zipfile.ZipFile(pathZip, 'r') as zipRef:
    zipRef.extractall(extract_path)
print('ZipFile extracted successfull...')
# Out:
# Start downloading beer data file...
# Download successful...
# ZipFile extracted successfull...

# %% [markdown]
# ## 2. Read the data into a class that allows data processing
#
# 1. Which package is well suited and why?
# 1. Read the data into this package
# 1. Create a "Qualitative Summary" of the data.
# 1. Access the column "brewery_id" from beers dataframe
# 1. Access first row of beers and its corresponding brewery row
# 1. Join beers data with brewery data and print result of first beer row from 5.

# %%
# Import pandas, which is a great package to process data
import pandas as pd
from IPython.display import display

# IMPORTANT: Run SolutionExample_1 first

basePath = 'openbeerdb_csv/'

# %%
### 2. Read data

# %%
# beers.csv
print('beers.csv')
beers = pd.read_csv(basePath + "beers.csv", header=0, usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8])
beers.head()
# Out:
# beers.csv
# C:\Users\weinz\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,1,3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   id brewery_id                    name cat_id style_id  abv ibu srm upc
# 0  1        812             Hocus Pocus     11      116  4.5   0   0   0
# 1  2        264       Grimbergen Blonde     -1       -1  6.7   0   0   0
# 2  3        779  Widdershins Barleywine     -1       -1  9.1   0   0   0
# 3  4        287                 Lucifer     -1       -1  8.5   0   0   0
# 4  5       1056                  Bitter     -1       -1    4   0   0   0

# %% [markdown]
# Exkurs Types in Pandas Dataframes:

# %%
beers.dtypes
# Out:
# id            object
# brewery_id    object
# name          object
# cat_id        object
# style_id      object
# abv           object
# ibu           object
# srm           object
# upc           object
# dtype: object

# %%
#simple solution in clean datasets:
beers['id'] = beers['id'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d45369c28aa3> in <module>
#       1 #simple solution in clean datasets:
# ----> 2 beers['id'] = beers['id'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
#in case you have to deal with only missing values (na) try this nice fuction of different prep-steps:
beers['id'] = (
    beers['id'].fillna(0)
    .astype(int)
    .astype(object)
    .where(beers['id'].notnull())
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-611b50374cac> in <module>
#       2 beers['id'] = (
#       3     beers['id'].fillna(0)
# ----> 4     .astype(int)
#       5     .astype(object)
#       6     .where(beers['id'].notnull())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'The Finches are long gone'

# %%
# in case you are dealing with a "dirty dataset", ignore errors, be specific in int-type (32/64 or float)
beers['id'] = pd.to_numeric(beers['id'],errors='coerce').astype(pd.Int64Dtype())

# %%
beers.dtypes
# Out:
# id             Int64
# brewery_id    object
# name          object
# cat_id        object
# style_id      object
# abv           object
# ibu           object
# srm           object
# upc           object
# dtype: object

# %%
# breweries.csv
print('breweries.csv')
breweries = pd.read_csv(basePath + "breweries.csv", header=0)
breweries.head()
# Out:
# breweries.csv
#    id                                               name  \
# 0   1                              (512) Brewing Company
# 1   2                        21st Amendment Brewery Cafe
# 2   3  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij
# 3   4                                       Aass Brewery
# 4   5                                    Abbaye de Leffe
#
#                          address1 address2           city           state  \
# 0                 407 Radam, F200      NaN         Austin           Texas
# 1               563 Second Street      NaN  San Francisco      California
# 2                   Hoogstraat 2A      NaN        Beersel  Vlaams Brabant
# 3  Ole Steensgt. 10 Postboks 1530      NaN        Drammen             NaN
# 4                          Dinant      NaN         Dinant           Namur
#
#     code        country              phone  \
# 0  78745  United States       512.707.2337
# 1  94107  United States     1-415-369-0900
# 2    NaN        Belgium  32-02-/-306-71-03
# 3    NaN         Norway     47-32-26-60-00
# 4    NaN        Belgium                NaN
#
#                               website filepath  \
# 0              http://512brewing.com/      NaN
# 1      http://www.21st-amendment.com/      NaN
# 2  http://www.3fonteinen.be/index.htm      NaN
# 3                  http://www.aass.no      NaN
# 4                                 NaN      NaN
#
#                                             descript             last_mod
# 0  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20
# 1  The 21st Amendment Brewery offers a variety of...  2010-10-24 13:54:07
# 2                                                NaN  2010-07-22 20:00:20
# 3  Aass Brewery was established in 1834 and is th...  2010-07-22 20:00:20
# 4                                                NaN  2010-07-22 20:00:20

# %%
# breweries_geocode.csv
print('breweries_geocode.csv')
breweries_geocode = pd.read_csv(basePath + "breweries_geocode.csv", header=0)
breweries_geocode.head()
# Out:
# breweries_geocode.csv
#    id  brewery_id  latitude  longitude            accuracy
# 0   1           1   30.2234   -97.7697             ROOFTOP
# 1   2           2   37.7825  -122.3930             ROOFTOP
# 2   3           3   50.7668     4.3081  RANGE_INTERPOLATED
# 3   4           4   59.7451    10.2135         APPROXIMATE
# 4   5           5   50.2606     4.9122         APPROXIMATE

# %%
# categories.csv
print('categories.csv')
categories = pd.read_csv(basePath + "categories.csv", header=0)
categories.head()
# Out:
# categories.csv
#    id                cat_name             last_mod
# 0   1             British Ale  2010-10-24 13:50:10
# 1   2               Irish Ale  2010-06-08 00:00:00
# 2   3      North American Ale  2010-06-08 00:00:00
# 3   4              German Ale  2010-06-08 00:00:00
# 4   5  Belgian and French Ale  2010-06-08 00:00:00

# %%
# styles.csv
print('styles.csv')
styles = pd.read_csv(basePath + "styles.csv", header=0)
styles.head()
# Out:
# styles.csv
#    id  cat_id                      style_name             last_mod
# 0   1       1  Classic English-Style Pale Ale  2010-10-24 13:53:31
# 1   2       1    English-Style India Pale Ale  2010-06-15 19:14:38
# 2   3       1                 Ordinary Bitter  2010-06-15 19:14:54
# 3   4       1   Special Bitter or Best Bitter  2010-06-15 19:15:02
# 4   5       1            Extra Special Bitter  2010-06-15 19:15:09

# %% [markdown]
# ### 3. "Qualitative Summary"

# %%
print('beers.csv')
beers.describe()
# Out:
# beers.csv
#           id brewery_id      name  cat_id  style_id     abv   ibu   srm   upc
# count   5845       5837      5837    5832      5829  5825.0  5822  5822  5822
# unique  5845       1650      4982      28       129   266.0    20    15     5
# top     4831       1072  Pale Ale       3        -1     0.0     0     0     0
# freq       1         47        48    1248      1046  2648.0  4803  4809  4816

# %%
print('breweries.csv')
breweries.describe()
# Out:
# breweries.csv
#                 id
# count  1414.000000
# mean    713.725601
# std     410.477463
# min       1.000000
# 25%     359.250000
# 50%     715.500000
# 75%    1068.750000
# max    1423.000000

# %%
print('breweries_geocode.csv')
breweries_geocode.describe()
# Out:
# breweries_geocode.csv
#                 id   brewery_id     latitude    longitude
# count  1304.000000  1304.000000  1304.000000  1304.000000
# mean    657.648006   699.611196    41.473073   -63.765908
# std     379.382053   400.565205    12.959051    58.324611
# min       1.000000     1.000000   -45.872000  -157.858000
# 25%     328.750000   353.500000    38.973475  -105.139500
# 50%     658.500000   703.500000    42.504450   -83.819250
# 75%     985.250000  1046.250000    48.149975    -1.260825
# max    1315.000000  1394.000000    64.958300   176.854000

# %%
print('categories.csv')
categories.describe()
# Out:
# categories.csv
#               id
# count  11.000000
# mean    6.000000
# std     3.316625
# min     1.000000
# 25%     3.500000
# 50%     6.000000
# 75%     8.500000
# max    11.000000

# %%
print('styles.csv')
styles.describe()
# Out:
# styles.csv
#                id      cat_id
# count  141.000000  141.000000
# mean    71.000000    5.900709
# std     40.847277    3.505720
# min      1.000000    1.000000
# 25%     36.000000    3.000000
# 50%     71.000000    5.000000
# 75%    106.000000    9.000000
# max    141.000000   11.000000

# %% [markdown]
# ### 4. Access the column "brewery_id" from beers dataframe

# %%
beers['brewery_id']
# Out:
# 0        812
# 1        264
# 2        779
# 3        287
# 4       1056
#         ...
# 5856      10
# 5857      10
# 5858      10
# 5859    1422
# 5860    1423
# Name: brewery_id, Length: 5861, dtype: object

# %% [markdown]
# ### 5. Access first row of beers and its corresponding brewery row

# %%
beers.loc[0, :]
# Out:
# id                      1
# brewery_id            812
# name          Hocus Pocus
# cat_id                 11
# style_id              116
# abv                   4.5
# ibu                     0
# srm                     0
# upc                     0
# Name: 0, dtype: object

# %%
# access brewery row with id = 812 (id not index ;-))
breweries.set_index('id').loc[812, :]
# Out:
# name                                                Magic Hat
# address1                                  5 Bartlett Bay Road
# address2                                                  NaN
# city                                         South Burlington
# state                                                 Vermont
# code                                                     5403
# country                                         United States
# phone                                          1-802-658-2739
# website                              http://www.magichat.net/
# filepath                                                  NaN
# descript    Burlington microbrewers of Humble Patience, Fa...
# last_mod                                  2010-07-22 20:00:20
# Name: 812, dtype: object

# %% [markdown]
# ### 6. Join beers data with brewery data and print result of first beer row from 5.

# %%
joined = beers.set_index('brewery_id').join(breweries.set_index('id'), lsuffix='_beer', rsuffix='_brewery') # column name is in both data sets
joined = joined.iloc[1:] # drops the first row, because we also matched the header
joined.head()
# Out:
#      id           name_beer cat_id style_id  abv ibu srm upc  \
# 1  5735           (512) Wit      5       67  5.2   0   0   0
# 1  5736          (512) Pale      3       26  5.8   0   0   0
# 1  5737           (512) IPA      3       31    7   0   0   0
# 1  5738  (512) Pecan Porter      2       25  6.8   0   0   0
# 1  5739           (512) ALT      4       57    6   0   0   0
#
#             name_brewery         address1 address2    city  state   code  \
# 1  (512) Brewing Company  407 Radam, F200      NaN  Austin  Texas  78745
# 1  (512) Brewing Company  407 Radam, F200      NaN  Austin  Texas  78745
# 1  (512) Brewing Company  407 Radam, F200      NaN  Austin  Texas  78745
# 1  (512) Brewing Company  407 Radam, F200      NaN  Austin  Texas  78745
# 1  (512) Brewing Company  407 Radam, F200      NaN  Austin  Texas  78745
#
#          country         phone                 website filepath  \
# 1  United States  512.707.2337  http://512brewing.com/      NaN
# 1  United States  512.707.2337  http://512brewing.com/      NaN
# 1  United States  512.707.2337  http://512brewing.com/      NaN
# 1  United States  512.707.2337  http://512brewing.com/      NaN
# 1  United States  512.707.2337  http://512brewing.com/      NaN
#
#                                             descript             last_mod
# 1  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20
# 1  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20
# 1  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20
# 1  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20
# 1  (512) Brewing Company is a microbrewery locate...  2010-07-22 20:00:20

# %%
# print our famous beer
#joined['id'] = joined['id'].fillna('')
joined[joined['id'] == 1]
# Out:
#     id    name_beer cat_id style_id  abv ibu srm upc name_brewery  \
# 812  1  Hocus Pocus     11      116  4.5   0   0   0    Magic Hat
#
#                 address1 address2              city    state  code  \
# 812  5 Bartlett Bay Road      NaN  South Burlington  Vermont  5403
#
#            country           phone                   website filepath  \
# 812  United States  1-802-658-2739  http://www.magichat.net/      NaN
#
#                                               descript             last_mod
# 812  Burlington microbrewers of Humble Patience, Fa...  2010-07-22 20:00:20

# %% [markdown]
# ## 3. Reading the data into a local database
#
# 1. Which database is well suited and why?
# 1. Read the data into this database

# %% [markdown]
# ### 1. Which database is well suited
#
# With python you can easily use sqlite as a database. It is easy to use and you can then query the database with SQL-commands to answer e.g. certain questions on the data. <br/>
# https://docs.python.org/3/library/sqlite3.html

# %% [markdown]
# ### 2. Read the data into this database

# %%
import sqlite3

beers_data = pd.DataFrame(beers, columns=["id","brewery_id","name","cat_id","style_id","abv"])
breweries_data = pd.DataFrame(breweries, columns=["id","name","city","country"])
categories_data = pd.DataFrame(categories, columns=["id","cat_name"])
styles_data = pd.DataFrame(styles, columns=["id","cat_id","style_name"])

conn = sqlite3.connect('beer.db')

# Create table
conn.execute('DROP TABLE IF EXISTS beers')
conn.execute('''CREATE TABLE beers
             (id INTEGER, brewery_id INTEGER,name TEXT,cat_id INTEGER,style_id INTEGER,abv REAL)''')

conn.execute('DROP TABLE IF EXISTS breweries')
conn.execute('''CREATE TABLE breweries
             (id INTEGER, name TEXT, city TEXT, country TEXT)''')

conn.execute('DROP TABLE IF EXISTS categories')
conn.execute('''CREATE TABLE categories
             (id INTEGER, cat_name TEXT)''')

conn.execute('DROP TABLE IF EXISTS styles')
conn.execute('''CREATE TABLE styles
             (id INTEGER, cat_id INTEGER, style_name TEXT)''')

# Insert a beer data
beers_data.to_sql('beers', conn, if_exists='replace', index = False)
breweries_data.to_sql('breweries', conn, if_exists='replace', index = False)
categories_data.to_sql('categories', conn, if_exists='replace', index = False)
styles_data.to_sql('styles', conn, if_exists='replace', index = False)


# Save (commit) the changes
conn.commit()

# read data
c = conn.cursor()
c.execute('''SELECT * FROM beers b 
                LEFT JOIN breweries bw ON b.brewery_id = bw.id 
                LEFT JOIN categories c ON b.cat_id = c.id 
                LEFT JOIN styles s ON b.style_id = s.id 
                ''')

for row in c.fetchall():
    print (row)

# We can also close the connection if we are done with it.
# Just be sure any changes have been committed or they will be lost.
conn.close()
# Out:
# ('1', '812', 'Hocus Pocus', '11', '116', '4.5', 812, 'Magic Hat', 'South Burlington', 'United States', 11, 'Other Style', 116, 11, 'Light American Wheat Ale or Lager')
# ('2', '264', 'Grimbergen Blonde', '-1', '-1', '6.7', 264, 'Brouwerij Alken-Maes', 'Jumet', 'Belgium', None, None, None, None, None)
# ('3', '779', 'Widdershins Barleywine', '-1', '-1', '9.1', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', None, None, None, None, None)
# ('4', '287', 'Lucifer', '-1', '-1', '8.5', 287, 'Brouwerij Liefmans', 'Oudenaarde', 'Belgium', None, None, None, None, None)
# ('5', '1056', 'Bitter', '-1', '-1', '4.0', 1056, 'Ridgeway Brewing', 'South Stoke', 'United Kingdom', None, None, None, None, None)
# ('6', '1385', 'Winter Warmer', '1', '13', '5.2', 1385, 'Youngs & Company Brewery', 'London', 'England', 1, 'British Ale', 13, 1, 'Old Ale')
# ('7', '1099', 'Winter Welcome 2007-2008', '-1', '-1', '6.0', 1099, 'Samuel Smith Old Brewery (Tadcaster)', 'Tadcaster', 'United Kingdom', None, None, None, None, None)
# ('8', '1099', 'Oatmeal Stout', '3', '42', '5.0', 1099, 'Samuel Smith Old Brewery (Tadcaster)', 'Tadcaster', 'United Kingdom', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('9', '501', 'Espresso Porter', '-1', '-1', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', None, None, None, None, None)
# ('10', '545', 'Chocolate Stout', '3', '42', '0.0', 545, 'Fort Collins Brewery', 'Fort Collins', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('11', '742', 'Hitachino Nest Real Ginger Brew', '-1', '-1', '7.0', 742, 'Kiuchi Shuzou Goushi Kaisya', 'Ibaraki', 'Japan', None, None, None, None, None)
# ('12', '779', 'JuJu Ginger', '-1', '-1', '4.0', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', None, None, None, None, None)
# ('13', '545', 'The Kidd Lager', '7', '86', '0.0', 545, 'Fort Collins Brewery', 'Fort Collins', 'United States', 7, 'German Lager', 86, 7, 'German-Style Schwarzbier')
# ('14', '1099', 'Imperial Stout', '3', '42', '7.0', 1099, 'Samuel Smith Old Brewery (Tadcaster)', 'Tadcaster', 'United Kingdom', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('15', '1315', 'Oak-Aged Belgian Tripel', '-1', '-1', '9.0', 1315, 'Upstream Brewing Company at Legacy', 'Omaha', 'United States', None, None, None, None, None)
# ('16', '168', 'Ultrablonde', '-1', '-1', '8.0', 168, "Brasserie d'Ecaussinnes", 'Ecaussinnes', 'Belgium', None, None, None, None, None)
# ('17', '1023', 'Wiesen Edel Weisse', '4', '50', '6.2', 1023, 'Private Weissbierbrauerei G. Schneider & Sohn GmbH', 'Kelheim', 'Germany', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('18', '39', 'Old Foghorn 2001', '-1', '-1', '10.0', 39, 'Anchor Brewing', 'San Francisco', 'United States', None, None, None, None, None)
# ('19', '196', 'Framboise', '-1', '-1', '6.0', 196, 'Brasserie La Choulette', 'Hordain', 'France', None, None, None, None, None)
# ('20', '483', 'Cow Palace Scotch Ale 1998', '1', '15', '8.7', 483, 'Egan Brewing', 'De Pere', 'United States', 1, 'British Ale', 15, 1, 'Scotch Ale')
# ('21', '1142', 'Bigfoot 2001', '-1', '-1', '9.6', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', None, None, None, None, None)
# ('22', '1142', 'Bigfoot 2002', '-1', '-1', '9.6', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', None, None, None, None, None)
# ('23', '1142', 'Bigfoot 2003', '-1', '-1', '9.6', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', None, None, None, None, None)
# ('24', '1142', 'Bigfoot 2004', '-1', '-1', '9.6', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', None, None, None, None, None)
# ('25', '1142', 'Bigfoot 2005', '-1', '-1', '9.6', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', None, None, None, None, None)
# ('26', '1220', 'Winter Ale', '1', '13', '5.9', 1220, 'Summit Brewing', 'Saint Paul', 'United States', 1, 'British Ale', 13, 1, 'Old Ale')
# ('27', '878', 'Full Moon Winter Ale', '5', '72', '5.6', 878, 'Molson Breweries of Canada', 'Toronto', 'Canada', 5, 'Belgian and French Ale', 72, 5, 'Other Belgian-Style Ales')
# ('28', '935', 'Odell IPA', '3', '31', '7.0', 935, 'Odell Brewing', 'Fort Collins', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('29', '1271', 'Ornery Amber Lager', '8', '95', '0.0', 1271, 'Tommyknocker Brewery and Pub', 'Idaho Springs', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('30', '935', 'Cutthroat Porter', '2', '25', '4.8', 935, 'Odell Brewing', 'Fort Collins', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('31', '1271', 'Maple Nut Brown Ale Ale', '3', '38', '0.0', 1271, 'Tommyknocker Brewery and Pub', 'Idaho Springs', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('32', '1271', 'Cocoa Porter', '-1', '-1', '0.0', 1271, 'Tommyknocker Brewery and Pub', 'Idaho Springs', 'United States', None, None, None, None, None)
# ('33', '190', 'Jenlain Blonde', '-1', '-1', '7.5', 190, 'Brasserie Duyck', 'Jenlain', 'France', None, None, None, None, None)
# ('34', '196', 'Blonde', '-1', '-1', '7.5', 196, 'Brasserie La Choulette', 'Hordain', 'France', None, None, None, None, None)
# ('35', '432', 'Flemish Primitive Wild Ale (Demon Fish)', '-1', '-1', '9.0', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('36', '294', 'Witkap-Pater Tripel', '-1', '-1', '7.5', 294, 'Brouwerij Slaghmuylder', 'Ninove', 'Belgium', None, None, None, None, None)
# ('37', '1175', 'Winter Cheer', '3', '38', '0.0', 1175, 'Spanish Peaks Brewing', 'Polson', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('38', '743', 'Canaster Winter Scotch', '-1', '-1', '8.7', 743, 'Kleinbrouwerij de Glazen Toren', 'Erpe-Mere', 'Belgium', None, None, None, None, None)
# ('39', '1307', '16', '-1', '-1', '10.0', 1307, 'Unibroue', 'Chambly', 'Canada', None, None, None, None, None)
# ('40', '1307', 'Quelque Chose', '5', '70', '8.0', 1307, 'Unibroue', 'Chambly', 'Canada', 5, 'Belgian and French Ale', 70, 5, 'Belgian-Style Fruit Lambic')
# ('41', '277', 'Kriek', '-1', '-1', '7.0', 277, 'Brouwerij De Ranke', 'Wevelgem', 'Belgium', None, None, None, None, None)
# ('42', '170', 'BiÃ¨re Darbyste', '11', '116', '0.0', 170, 'Brasserie de Blaugies', 'Blaugies', 'Belgium', 11, 'Other Style', 116, 11, 'Light American Wheat Ale or Lager')
# ('43', '723', 'Maracaibo Especial', '3', '38', '7.5', 723, 'Jolly Pumpkin Artisan Ales', 'Dexter', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('44', '432', 'Flemish Primitive Wild Ale (Pin Head)', '-1', '-1', '9.0', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('45', '723', 'Calabaza Blanca', '5', '72', '4.8', 723, 'Jolly Pumpkin Artisan Ales', 'Dexter', 'United States', 5, 'Belgian and French Ale', 72, 5, 'Other Belgian-Style Ales')
# ('46', '901', 'Porter', '2', '25', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('47', '901', 'Cardinal Pale Ale', '3', '26', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('48', '176', 'Zinnebir Xmas', '-1', '-1', '6.6', 176, 'Brasserie de la Senne', 'Sint-Pieters-Leeuw', 'Belgium', None, None, None, None, None)
# ('49', '974', 'Bridal Ale 2005', '-1', '-1', '0.0', 974, 'Pelican Pub & Brewery', 'Pacific City', 'United States', None, None, None, None, None)
# ('50', '176', 'Zinnebir', '3', '26', '0.0', 176, 'Brasserie de la Senne', 'Sint-Pieters-Leeuw', 'Belgium', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('51', '432', 'Saison Imperiale', '-1', '-1', '8.5', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('52', '170', 'La Moneuse', '-1', '-1', '8.0', 170, 'Brasserie de Blaugies', 'Blaugies', 'Belgium', None, None, None, None, None)
# ('53', '901', 'Red Sled Winter Ale', '-1', '-1', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', None, None, None, None, None)
# ('54', '39', 'Christmas Ale 2007', '-1', '-1', '0.0', 39, 'Anchor Brewing', 'San Francisco', 'United States', None, None, None, None, None)
# ('55', '176', 'Equinox Dark Belgian Winter', '-1', '-1', '8.0', 176, 'Brasserie de la Senne', 'Sint-Pieters-Leeuw', 'Belgium', None, None, None, None, None)
# ('56', '856', 'Serafijn Christmas Angel', '-1', '-1', '8.0', 856, 'Microbrouwerij Achilles', 'Itegem', 'Belgium', None, None, None, None, None)
# ('57', '160', 'Obovoid Empirical Stout', '3', '43', '8.0', 160, 'Boulder Beer Company', 'Boulder', 'United States', 3, 'North American Ale', 43, 3, 'American-Style Imperial Stout')
# ('58', '1221', 'Furious Beer', '3', '31', '6.0', 1221, 'Surly Brewing', 'Brooklyn Center', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('59', '1221', 'Bender Beer', '3', '38', '5.1', 1221, 'Surly Brewing', 'Brooklyn Center', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('60', '1315', 'Oak Aged Ebenezer', '-1', '-1', '9.4', 1315, 'Upstream Brewing Company at Legacy', 'Omaha', 'United States', None, None, None, None, None)
# ('61', '160', 'Killer Penguin', '3', '35', '10.0', 160, 'Boulder Beer Company', 'Boulder', 'United States', 3, 'North American Ale', 35, 3, 'American-Style Barley Wine Ale')
# ('62', '236', 'Oatmeal Stout', '3', '42', '0.0', 236, 'Breckenridge Brewery', 'Denver', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('63', '935', 'Isolation Ale', '11', '141', '6.0', 935, 'Odell Brewing', 'Fort Collins', 'United States', 11, 'Other Style', 141, 11, 'Winter Warmer')
# ('64', '501', 'Festive Ale 2007', '-1', '-1', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', None, None, None, None, None)
# ('65', '586', 'Bourbon County Stout 2007', '-1', '-1', '13.0', 586, 'Goose Island Beer Company - Fulton Street', 'Chicago', 'United States', None, None, None, None, None)
# ('66', '670', 'Twelve Days', '3', '42', '5.5', 670, 'Hook Norton Brewery', 'Hook Norton', 'United Kingdom', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('67', '1056', 'Seriously Bad Elf', '-1', '-1', '9.0', 1056, 'Ridgeway Brewing', 'South Stoke', 'United Kingdom', None, None, None, None, None)
# ('68', '905', 'Big Shot Seasonal Ale', '2', '25', '0.0', 905, 'New Belgium Brewing', 'Fort Collins', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('69', '923', 'God Jul - Winter Ale', '3', '42', '8.5', 923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 'Grimstad', 'Norway', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('70', '1142', 'Harvest Ale 2007', '3', '26', '6.7', 1142, 'Sierra Nevada Brewing Co.', 'Chico', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('71', '161', 'Nut Cracker Ale', '11', '141', '5.9', 161, 'Boulevard Brewing Company', 'Kansas City', 'United States', 11, 'Other Style', 141, 11, 'Winter Warmer')
# ('72', '779', 'Goosinator Smoked Doppelbock 2007', '8', '95', '0.0', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('73', '779', 'Snow Bound Winter Ale', '-1', '-1', '8.6', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', None, None, None, None, None)
# ('74', '779', 'Warrior IPA', '3', '31', '6.6', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('75', '266', 'Petrus Oud Bruin', '-1', '-1', '5.5', 266, 'Brouwerij Bavik - De Brabandere', 'Bavikhove', 'Belgium', None, None, None, None, None)
# ('76', '266', 'Petrus Gouden Tripel Ale', '-1', '-1', '7.5', 266, 'Brouwerij Bavik - De Brabandere', 'Bavikhove', 'Belgium', None, None, None, None, None)
# ('77', '266', 'Petrus Blond Ale', '-1', '-1', '6.6', 266, 'Brouwerij Bavik - De Brabandere', 'Bavikhove', 'Belgium', None, None, None, None, None)
# ('78', '266', 'Petrus Dubbel Bruin Ale', '5', '60', '6.5', 266, 'Brouwerij Bavik - De Brabandere', 'Bavikhove', 'Belgium', 5, 'Belgian and French Ale', 60, 5, 'Belgian-Style Dubbel')
# ('79', '266', 'Petrus Speciale', '3', '26', '5.5', 266, 'Brouwerij Bavik - De Brabandere', 'Bavikhove', 'Belgium', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('80', '1202', 'Weizengold Hefefein', '4', '50', '5.1', 1202, 'Stieglbrauerei zu Salzburg GmbH', 'Salzburg', 'Austria', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('81', '160', 'Never Summer Ale', '11', '141', '5.94', 160, 'Boulder Beer Company', 'Boulder', 'United States', 11, 'Other Style', 141, 11, 'Winter Warmer')
# ('82', '1264', 'Modern Monks Belgian Blonde', '3', '26', '0.0', 1264, 'Thunderhead Brewery #2', 'Grand Island', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('83', '1264', 'Grand Cru', '-1', '-1', '0.0', 1264, 'Thunderhead Brewery #2', 'Grand Island', 'United States', None, None, None, None, None)
# ('84', '210', 'JÃ¶rger WeiÃŸe Hell', '4', '50', '0.0', 210, 'Brauerei Grieskirchen AG', 'Grieskirchen', 'Austria', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('85', '1272', 'OSB Premium Ale', '-1', '-1', '4.5', 1272, 'Tomos Watkin and Sons Ltd.', 'Swansea', 'United Kingdom', None, None, None, None, None)
# ('86', '425', 'Morocco Ale', '-1', '-1', '5.5', 425, 'Daleside Brewery', 'Harrogate', 'United Kingdom', None, None, None, None, None)
# ('87', '1047', 'Glacier Ale', '3', '33', '0.0', 1047, 'Red Lodge Ales', 'Red Lodge', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('88', '1047', 'Bent Nail IPA', '3', '31', '0.0', 1047, 'Red Lodge Ales', 'Red Lodge', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('89', '879', 'Espresso Porter', '-1', '-1', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', None, None, None, None, None)
# ('90', '879', 'Harvest Ale', '3', '26', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('91', '879', 'Stillwater Rye', '-1', '-1', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', None, None, None, None, None)
# ('92', '879', 'Sharptail Pale Ale', '3', '26', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('93', '879', 'Fat Belly Amber', '3', '33', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('94', '879', 'Whitetail Wheat', '8', '95', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('95', '879', 'Sandbagger Gold', '-1', '-1', '0.0', 879, 'Montana Brewing', 'Billings', 'United States', None, None, None, None, None)
# ('96', '901', 'Brunette Nut Brown Ale', '3', '38', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('97', '901', 'Irish Red', '-1', '-1', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', None, None, None, None, None)
# ('98', '901', 'Belgian Wit', '-1', '-1', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', None, None, None, None, None)
# ('99', '901', 'EOS Hefeweizen', '4', '50', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('100', '901', 'India Pale Ale', '3', '26', '0.0', 901, 'Nebraska Brewing Company', 'Papillion', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('101', '1185', 'Winter Ale', '1', '13', '6.3', 1185, "St Peter's Brewery", 'Bungay', 'United Kingdom', 1, 'British Ale', 13, 1, 'Old Ale')
# ('102', '1260', 'Pride & Joy Mild Ale', '1', '10', '0.0', 1260, 'Three Floyds Brewing', 'Munster', 'United States', 1, 'British Ale', 10, 1, 'English-Style Pale Mild Ale')
# ('103', '1260', 'Robert the Bruce Scottish Ale', '1', '15', '7.0', 1260, 'Three Floyds Brewing', 'Munster', 'United States', 1, 'British Ale', 15, 1, 'Scotch Ale')
# ('104', '1056', 'Lump of Coal Dark Holiday Stout', '3', '42', '8.0', 1056, 'Ridgeway Brewing', 'South Stoke', 'United Kingdom', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('105', '1056', 'Warm Welcome Nut Browned Ale', '3', '38', '6.0', 1056, 'Ridgeway Brewing', 'South Stoke', 'United Kingdom', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('106', '884', 'Pendle Witches Brew', '3', '26', '5.1', 884, "Moorhouse's Brewery (Burnley)", 'Burnley', 'United Kingdom', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('107', '345', 'Carnegie Stark-Porter', '2', '25', '5.5', 345, 'Carlsberg Sverige AB', 'Falkenberg', 'Sweden', 2, 'Irish Ale', 25, 2, 'Porter')
# ('108', '727', 'Harvest Ale 2002', '1', '13', '11.5', 727, 'JW Lees and Co (Brewers) Ltd.', 'Manchester', 'United Kingdom', 1, 'British Ale', 13, 1, 'Old Ale')
# ('109', '1075', 'Woody Organic IPA', '3', '31', '6.2', 1075, 'Roots Organic Brewing', 'Portland', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('110', '620', 'Adriaan', '-1', '-1', '5.0', 620, 'Haarlems Biergenootschap Jopen', 'Haarlem', 'Netherlands', None, None, None, None, None)
# ('111', '304', 'Leute Bok Bier', '7', '90', '7.5', 304, 'Brouwerij Van Steenberge', 'Ertvelde', 'Belgium', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('112', '905', 'La Folie Falling Rock', '-1', '-1', '6.0', 905, 'New Belgium Brewing', 'Fort Collins', 'United States', None, None, None, None, None)
# ('113', '1315', 'Oak Aged IPA', '-1', '-1', '6.0', 1315, 'Upstream Brewing Company at Legacy', 'Omaha', 'United States', None, None, None, None, None)
# ('114', '304', 'Tikka Gold', '3', '26', '5.0', 304, 'Brouwerij Van Steenberge', 'Ertvelde', 'Belgium', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('115', '179', 'La Divine Double Blond', '-1', '-1', '7.5', 179, 'Brasserie de Silly', 'Silly', 'Belgium', None, None, None, None, None)
# ('116', '179', 'La Divine Tripel Amber', '-1', '-1', '9.0', 179, 'Brasserie de Silly', 'Silly', 'Belgium', None, None, None, None, None)
# ('117', '292', 'Ename Tripel', '-1', '-1', '8.5', 292, 'Brouwerij Roman', 'Oudenaarde', 'Belgium', None, None, None, None, None)
# ('118', '827', 'Triple Dipsea Belgian', '-1', '-1', '9.2', 827, 'Marin Brewing', 'Larkspur Landing', 'United States', None, None, None, None, None)
# ('119', '1019', 'Oktoberfest Weizen', '-1', '-1', '5.7', 1019, 'Privatbrauerei Erdinger Weissbru', 'Erding', 'Germany', None, None, None, None, None)
# ('120', '1029', 'Imperial Hefeweizen', '-1', '-1', '7.5', 1029, 'Pyramid Alehouse, Brewery and Restaurant - Berkeley', 'Berkeley', 'United States', None, None, None, None, None)
# ('121', '481', 'Triple Exultation Old Ale', '1', '13', '9.7', 481, 'Eel River Brewing', 'Fortuna', 'United States', 1, 'British Ale', 13, 1, 'Old Ale')
# ('122', '130', 'Organic Gingerbread Ale', '-1', '-1', '6.8', 130, 'Bison Brewing', 'Berkeley', 'United States', None, None, None, None, None)
# ('123', '1064', 'Falcon Pale Ale', '3', '26', '0.0', 1064, 'Rock Bottom Restaurant & Brewery - Denver', 'Denver', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('124', '441', 'Buzzsaw Brown', '3', '38', '4.8', 441, 'Deschutes Brewery', 'Bend', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('125', '369', 'Eisenbahn South American Pale Ale (S.A.P.A.)', '3', '26', '0.0', 369, 'Cervejaria Sudbrack', 'Blumenau', 'Brazil', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('126', '584', 'Geist Bock', '7', '90', '6.1', 584, 'Golden Valley Brewery and Pub', 'McMinnville', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('127', '623', 'Troll Porter', '2', '25', '0.0', 623, "Hale's Ales #3", 'Seattle', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('128', '397', 'Dark Ale', '1', '10', '4.5', 397, 'Coopers Brewery', 'Regency Park', 'Australia', 1, 'British Ale', 10, 1, 'English-Style Pale Mild Ale')
# ('129', '441', 'Cinder Cone Red', '3', '33', '5.4', 441, 'Deschutes Brewery', 'Bend', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('130', '562', 'LTD 02 Lager', '7', '90', '6.4', 562, 'Full Sail Brewing #1', 'Hood River', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('131', '189', 'Saison Vielle Provision', '-1', '-1', '6.5', 189, 'Brasserie Dupont', 'Tourpes', 'Belgium', None, None, None, None, None)
# ('132', '130', 'Organic Barley Wine Ale 2005', '-1', '-1', '9.5', 130, 'Bison Brewing', 'Berkeley', 'United States', None, None, None, None, None)
# ('133', '562', 'Old Boardhead 2006', '-1', '-1', '9.0', 562, 'Full Sail Brewing #1', 'Hood River', 'United States', None, None, None, None, None)
# ('134', '622', 'Blue Dot Double India Pale Ale', '3', '32', '7.0', 622, 'Hair of the Dog Brewing', 'Portland', 'United States', 3, 'North American Ale', 32, 3, 'Imperial or Double India Pale Ale')
# ('135', '562', 'Nugget', '3', '33', '0.0', 562, 'Full Sail Brewing #1', 'Hood River', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('136', '1175', 'American Pale Ale', '3', '26', '0.0', 1175, 'Spanish Peaks Brewing', 'Polson', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('137', '236', '471 Extra ESB', '-1', '-1', '7.8', 236, 'Breckenridge Brewery', 'Denver', 'United States', None, None, None, None, None)
# ('138', '935', 'Odell Red Ale', '3', '33', '6.5', 935, 'Odell Brewing', 'Fort Collins', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('139', '335', 'Long Leg English Fuggles Hop Ale', '-1', '-1', '0.0', 335, 'Camerons Brewery Company', 'Harltepool', 'United Kingdom', None, None, None, None, None)
# ('140', '671', 'Summer Lightning', '-1', '-1', '5.0', 671, 'Hop Back Brewery', 'Salisbury', 'United Kingdom', None, None, None, None, None)
# ('141', '255', 'Haymaker Extra Pale Ale', '-1', '-1', '0.0', 255, 'BridgePort Brewing', 'Portland', 'United States', None, None, None, None, None)
# ('142', '447', 'Pale Ale', '3', '26', '0.0', 447, "Dick's Brewing", 'Centralia', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('143', '447', 'Silk Lady', '3', '26', '4.4', 447, "Dick's Brewing", 'Centralia', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('144', '447', 'Danger Ale', '3', '38', '5.2', 447, "Dick's Brewing", 'Centralia', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('145', '447', 'Irish Style Ale', '-1', '-1', '5.2', 447, "Dick's Brewing", 'Centralia', 'United States', None, None, None, None, None)
# ('146', '1392', 'Yeti Special Export', '8', '95', '7.0', 1392, 'Yuksom Breweries', 'Malli', 'India', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('147', '1151', 'Steelie Brown Ale', '3', '38', '0.0', 1151, 'Skagit River Brewing', 'Mount Vernon', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('148', '441', 'Bond Street 19th Anniversary', '-1', '-1', '8.7', 441, 'Deschutes Brewery', 'Bend', 'United States', None, None, None, None, None)
# ('149', '1151', 'Trumpeter', '3', '42', '0.0', 1151, 'Skagit River Brewing', 'Mount Vernon', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('150', '1264', 'Nitro Porter', '2', '25', '0.0', 1264, 'Thunderhead Brewery #2', 'Grand Island', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('151', '62', 'Fourteen', '-1', '-1', '9.46', 62, 'Avery Brewing Company', 'Boulder', 'United States', None, None, None, None, None)
# ('152', '919', 'Old Stock Ale 2007', '1', '13', '11.7', 919, 'North Coast Brewing Company', 'Fort Bragg', 'United States', 1, 'British Ale', 13, 1, 'Old Ale')
# ('153', '160', 'Cold Hop', '1', '2', '6.5', 160, 'Boulder Beer Company', 'Boulder', 'United States', 1, 'British Ale', 2, 1, 'English-Style India Pale Ale')
# ('154', '742', 'Hitachino Nest Espresso Stout', '-1', '-1', '7.5', 742, 'Kiuchi Shuzou Goushi Kaisya', 'Ibaraki', 'Japan', None, None, None, None, None)
# ('155', '433', 'Witte', '-1', '-1', '5.0', 433, 'De Struise Brouwers', 'Woesten', 'Belgium', None, None, None, None, None)
# ('156', '432', 'Slaapmutske Triple Nightcap', '-1', '-1', '8.1', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('157', '723', 'Biere de Mars', '1', '13', '7.0', 723, 'Jolly Pumpkin Artisan Ales', 'Dexter', 'United States', 1, 'British Ale', 13, 1, 'Old Ale')
# ('158', '300', 'Kerst Pater Special Christmas Beer', '-1', '-1', '9.0', 300, 'Brouwerij Van Den Bossche', 'Sint-Lievens-Esse', 'Belgium', None, None, None, None, None)
# ('159', '432', 'Zoetzuur Flemish Ale', '-1', '-1', '7.0', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('160', '869', 'WPA (Wheat Pale Ale)', '-1', '-1', '0.0', 869, 'Minneapolis Town Hall Brewery', 'Minneapolis', 'United States', None, None, None, None, None)
# ('161', '869', 'Smoked Hefe', '8', '95', '0.0', 869, 'Minneapolis Town Hall Brewery', 'Minneapolis', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('162', '1084', 'The Unforgiven Amber Ale', '3', '33', '5.8', 1084, 'Rush River Brewing', 'River Falls', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('163', '192', 'Strange Ghost', '-1', '-1', '8.0', 192, 'Brasserie Fantme', 'Soy', 'Belgium', None, None, None, None, None)
# ('164', '595', 'Duke IPA', '3', '31', '5.1', 595, 'Granite City Food & Brewery - Omaha', 'Omaha', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('165', '595', 'Broad Axe Stout', '3', '42', '5.0', 595, 'Granite City Food & Brewery - Omaha', 'Omaha', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('166', '595', 'Northern Light Lager', '8', '95', '4.4', 595, 'Granite City Food & Brewery - Omaha', 'Omaha', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('167', '31', 'Podge Belgian Imperial Stout', '3', '42', '10.5', 31, 'Alvinne Picobrouwerij', 'Ingelmunster', 'Belgium', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('168', '307', 'Okocim Porter', '2', '25', '8.3', 307, 'Browar Okocim', 'Brzesko', 'Poland', 2, 'Irish Ale', 25, 2, 'Porter')
# ('169', '458', '1809', '-1', '-1', '5.0', 458, 'Doemens e.V.', 'Grfelfing', 'Germany', None, None, None, None, None)
# ('170', '433', 'Pannepot', '-1', '-1', '10.0', 433, 'De Struise Brouwers', 'Woesten', 'Belgium', None, None, None, None, None)
# ('171', '604', 'Samurai', '-1', '-1', '5.1', 604, 'Great Divide Brewing', 'Denver', 'United States', None, None, None, None, None)
# ('172', '122', 'Crystal Ale', '-1', '-1', '0.0', 122, 'Big Sky Brewing', 'Missoula', 'United States', None, None, None, None, None)
# ('173', '177', 'Gavroche French Red Ale', '-1', '-1', '8.5', 177, 'Brasserie De Saint Sylvestre', 'St-Sylvestre-Cappel', 'France', None, None, None, None, None)
# ('174', '1138', 'Coney Island Lager', '-1', '-1', '0.0', 1138, 'Shmaltz Enterprises', 'San Francisco', 'United States', None, None, None, None, None)
# ('175', '191', 'La BiÃ¨re des Collines van de Saisis', '-1', '-1', '0.0', 191, 'Brasserie Ellezelloise', 'Ellezelles', 'Belgium', None, None, None, None, None)
# ('176', '211', 'Dark Beer / StiftsbrÃ¤u', '-1', '-1', '0.0', 211, 'Brauerei Gss', 'Leoben-Gss', 'Austria', None, None, None, None, None)
# ('177', '723', 'LuciÃ©rnaga', '5', '64', '6.5', 723, 'Jolly Pumpkin Artisan Ales', 'Dexter', 'United States', 5, 'Belgian and French Ale', 64, 5, 'Belgian-Style Pale Ale')
# ('178', '202', 'CuvÃ©e des Champions 2003-2004', '5', '70', '0.0', 202, 'Brasserie-Brouwerij Cantillon', 'Anderlecht', 'Belgium', 5, 'Belgian and French Ale', 70, 5, 'Belgian-Style Fruit Lambic')
# ('179', '859', 'Beer Geek Breakfast', '3', '43', '7.5', 859, 'Mikkeller', 'KÃ¸benhavn', 'Denmark', 3, 'North American Ale', 43, 3, 'American-Style Imperial Stout')
# ('180', '432', 'Flemish Primitive Wild Ale (Spoon Whacker)', '-1', '-1', '9.0', 432, 'De Proef Brouwerij', 'Lochristi-Hijfte', 'Belgium', None, None, None, None, None)
# ('181', '39', 'Bock', '7', '90', '5.5', 39, 'Anchor Brewing', 'San Francisco', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('182', '810', 'Double India Pale Ale', '3', '26', '8.6', 810, 'Mad River Brewing', 'Blue Lake', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('183', '984', 'Old Bawdy 2006', '-1', '-1', '10.0', 984, 'Pike Pub and Brewery', 'Seattle', 'United States', None, None, None, None, None)
# ('184', '397', 'Extra Strong Vintage Ale', '-1', '-1', '7.5', 397, 'Coopers Brewery', 'Regency Park', 'Australia', None, None, None, None, None)
# ('185', '481', 'Certified Organic India Pale Ale', '3', '26', '7.0', 481, 'Eel River Brewing', 'Fortuna', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('186', '481', 'Certified Organic Porter', '2', '25', '5.5', 481, 'Eel River Brewing', 'Fortuna', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('187', '481', 'Certified Organic Extra Pale Ale', '-1', '-1', '0.0', 481, 'Eel River Brewing', 'Fortuna', 'United States', None, None, None, None, None)
# ('188', '481', 'Certified Organic Amber Ale', '3', '33', '4.8', 481, 'Eel River Brewing', 'Fortuna', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('189', '706', 'Farm House Ale', '-1', '-1', '6.7', 706, 'Jack Russell Brewing', 'Camino', 'United States', None, None, None, None, None)
# ('190', '255', 'Beer Town Brown', '3', '38', '0.0', 255, 'BridgePort Brewing', 'Portland', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('191', '890', 'Tanners Jack', '-1', '-1', '4.4', 890, 'Morland and Co.', 'Abingdon', 'United Kingdom', None, None, None, None, None)
# ('192', '62', 'Mephistopheles Stout', '3', '42', '16.03', 62, 'Avery Brewing Company', 'Boulder', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('193', '923', 'NÃ¸gne Ã˜ Brown Ale', '3', '38', '4.5', 923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 'Grimstad', 'Norway', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('194', '1204', 'Vertical Epic 07.07.07', '-1', '-1', '8.4', 1204, 'Stone Brewing Co.', 'Escondido', 'United States', None, None, None, None, None)
# ('195', '1136', 'Ringwood Brewery Old Thumper Extra Special Ale', '-1', '-1', '0.0', 1136, 'Shipyard Brewing - Portland', 'Portland', 'United States', None, None, None, None, None)
# ('196', '1136', 'Export Ale', '3', '26', '5.1', 1136, 'Shipyard Brewing - Portland', 'Portland', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('197', '950', 'Bourbon Barrel Porter', '-1', '-1', '9.1', 950, 'Oregon Trail Brewery', 'Corvallis', 'United States', None, None, None, None, None)
# ('198', '1204', 'Old Guardian Barley Wine 2007', '-1', '-1', '11.26', 1204, 'Stone Brewing Co.', 'Escondido', 'United States', None, None, None, None, None)
# ('199', '892', 'White Christmas', '-1', '-1', '6.5', 892, "Moylan's Brewery & Restaurant", 'Novato', 'United States', None, None, None, None, None)
# ('200', '175', 'Winter', '-1', '-1', '10.5', 175, "Brasserie de l'Abbaye Val-Dieu", 'Aubel', 'Belgium', None, None, None, None, None)
# ('201', '765', 'Undercover Investigation Shut-Down Ale', '3', '26', '9.28', 765, 'Lagunitas Brewing Company', 'Petaluma', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('202', '727', 'Harvest Ale 2006', '1', '13', '11.6', 727, 'JW Lees and Co (Brewers) Ltd.', 'Manchester', 'United Kingdom', 1, 'British Ale', 13, 1, 'Old Ale')
# ('203', '202', 'Classic Gueuze', '5', '70', '0.0', 202, 'Brasserie-Brouwerij Cantillon', 'Anderlecht', 'Belgium', 5, 'Belgian and French Ale', 70, 5, 'Belgian-Style Fruit Lambic')
# ('204', '1315', 'Gueuze-Lambic', '5', '70', '6.5', 1315, 'Upstream Brewing Company at Legacy', 'Omaha', 'United States', 5, 'Belgian and French Ale', 70, 5, 'Belgian-Style Fruit Lambic')
# ('205', '484', 'Schwarzbier / Dunkel', '7', '86', '4.9', 484, 'Einbecker Brauhaus AG', 'Einbeck', 'Germany', 7, 'German Lager', 86, 7, 'German-Style Schwarzbier')
# ('206', '779', 'Sawtooth Ale', '3', '26', '0.0', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('207', '779', 'Pole Star Pilsner', '-1', '-1', '0.0', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', None, None, None, None, None)
# ('208', '935', '90 Shilling', '1', '7', '5.3', 935, 'Odell Brewing', 'Fort Collins', 'United States', 1, 'British Ale', 7, 1, 'Scottish-Style Light Ale')
# ('209', '905', 'Sunshine Wheat', '11', '116', '4.8', 905, 'New Belgium Brewing', 'Fort Collins', 'United States', 11, 'Other Style', 116, 11, 'Light American Wheat Ale or Lager')
# ('210', '174', 'Grand Cru', '-1', '-1', '9.5', 174, "Brasserie De L'Abbaye Des Rocs", 'Montignies-sur-Roc', 'Belgium', None, None, None, None, None)
# ('211', '70', 'Der Weisse Bock', '4', '55', '8.5', 70, "Bamberger Mahr's-Bru", 'Bamberg', 'Germany', 4, 'German Ale', 55, 4, 'South German-Style Weizenbock')
# ('212', '176', 'Stouterik / The Brussels Stout', '-1', '-1', '0.0', 176, 'Brasserie de la Senne', 'Sint-Pieters-Leeuw', 'Belgium', None, None, None, None, None)
# ('213', '779', 'Black Jack Porter', '2', '25', '0.0', 779, 'Left Hand Brewing Company', 'Longmont', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('214', '161', 'Lunar Ale', '3', '38', '5.1', 161, 'Boulevard Brewing Company', 'Kansas City', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('215', '604', 'Denver Pale Ale / DPA', '3', '26', '5.4', 604, 'Great Divide Brewing', 'Denver', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('216', '296', 'Grotten Flemish Ale', '5', '72', '7.7', 296, 'Brouwerij St. Bernardus', 'Watou', 'Belgium', 5, 'Belgian and French Ale', 72, 5, 'Other Belgian-Style Ales')
# ('217', '1316', 'Grand Cru', '-1', '-1', '9.0', 1316, 'Upstream Brewing Old Market', 'Omaha', 'United States', None, None, None, None, None)
# ('218', '501', 'Summer Common', '-1', '-1', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', None, None, None, None, None)
# ('219', '1185', 'Golden Ale', '-1', '-1', '4.7', 1185, "St Peter's Brewery", 'Bungay', 'United Kingdom', None, None, None, None, None)
# ('220', '174', 'Ambree', '-1', '-1', '9.0', 174, "Brasserie De L'Abbaye Des Rocs", 'Montignies-sur-Roc', 'Belgium', None, None, None, None, None)
# ('221', '296', 'Pater 6', '5', '60', '6.7', 296, 'Brouwerij St. Bernardus', 'Watou', 'Belgium', 5, 'Belgian and French Ale', 60, 5, 'Belgian-Style Dubbel')
# ('222', '187', 'Blanche de Namur', '-1', '-1', '4.5', 187, 'Brasserie du Bocq', 'Purnode', 'Belgium', None, None, None, None, None)
# ('223', '905', 'Skinny Dip', '3', '37', '4.2', 905, 'New Belgium Brewing', 'Fort Collins', 'United States', 3, 'North American Ale', 37, 3, 'Golden or Blonde Ale')
# ('224', '174', 'Blanche Double', '-1', '-1', '6.0', 174, "Brasserie De L'Abbaye Des Rocs", 'Montignies-sur-Roc', 'Belgium', None, None, None, None, None)
# ('225', '236', 'Summer Bright Ale', '-1', '-1', '0.0', 236, 'Breckenridge Brewery', 'Denver', 'United States', None, None, None, None, None)
# ('226', '905', 'Mothership Wit', '-1', '-1', '4.8', 905, 'New Belgium Brewing', 'Fort Collins', 'United States', None, None, None, None, None)
# ('227', '696', 'Lia Fail Stone of Destiny Ale', '-1', '-1', '4.7', 696, 'Inveralmond Brewery', 'Perth', 'United Kingdom', None, None, None, None, None)
# ('228', '395', 'Premium XB Bluebird Bitter', '-1', '-1', '4.4', 395, 'Coniston Brewing', 'Coniston', 'United Kingdom', None, None, None, None, None)
# ('229', '1056', 'IPA', '3', '31', '5.5', 1056, 'Ridgeway Brewing', 'South Stoke', 'United Kingdom', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('230', '167', 'Houblon', '-1', '-1', '9.0', 167, "Brasserie D'Achouffe", 'Houffalize-Achouffe', 'Belgium', None, None, None, None, None)
# ('231', '935', 'Double Pilsner', '8', '95', '8.1', 935, 'Odell Brewing', 'Fort Collins', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('232', '708', 'Creamy Dark', '8', '95', '4.9', 708, 'Jacob Leinenkugel Brewing Company', 'Chippewa Falls', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('233', '757', 'Premium Pils Edelherb', '-1', '-1', '4.9', 757, 'Kulmbacher Brauerei AG', 'Kulmbach', 'Germany', None, None, None, None, None)
# ('234', '590', 'StÃ¼venbrÃ¤u Maibock', '7', '90', '0.0', 590, 'Gottberg Brew Pub', 'Columbus', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('235', '590', 'Jack of Spades Schwarzbier', '7', '86', '3.9', 590, 'Gottberg Brew Pub', 'Columbus', 'United States', 7, 'German Lager', 86, 7, 'German-Style Schwarzbier')
# ('236', '1179', 'Shiner Hefeweizen', '4', '50', '5.4', 1179, 'Spoetzl Brewery', 'Shiner', 'United States', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('237', '1154', 'Sapporo Premium Beer', '8', '95', '0.0', 1154, 'Sleeman Brewing & Malting', 'Guelph', 'Canada', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('238', '501', 'Dark German Lager', '-1', '-1', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', None, None, None, None, None)
# ('239', '44', 'Spring Heat Spiced Wheat', '-1', '-1', '5.2', 44, 'Anheuser-Busch', 'Saint Louis', 'United States', None, None, None, None, None)
# ('240', '567', 'Gose', '-1', '-1', '4.6', 567, 'Gasthaus & Gosebrauerei Bayerischer Bahnhof', 'Leipzig', 'Germany', None, None, None, None, None)
# ('241', '1176', 'Pils', '-1', '-1', '5.0', 1176, 'Spaten-Franziskaner-BrÃ¤u', 'MÃ¼nchen', 'Germany', None, None, None, None, None)
# ('242', '1274', 'New', '8', '95', '4.6', 1274, 'Tooheys', 'Sydney', 'Australia', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('243', '369', 'Eisenbahn Defumada', '-1', '-1', '0.0', 369, 'Cervejaria Sudbrack', 'Blumenau', 'Brazil', None, None, None, None, None)
# ('244', '369', 'Eisenbahn Escura', '7', '86', '0.0', 369, 'Cervejaria Sudbrack', 'Blumenau', 'Brazil', 7, 'German Lager', 86, 7, 'German-Style Schwarzbier')
# ('245', '369', 'Eisenbahn Dourada', '-1', '-1', '0.0', 369, 'Cervejaria Sudbrack', 'Blumenau', 'Brazil', None, None, None, None, None)
# ('246', '501', 'Fallen Angel Sweet Stout', '3', '42', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('247', '604', 'Hot Shot ESB', '1', '5', '5.0', 604, 'Great Divide Brewing', 'Denver', 'United States', 1, 'British Ale', 5, 1, 'Extra Special Bitter')
# ('248', '312', 'Porter', '2', '25', '8.0', 312, 'Bryggeriet lfabrikken', 'Tisvildeleje', 'Denmark', 2, 'Irish Ale', 25, 2, 'Porter')
# ('249', '923', 'NÃ¸gne Ã˜ Imperial Stout', '3', '43', '9.0', 923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 'Grimstad', 'Norway', 3, 'North American Ale', 43, 3, 'American-Style Imperial Stout')
# ('250', '923', 'NÃ¸gne Ã˜ Porter', '2', '25', '7.0', 923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 'Grimstad', 'Norway', 2, 'Irish Ale', 25, 2, 'Porter')
# ('251', '923', 'NÃ¸gne Ã˜ Pale Ale', '3', '26', '6.0', 923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 'Grimstad', 'Norway', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('252', '501', 'Eccentric Belgian Wheat', '-1', '-1', '0.0', 501, 'Empyrean Brewing Company', 'Lincoln', 'United States', None, None, None, None, None)
# ('253', '1265', 'Oatmeal Stout', '3', '42', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('254', '1265', 'Amber Light', '8', '95', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('255', '1265', 'New World Wheat', '8', '95', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('256', '1265', 'Maibock', '7', '90', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('257', '1265', 'Ironwood Dark', '3', '38', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('258', '1265', 'Cascade Amber', '3', '33', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('259', '1265', 'Alpine Gold', '-1', '-1', '0.0', 1265, 'Tied House Cafe & Brewery - San Jose', 'San Jose', 'United States', None, None, None, None, None)
# ('260', '624', 'Illuminator Doppelbock', '7', '90', '6.8', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('261', '624', 'Old Princeton Landing IPA', '3', '31', '6.1', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('262', '624', 'Paddle Out Stout', '3', '42', '5.2', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('263', '624', 'Pillar Point Pale Ale', '3', '26', '4.6', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('264', '624', 'Sandy Beach Blonde Hefeweizen', '4', '50', '4.5', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('265', '624', 'Mavericks Amber Ale', '3', '33', '4.8', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('266', '624', 'Harbor Light Ale', '-1', '-1', '4.8', 624, 'Half Moon Bay Brewing', 'Princeton by the Sea', 'United States', None, None, None, None, None)
# ('267', '1126', 'Leroy Barleywine', '-1', '-1', '0.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', None, None, None, None, None)
# ('268', '1126', 'Oatmeal Stout', '3', '42', '6.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('269', '1126', 'Amber', '3', '33', '5.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('270', '1126', 'Blur IPA', '3', '31', '0.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('271', '1126', 'Pelican Pale', '3', '26', '5.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('272', '1126', 'Brew Ribbon', '8', '95', '0.0', 1126, 'Seabright Brewery', 'Santa Cruz', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('273', '701', 'Casey Jones Imperial IPA', '3', '31', '7.25', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('274', '701', 'Fairfax Coffee Porter', '-1', '-1', '5.5', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', None, None, None, None, None)
# ('275', '701', 'Epiphany Ale', '3', '33', '5.5', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('276', '701', 'IPA', '3', '31', '6.0', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('277', '701', 'Chazz Cat Rye', '8', '95', '4.5', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('278', '701', 'Shining Star Pale Ale', '3', '26', '5.0', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('279', '701', 'Honey Bunny Blonde Ale', '8', '95', '5.8', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('280', '701', 'Kent Lake Kolsch', '-1', '-1', '4.0', 701, 'Iron Springs Pub & Brewery', 'Fairfax', 'United States', None, None, None, None, None)
# ('281', '892', 'Old Blarney Barleywine', '-1', '-1', '10.0', 892, "Moylan's Brewery & Restaurant", 'Novato', 'United States', None, None, None, None, None)
# ('282', '892', 'Irish Dry Stout', '3', '42', '4.8', 892, "Moylan's Brewery & Restaurant", 'Novato', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('283', '892', 'Kilt Lifter Scottish Ale', '1', '15', '8.0', 892, "Moylan's Brewery & Restaurant", 'Novato', 'United States', 1, 'British Ale', 15, 1, 'Scotch Ale')
# ('284', '892', 'India Pale Ale', '3', '26', '6.5', 892, "Moylan's Brewery & Restaurant", 'Novato', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('285', '588', 'Blonde Bock', '7', '90', '7.0', 588, 'Gordon Biersch Brewing', 'San Jose', 'United States', 7, 'German Lager', 90, 7, 'Traditional German-Style Bock')
# ('286', '588', 'Schwarzbier', '7', '86', '4.3', 588, 'Gordon Biersch Brewing', 'San Jose', 'United States', 7, 'German Lager', 86, 7, 'German-Style Schwarzbier')
# ('287', '588', 'Czech Lager', '-1', '-1', '0.0', 588, 'Gordon Biersch Brewing', 'San Jose', 'United States', None, None, None, None, None)
# ('288', '385', 'Yule Tide', '5', '61', '10.0', 385, 'Clipper City Brewing Co.', 'Baltimore', 'United States', 5, 'Belgian and French Ale', 61, 5, 'Belgian-Style Tripel')
# ('289', '588', 'Pilsner', '-1', '-1', '5.3', 588, 'Gordon Biersch Brewing', 'San Jose', 'United States', None, None, None, None, None)
# ('290', '308', 'Warka Strong', '8', '95', '7.0', 308, 'Browar Warka', 'Warka', 'Poland', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('291', '1074', 'Porter', '2', '25', '0.0', 1074, 'Roost Brewery', 'Campbell', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('292', '1074', 'ESB', '-1', '-1', '0.0', 1074, 'Roost Brewery', 'Campbell', 'United States', None, None, None, None, None)
# ('293', '1074', 'Pale Ale', '3', '26', '0.0', 1074, 'Roost Brewery', 'Campbell', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('294', '1074', 'Kristall Weizen', '8', '95', '0.0', 1074, 'Roost Brewery', 'Campbell', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('295', '1163', 'ESB (Extra Special Blizzard)', '-1', '-1', '6.0', 1163, 'Snowshoe Brewing - Sonora', 'Sonora', 'United States', None, None, None, None, None)
# ('296', '677', 'Paint the Town Red', '3', '33', '0.0', 677, 'HopTown Brewing', 'Pleasanton', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('297', '677', 'Golden Ale', '-1', '-1', '0.0', 677, 'HopTown Brewing', 'Pleasanton', 'United States', None, None, None, None, None)
# ('298', '1004', 'Train Wreck IPA', '3', '31', '0.0', 1004, 'Pleasanton Main Street Brewery', 'Pleasanton', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('299', '1004', 'Zone 7 Porter', '2', '25', '3.8', 1004, 'Pleasanton Main Street Brewery', 'Pleasanton', 'United States', 2, 'Irish Ale', 25, 2, 'Porter')
# ('300', '1004', 'Pleasanton Pale', '3', '26', '5.3', 1004, 'Pleasanton Main Street Brewery', 'Pleasanton', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('301', '1004', 'Island Wheat', '8', '95', '0.0', 1004, 'Pleasanton Main Street Brewery', 'Pleasanton', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('302', '707', 'Hefeweizen', '4', '50', '5.6', 707, "Jack's Brewing", 'Fremont', 'United States', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ...
# ('5818', '1251', "The Angel's Share - Bourbon Barrel Aged", '3.0', '30.0', '12.5', 1251, 'The Lost Abbey', 'San Marcos', 'United States', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5819', '1352', 'Weyerbacher Juliet', '4.0', '57.0', '8.5', 1352, 'Weyerbacher Brewing Company', 'Easton', 'United States', 4, 'German Ale', 57, 4, 'German-Style Brown Ale/Altbier')
# ('5820', '87', '2x4 India Pale Ale', '3.0', '32.0', '7.0', 87, 'Bavarian Barbarian Brewing Company', 'Williamsport', 'United States', 3, 'North American Ale', 32, 3, 'Imperial or Double India Pale Ale')
# ('5821', '358', 'Brewhouse Coffee Stout', '-1.0', '-1.0', '0.0', 358, 'Central Waters Brewing Company', 'Amherst', 'United States', None, None, None, None, None)
# ('5822', '656', 'Dundee KÃ¶lsch-Style Ale', '-1.0', '-1.0', '5.68', 656, 'High Falls Brewing', 'Rochester', 'United States', None, None, None, None, None)
# ('5823', '656', 'Dundee Stout', '3.0', '42.0', '5.8', 656, 'High Falls Brewing', 'Rochester', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('5824', '859', 'Simcoe Single Hop IPA', '3.0', '31.0', '6.9', 859, 'Mikkeller', 'KÃ¸benhavn', 'Denmark', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5825', '700', 'Kryptonite Imperial IPA', '3.0', '32.0', '9.0', 700, 'Iron Hill Brewery - Wilmingon', 'Wilmington', 'United States', 3, 'North American Ale', 32, 3, 'Imperial or Double India Pale Ale')
# ('5826', '1172', 'Pine Belt Pale Ale', '3.0', '26.0', '6.3', 1172, 'Southern Star Brewing Company', 'Conroe', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5827', '45', 'Batch 666', '11.0', '141.0', '7.7', 45, 'Appalachian Brewing Company', 'Harrisburg', 'United States', 11, 'Other Style', 141, 11, 'Winter Warmer')
# ('5828', '236', '471 IPA', '3.0', '32.0', '9.2', 236, 'Breckenridge Brewery', 'Denver', 'United States', 3, 'North American Ale', 32, 3, 'Imperial or Double India Pale Ale')
# ('5829', '45', 'IPA Series (Simcoe)', '3.0', '31.0', '0.0', 45, 'Appalachian Brewing Company', 'Harrisburg', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5830', '45', 'IPA Series (Zeus)', '3.0', '31.0', '0.0', 45, 'Appalachian Brewing Company', 'Harrisburg', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5831', '45', 'IPA Series (Horizon)', '3.0', '31.0', '0.0', 45, 'Appalachian Brewing Company', 'Harrisburg', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5832', '133', 'Nit Wit', '5.0', '67.0', '4.7', 133, "BJ's Restaurant and Brewery", 'Brea', 'United States', 5, 'Belgian and French Ale', 67, 5, 'Belgian-Style White')
# ('5833', '1286', 'Scratch Beer 31 - 2010 Citra Of Brotherly Love IPA', '3.0', '31.0', '7.4', 1286, 'Troegs Brewing', 'Harrisburg', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5834', '634', 'Harpoon Leviathan', '3.0', '32.0', '10.0', 634, 'Harpoon Brewery - Boston', 'Boston', 'United States', 3, 'North American Ale', 32, 3, 'Imperial or Double India Pale Ale')
# ('5835', '1044', 'Full Moon Pale Rye Ale', '11.0', '119.0', '5.7', 1044, 'Real Ale Brewing Company', 'Blanco', 'United States', 11, 'Other Style', 119, 11, 'American Rye Ale or Lager')
# ('5836', '1044', 'Rio Blanco Pale Ale', '3.0', '26.0', '5.3', 1044, 'Real Ale Brewing Company', 'Blanco', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5837', '742', 'Hitachino Nest XH', '3.0', '30.0', '8.0', 742, 'Kiuchi Shuzou Goushi Kaisya', 'Ibaraki', 'Japan', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5838', '914', 'Ise Kadoya Stout', '3.0', '42.0', '5.0', 914, 'Nikenjayamochi Kadoya Honten Co.', None, 'Japan', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('5839', '1348', 'Wells Banana Bread Beer', '11.0', '121.0', '5.2', 1348, 'Wells and (&) Youngs Brewing Company Ltd.', None, 'United Kingdom', 11, 'Other Style', 121, 11, 'Fruit Beer')
# ('5840', '23', 'Allagash Fluxus 09', '5.0', '74.0', '8.3', 23, 'Allagash Brewing', 'Portland', 'United States', 5, 'Belgian and French Ale', 74, 5, 'French & Belgian-Style Saison')
# ('5841', '1394', 'HotRod Red', '2.0', '22.0', '6.1', 1394, 'Aviator Brewing Company', 'Fuquay Varina', 'United States', 2, 'Irish Ale', 22, 2, 'Irish-Style Red Ale')
# ('5842', '1394', 'Old BullDog Extra Special', '3.0', '30.0', '5.8', 1394, 'Aviator Brewing Company', 'Fuquay Varina', 'United States', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5843', '1', 'One', '5.0', '65.0', '8.0', 1, '(512) Brewing Company', 'Austin', 'United States', 5, 'Belgian and French Ale', 65, 5, 'Belgian-Style Pale Strong Ale')
# ('5847', '1396', 'Conundrum Red Ale', '3.0', '33.0', '7.0', 1396, 'Aspen Brewing Company', 'Aspen', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('5848', '1397', 'Oasis', '3.0', '31.0', '7.2', 1397, 'Tallgrass Brewing Co.', 'Manhattan', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5849', '1399', 'Hudson Pale Ale', '3.0', '26.0', '0.0', 1399, 'New Jersey Beer Company', 'North Bergen', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5850', '1326', 'Yakima Glory', '3.0', '41.0', '8.7', 1326, 'Victory Brewing', 'Downingtown', 'United States', 3, 'North American Ale', 41, 3, 'American-Style India Black Ale')
# ('5851', '1400', 'Irish Amber', '2.0', '22.0', '4.6', 1400, 'FINNEGANS', 'Minneapolis', 'United States', 2, 'Irish Ale', 22, 2, 'Irish-Style Red Ale')
# ('5852', '415', "Colonel Blide's Cask Ale", '1.0', '3.0', '5.5', 415, 'Cricket Hill', 'Fairfield', 'United States', 1, 'British Ale', 3, 1, 'Ordinary Bitter')
# ('5853', '415', "Cricket's Nocturne", '8.0', '105.0', '4.5', 415, 'Cricket Hill', 'Fairfield', 'United States', 8, 'North American Lager', 105, 8, 'American-Style Dark Lager')
# ('5854', '415', 'Fall Festivus Ale', '3.0', '33.0', '4.8', 415, 'Cricket Hill', 'Fairfield', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('5855', '1401', 'Little Scrapper IPA', '3.0', '31.0', '6.0', 1401, 'Half Pints Brewing Company', 'Winnipeg', 'Canada', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5856', '10', 'Christmas Ale', '3.0', '38.0', '5.5', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('5857', '62', "Samael's Oak-aged Ale", '1.0', '14.0', '14.5', 62, 'Avery Brewing Company', 'Boulder', 'United States', 1, 'British Ale', 14, 1, 'Strong Ale')
# ('5858', '62', 'Old Jubilation Ale', '1.0', '14.0', '8.0', 62, 'Avery Brewing Company', 'Boulder', 'United States', 1, 'British Ale', 14, 1, 'Strong Ale')
# ('5859', '144', 'Fresh Hops Pale Ale', '3.0', '26.0', '5.0', 144, 'Blue Point Brewing', 'Patchogue', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5860', '144', 'Oktoberfest', '7.0', '84.0', '5.01', 144, 'Blue Point Brewing', 'Patchogue', 'United States', 7, 'German Lager', 84, 7, 'German-Style Oktoberfest')
# ('5861', '144', 'Sour Cherry Imperial Stout', '3.0', '43.0', '0.0', 144, 'Blue Point Brewing', 'Patchogue', 'United States', 3, 'North American Ale', 43, 3, 'American-Style Imperial Stout')
# ('5862', '49', 'Foreign Extra Stout', '2.0', '24.0', '7.5', 49, 'Arthur Guinness & Son', 'Dublin', 'Ireland', 2, 'Irish Ale', 24, 2, 'Foreign (Export)-Style Stout')
# ('5863', '1149', 'Sweet Action', '11.0', '113.0', '5.2', 1149, 'Sixpoint Craft Ales', 'Brooklyn', 'United States', 11, 'Other Style', 113, 11, 'American-Style Cream Ale or Lager')
# ('5864', '1204', 'Vertical Epic 10.10.10', '5.0', '64.0', '9.5', 1204, 'Stone Brewing Co.', 'Escondido', 'United States', 5, 'Belgian and French Ale', 64, 5, 'Belgian-Style Pale Ale')
# ('5865', '1271', 'Imperial Nut Brown', '3.0', '38.0', '9.8', 1271, 'Tommyknocker Brewery and Pub', 'Idaho Springs', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('5866', '959', 'Alta Gracia Coffee Porter', '3.0', '46.0', '0.0', 959, "Otter Creek Brewing & Wolaver's Organic Ales", 'Middlebury', 'United States', 3, 'North American Ale', 46, 3, 'Porter')
# ('5867', '206', "Beck's Light", '7.0', '79.0', '0.0', 206, 'Brauerei Beck', 'Bremen', 'Germany', 7, 'German Lager', 79, 7, 'European Low-Alcohol Lager')
# ('5868', '164', 'Triple', '5.0', '61.0', '8.4', 164, 'Brasserie Artisanale de Rulles', 'Habay-Rulles', 'Belgium', 5, 'Belgian and French Ale', 61, 5, 'Belgian-Style Tripel')
# ('5869', '618', 'Corona Light', '8.0', '96.0', '4.1', 618, 'Grupo Modelo', 'Mexico City', 'Mexico', 8, 'North American Lager', 96, 8, 'American-Style Light Lager')
# ('5870', '1402', "Doc's Hard Apple Cider", '11.0', '121.0', '4.5', 1402, 'Warwick Valley Wine Co.', 'Warwick', 'United States', 11, 'Other Style', 121, 11, 'Fruit Beer')
# ('5871', '1246', 'Loakal Red', '3.0', '33.0', '6.9', 1246, 'The Bruery', 'Placentia', 'United States', 3, 'North American Ale', 33, 3, 'American-Style Amber/Red Ale')
# ('5872', '1312', 'Kingfisher Premium', '8.0', '96.0', '4.8', 1312, 'United Breweries Limited', 'Bangalore', 'India', 8, 'North American Lager', 96, 8, 'American-Style Light Lager')
# ('5873', '1092', 'Dry-Hopped APA', '3.0', '26.0', '5.9', 1092, 'Saint Louis Brewery / Schlafy Tap Room', 'Saint Louis', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5874', '1092', 'Coffee Stout', '3.0', '42.0', '5.7', 1092, 'Saint Louis Brewery / Schlafy Tap Room', 'Saint Louis', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('5875', '1404', 'Pale Ale', '3.0', '26.0', '4.4', 1404, 'The St. Louis Brewrey', 'St. Louis', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5876', '1405', 'Baltika 6', '9.0', '106.0', '7.0', 1405, 'Baltika Breweries', 'St. Petersburg', 'Russia', 9, 'Other Lager', 106, 9, 'Baltic-Style Porter')
# ('5877', '1407', 'Firewater Indian Pale Ale', '3.0', '31.0', '0.0', 1407, 'Catawba Valley Brewing Company', 'Glen Alpine', 'United States', 3, 'North American Ale', 31, 3, 'American-Style India Pale Ale')
# ('5878', '49', 'Guinness Draught', '2.0', '23.0', '4.3', 49, 'Arthur Guinness & Son', 'Dublin', 'Ireland', 2, 'Irish Ale', 23, 2, 'Classic Irish-Style Dry Stout')
# ('5879', '1409', 'Summer Teeth', '4.0', '58.0', '5.3', 1409, 'Columbus Brewing Company', 'Columbus', 'United States', 4, 'German Ale', 58, 4, 'Kellerbier - Ale')
# ('5880', '1410', 'Dank', '3.0', '34.0', '9.2', 1410, 'Oso', 'Plover', 'United States', 3, 'North American Ale', 34, 3, 'Imperial or Double Red Ale')
# ('5881', '1391', 'Dos Perros', '3.0', '38.0', '3.5', 1391, 'Yazoo Brewing', 'Nashville', 'United States', 3, 'North American Ale', 38, 3, 'American-Style Brown Ale')
# ('5882', '1391', 'Pale Ale', '3.0', '30.0', '5.8', 1391, 'Yazoo Brewing', 'Nashville', 'United States', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5883', '1391', 'Hefeweizen', '4.0', '50.0', '5.0', 1391, 'Yazoo Brewing', 'Nashville', 'United States', 4, 'German Ale', 50, 4, 'South German-Style Hefeweizen')
# ('5884', '1391', 'Sly Rye Porter', '3.0', '46.0', '5.7', 1391, 'Yazoo Brewing', 'Nashville', 'United States', 3, 'North American Ale', 46, 3, 'Porter')
# ('5885', '1391', 'Onward Stout', '3.0', '42.0', '3.8', 1391, 'Yazoo Brewing', 'Nashville', 'United States', 3, 'North American Ale', 42, 3, 'American-Style Stout')
# ('5886', '1411', 'Dark Element', '11.0', '127.0', '8.75', 1411, 'Element Brewing Company', 'Millers Falls', 'United States', 11, 'Other Style', 127, 11, 'Specialty Beer')
# ('5887', '1412', 'Finest Bitter', '1.0', '3.0', '4.0', 1412, 'Cains', 'Liverpool', 'United Kingdom', 1, 'British Ale', 3, 1, 'Ordinary Bitter')
# ('5888', '1412', 'FA', '1.0', '4.0', '4.8', 1412, 'Cains', 'Liverpool', 'United Kingdom', 1, 'British Ale', 4, 1, 'Special Bitter or Best Bitter')
# ('5889', '1412', 'IPA', '1.0', '2.0', '3.5', 1412, 'Cains', 'Liverpool', 'United Kingdom', 1, 'British Ale', 2, 1, 'English-Style India Pale Ale')
# ('5890', '1412', 'Dark Mild', '1.0', '11.0', '3.2', 1412, 'Cains', 'Liverpool', 'United Kingdom', 1, 'British Ale', 11, 1, 'English-Style Dark Mild Ale')
# ('5891', '1412', '2008 Culture Beer', '1.0', '3.0', '5.0', 1412, 'Cains', 'Liverpool', 'United Kingdom', 1, 'British Ale', 3, 1, 'Ordinary Bitter')
# ('5892', '1413', 'Iron Rail IPA', '1.0', '2.0', '7.2', 1413, 'Wedge Brewery', 'Asheville', 'United States', 1, 'British Ale', 2, 1, 'English-Style India Pale Ale')
# ('5893', '1414', 'Black Creek Porter', '11.0', '130.0', '0.0', 1414, 'Black Creek Historic Brewery', 'Toronto', 'Canada', 11, 'Other Style', 130, 11, 'Smoke Beer')
# ('5894', '1416', 'Vivant Tripel', '5.0', '61.0', '9.25', 1416, 'Brewery Vivant', 'Grand Rapids', 'United States', 5, 'Belgian and French Ale', 61, 5, 'Belgian-Style Tripel')
# ('5895', '1417', 'Watershed IPA', '3.0', '30.0', '7.1', 1417, 'Oakshire', 'Eugene', 'United States', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5896', '1417', 'Watershed IPA', '3.0', '30.0', '7.1', 1417, 'Oakshire', 'Eugene', 'United States', 3, 'North American Ale', 30, 3, 'American-Style Strong Pale Ale')
# ('5898', '1087', 'Estrella Levante Especial', '9.0', '106.0', '5.4', 1087, 'S.A. Damm', 'Barcelona', 'Spain', 9, 'Other Lager', 106, 9, 'Baltic-Style Porter')
# ('5899', '1087', 'Estrella Levante Sin 0.0% Alcohol', '9.0', '106.0', '1.0', 1087, 'S.A. Damm', 'Barcelona', 'Spain', 9, 'Other Lager', 106, 9, 'Baltic-Style Porter')
# ('5900', '1419', 'Koshihikari Echigo Beer', '11.0', '132.0', '5.0', 1419, 'Uehara Shuzou Co. Ltd. / Echigo Beer Pub', None, 'Japan', 11, 'Other Style', 132, 11, 'Out of Category')
# ('5901', '1420', 'Full Boar', '11.0', '132.0', '0.0', 1420, "Devil's Canyon", 'Belmont', 'United States', 11, 'Other Style', 132, 11, 'Out of Category')
# ('5902', '1421', 'The Public', '3.0', '26.0', '6.0', 1421, 'DC Brau', 'Washington', 'United States', 3, 'North American Ale', 26, 3, 'American-Style Pale Ale')
# ('5903', '10', 'Abita Amber', '7.0', '82.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 7, 'German Lager', 82, 7, 'Vienna-Style Lager')
# ('5904', '10', 'S.O.S', '7.0', '77.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 7, 'German Lager', 77, 7, 'German-Style Pilsener')
# ('5905', '10', 'Abita Golden', '8.0', '95.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 8, 'North American Lager', 95, 8, 'American-Style Lager')
# ('5906', '10', 'Abita Light Beer', '8.0', '96.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 8, 'North American Lager', 96, 8, 'American-Style Light Lager')
# ('5907', '10', 'Abbey Ale', '1.0', '1.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 1, 'British Ale', 1, 1, 'Classic English-Style Pale Ale')
# ('5908', '10', 'Wheat', '7.0', '82.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 7, 'German Lager', 82, 7, 'Vienna-Style Lager')
# ('5909', '10', 'Triple Citra Hopped Satsuma Wit', '11.0', '121.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 11, 'Other Style', 121, 11, 'Fruit Beer')
# ('5910', '10', 'Honey Rye Ale', '11.0', '128.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 11, 'Other Style', 128, 11, 'Specialty Honey Lager or Ale')
# ('5911', '10', 'Strawberry', '11.0', '121.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 11, 'Other Style', 121, 11, 'Fruit Beer')
# ('5912', '10', 'Satsuma Wit', '11.0', '121.0', '0.0', 10, 'Abita Brewing Company', 'Abita Springs', 'United States', 11, 'Other Style', 121, 11, 'Fruit Beer')
# ('5913', '1422', 'Abhi beer', '7.0', '89.0', '0.0', 1422, 'Abhi Brewery', None, 'India', 7, 'German Lager', 89, 7, 'Bamberg-Style Bock Rauchbier')
# ('5914', '1423', 'Ambr', '11.0', '132.0', '0.0', 1423, 'Brasserie du Bouffay', 'Carquefou', 'France', 11, 'Other Style', 132, 11, 'Out of Category')

# %% [markdown]
# ## 4. Questions related to the data (use database from 3. to answer)
#
# 1. What is the average alcohol content of the beers produced by country of production?
# 1. How many breweries are there per country/city?
# 1. How many beer styles does a brewery brew on average? How many are there per country?
# 1. What is the median of the alcohol content?
# 1. Which beer style is mainly found in which country?

# %%
# open db and cursor
conn = sqlite3.connect('beer.db')
c = conn.cursor()

# %% [markdown]
# ### 1. What is the average alcohol content of the beers produced by country of production?

# %%
c.execute('''SELECT bw.country, round(AVG(b.abv), 2) as 'abv' FROM beers b 
                LEFT JOIN breweries bw ON b.brewery_id = bw.id 
                WHERE bw.country <> 'None'
                GROUP BY bw.country ORDER BY abv DESC
                ''')

for row in c.fetchall():
    print (row)
# Out:
# ('Sri Lanka', 8.4)
# ('Estonia', 7.8)
# ('Denmark', 7.07)
# ('Argentina', 6.5)
# ('Poland', 6.13)
# ('Latvia', 5.73)
# ('Lithuania', 5.7)
# ('Hungary', 5.58)
# ('England', 5.49)
# ('Belgium', 5.49)
# ('Norway', 5.47)
# ('Russia', 5.38)
# ('United Kingdom', 5.25)
# ('Netherlands', 5.22)
# ('France', 5.14)
# ('India', 5.01)
# ('Myanmar', 5.0)
# ('Mauritius', 5.0)
# ('Macedonia, the Former Yugoslav Republic of', 5.0)
# ('Greece', 5.0)
# ('French Polynesia', 5.0)
# ('Aruba', 5.0)
# ('Austria', 4.77)
# ('Finland', 4.73)
# ('Colombia', 4.7)
# ('Jamaica', 4.67)
# ('Ireland', 4.57)
# ('Italy', 4.38)
# ('Spain', 4.24)
# ('New Zealand', 4.15)
# ('Macao', 4.0)
# ('Sweden', 3.79)
# ('Australia', 3.77)
# ('United States', 3.15)
# ('Japan', 3.01)
# ('Korea, Republic of', 2.97)
# ('Germany', 2.87)
# ('Thailand', 2.5)
# ('Czech Republic', 2.34)
# ('Canada', 2.31)
# ('Mexico', 2.15)
# ('Brazil', 2.12)
# ('Philippines', 2.1)
# ('Switzerland', 2.0)
# ('Panama', 1.25)
# ('El Salvador', 0.78)
# ('Togo', 0.0)
# ('Taiwan, Province of China', 0.0)
# ('Slovakia', 0.0)
# ('Sierra Leone', 0.0)
# ('Namibia', 0.0)
# ('Kenya', 0.0)
# ('Honduras', 0.0)
# ('Guatemala', 0.0)
# ('Cuba', 0.0)
# ('Croatia', 0.0)
# ('China', 0.0)
# ('Belize', 0.0)

# %% [markdown]
# ### 2. How many breweries are there per country/city?

# %%
# per country
c.execute('''SELECT bw.country, count(bw.id) as 'cnt' FROM breweries bw
                WHERE bw.country <> 'None'
                GROUP BY bw.country ORDER BY 2 DESC
                ''')

for row in c.fetchall():
    print (row)
# Out:
# ('United States', 876)
# ('Germany', 117)
# ('Belgium', 99)
# ('United Kingdom', 79)
# ('Canada', 45)
# ('Czech Republic', 18)
# ('Australia', 14)
# ('Netherlands', 12)
# ('France', 11)
# ('Switzerland', 10)
# ('Japan', 10)
# ('Ireland', 10)
# ('Austria', 10)
# ('New Zealand', 9)
# ('Poland', 6)
# ('Sweden', 5)
# ('Russia', 5)
# ('Mexico', 5)
# ('India', 5)
# ('Italy', 4)
# ('Norway', 3)
# ('Lithuania', 3)
# ('Korea, Republic of', 3)
# ('Hungary', 3)
# ('Denmark', 3)
# ('Viet Nam', 2)
# ('Thailand', 2)
# ('Spain', 2)
# ('Greece', 2)
# ('Finland', 2)
# ('England', 2)
# ('El Salvador', 2)
# ('China', 2)
# ('Brazil', 2)
# ('Argentina', 2)
# ('Togo', 1)
# ('Taiwan, Province of China', 1)
# ('Sri Lanka', 1)
# ('Slovakia', 1)
# ('Sierra Leone', 1)
# ('Serbia and Montenegro', 1)
# ('Portugal', 1)
# ('Philippines', 1)
# ('Panama', 1)
# ('Namibia', 1)
# ('Myanmar', 1)
# ('Mauritius', 1)
# ('Macedonia, the Former Yugoslav Republic of', 1)
# ('Macao', 1)
# ('Latvia', 1)
# ('Kenya', 1)
# ('Jamaica', 1)
# ('Israel', 1)
# ('Honduras', 1)
# ('Guatemala', 1)
# ('French Polynesia', 1)
# ('Estonia', 1)
# ('Egypt', 1)
# ('Cuba', 1)
# ('Croatia', 1)
# ('Colombia', 1)
# ('Belize', 1)
# ('Aruba', 1)

# %%
# per city
c.execute('''SELECT bw.city, bw.country, count(bw.id) as 'cnt' FROM breweries bw
                WHERE bw.city <> 'None' and bw.country <> 'None'
                GROUP BY bw.city ORDER BY 3 DESC
                ''')

for row in c.fetchall():
    print (row)
# Out:
# ('Portland', 'United States', 17)
# ('Seattle', 'United States', 13)
# ('Denver', 'United States', 13)
# ('San Francisco', 'United States', 10)
# ('Chicago', 'United States', 10)
# ('San Diego', 'United States', 9)
# ('Bamberg', 'Germany', 9)
# ('Milwaukee', 'United States', 8)
# ('Boulder', 'United States', 8)
# ('Vancouver', 'Canada', 7)
# ('Omaha', 'United States', 7)
# ('Dallas', 'United States', 7)
# ('Baltimore', 'United States', 7)
# ('Saint Paul', 'United States', 6)
# ('Pittsburgh', 'United States', 6)
# ('Madison', 'United States', 6)
# ('Dsseldorf', 'Germany', 6)
# ('Philadelphia', 'United States', 5)
# ('Minneapolis', 'United States', 5)
# ('Las Vegas', 'United States', 5)
# ('Cleveland', 'United States', 5)
# ('Boston', 'United States', 5)
# ('Austin', 'United States', 5)
# ('Anchorage', 'United States', 5)
# ('Wilmington', 'United States', 4)
# ('Toronto', 'Canada', 4)
# ('Santa Rosa', 'United States', 4)
# ('Salt Lake City', 'United States', 4)
# ('MÃ¼nchen', 'Germany', 4)
# ('Louisville', 'United States', 4)
# ('London', 'United Kingdom', 4)
# ('La Jolla', 'United States', 4)
# ('La Crosse', 'United States', 4)
# ('Kln', 'Germany', 4)
# ('Fort Collins', 'United States', 4)
# ('Eugene', 'United States', 4)
# ('Columbus', 'United States', 4)
# ('Cincinnati', 'United States', 4)
# ('Berkeley', 'United States', 4)
# ('Albuquerque', 'United States', 4)
# ('Zrich', 'Switzerland', 3)
# ('Williamsport', 'United States', 3)
# ('Utica', 'United States', 3)
# ('Tampa', 'United States', 3)
# ('Sydney', 'Australia', 3)
# ('Surrey', 'Canada', 3)
# ('San Marcos', 'United States', 3)
# ('San Antonio', 'United States', 3)
# ('Saint Louis', 'United States', 3)
# ('Sacramento', 'United States', 3)
# ('Richmond', 'Canada', 3)
# ('Portsmouth', 'United Kingdom', 3)
# ('Oudenaarde', 'Belgium', 3)
# ('New Orleans', 'United States', 3)
# ('Milford', 'United States', 3)
# ('Melbourne', 'Australia', 3)
# ('Manchester', 'United Kingdom', 3)
# ('Longmont', 'United States', 3)
# ('Lincoln', 'United States', 3)
# ('Kansas City', 'United States', 3)
# ('Ingelmunster', 'Belgium', 3)
# ('Greenville', 'United States', 3)
# ('Green Bay', 'United States', 3)
# ('Grand Rapids', 'United States', 3)
# ('Fresno', 'United States', 3)
# ('Durango', 'United States', 3)
# ('Dublin', 'Ireland', 3)
# ('Dresden', 'Germany', 3)
# ('Detroit', 'United States', 3)
# ('Colorado Springs', 'United States', 3)
# ('Burlington', 'United States', 3)
# ('Bloomington', 'United States', 3)
# ('Atlanta', 'United States', 3)
# ('Ashland', 'United States', 3)
# ('Asheville', 'United States', 3)
# ('Appleton', 'United States', 3)
# ('esk Budjovice', 'Czech Republic', 2)
# ('baarle-hertog', 'Belgium', 2)
# ('Winnipeg', 'Canada', 2)
# ('Watou', 'Belgium', 2)
# ('Washington', 'United States', 2)
# ('Warren', 'United States', 2)
# ('Vista', 'United States', 2)
# ('Victoria', 'Canada', 2)
# ('Ukiah', 'United States', 2)
# ('Toms River', 'United States', 2)
# ('Tokyo', 'Japan', 2)
# ('Tempe', 'United States', 2)
# ('Tadcaster', 'United Kingdom', 2)
# ('Tacoma', 'United States', 2)
# ('Sunnyvale', 'United States', 2)
# ('Stuttgart', 'Germany', 2)
# ('Sturgeon Bay', 'United States', 2)
# ('Strongsville', 'United States', 2)
# ('Stevens Point', 'United States', 2)
# ('St. Petersburg', 'Russia', 2)
# ('South Burlington', 'United States', 2)
# ('Seoul', 'Korea, Republic of', 2)
# ('Scottsdale', 'United States', 2)
# ('Santa Fe', 'United States', 2)
# ('Santa Cruz', 'United States', 2)
# ('San Salvador', 'El Salvador', 2)
# ('San Jose', 'United States', 2)
# ('Saint John', 'Canada', 2)
# ('Saint Cloud', 'United States', 2)
# ('Roseburg', 'United States', 2)
# ('Rochester', 'United States', 2)
# ('Ripon', 'United Kingdom', 2)
# ('Regensburg', 'Germany', 2)
# ('Reedsburg', 'United States', 2)
# ('Raleigh', 'United States', 2)
# ('Qingdao', 'China', 2)
# ('Praha', 'Czech Republic', 2)
# ('Port Washington', 'United States', 2)
# ('Pleasanton', 'United States', 2)
# ('Petaluma', 'United States', 2)
# ('Orlando', 'United States', 2)
# ('Opwijk', 'Belgium', 2)
# ('Novato', 'United States', 2)
# ('New York', 'United States', 2)
# ('Nelson', 'New Zealand', 2)
# ('Nashville', 'United States', 2)
# ('Mukilteo', 'United States', 2)
# ('Moskva', 'Russia', 2)
# ('Morrisville', 'United States', 2)
# ('Montreal', 'Canada', 2)
# ('Monterrey', 'Mexico', 2)
# ('Monroe', 'United States', 2)
# ('Modesto', 'United States', 2)
# ('Moab', 'United States', 2)
# ('Mnchen', 'Germany', 2)
# ('Missoula', 'United States', 2)
# ('Middlebury', 'United States', 2)
# ('Manhattan', 'United States', 2)
# ('Lexington', 'United States', 2)
# ('Leuven', 'Belgium', 2)
# ('Lake Havasu City', 'United States', 2)
# ('Lake Barrington', 'United States', 2)
# ('Kulmbach', 'Germany', 2)
# ('Konstanz', 'Germany', 2)
# ('Knoxville', 'United States', 2)
# ('Kearney', 'United States', 2)
# ('Kalamazoo', 'United States', 2)
# ('Ipswich', 'United States', 2)
# ('Indianapolis', 'United States', 2)
# ('Hood River', 'United States', 2)
# ('Honolulu', 'United States', 2)
# ('Holland', 'United States', 2)
# ('Hereford', 'United Kingdom', 2)
# ('Helena', 'United States', 2)
# ('Hastings', 'United States', 2)
# ('Harrisburg', 'United States', 2)
# ('Hannover', 'Germany', 2)
# ('Greeley', 'United States', 2)
# ('Grand Island', 'United States', 2)
# ('Golden', 'United States', 2)
# ('Fremont', 'United States', 2)
# ('Frederick', 'United States', 2)
# ('Fort Wayne', 'United States', 2)
# ('Flagstaff', 'United States', 2)
# ('Fairfax', 'United States', 2)
# ('Edinburgh', 'United Kingdom', 2)
# ('Durham', 'United Kingdom', 2)
# ('Dunedin', 'United States', 2)
# ('Duluth', 'United States', 2)
# ('Dubuque', 'United States', 2)
# ('Dornbirn', 'Austria', 2)
# ('Dillon', 'United States', 2)
# ('Des Moines', 'United States', 2)
# ('Delafield', 'United States', 2)
# ('Cork', 'Ireland', 2)
# ('Concord', 'United States', 2)
# ('Chico', 'United States', 2)
# ('Charleston', 'United States', 2)
# ('Chapel Hill', 'United States', 2)
# ('Castle Rock', 'United States', 2)
# ('Campbell', 'United States', 2)
# ('Cambridge', 'United States', 2)
# ('Calgary', 'Canada', 2)
# ('Burton-upon-Trent', 'United Kingdom', 2)
# ('Buggenhout', 'Belgium', 2)
# ('Brugge', 'Belgium', 2)
# ('Brooklyn', 'United States', 2)
# ('Breendonk', 'Belgium', 2)
# ('Boise', 'United States', 2)
# ('Blue Lake', 'United States', 2)
# ('Billings', 'United States', 2)
# ('Berlin', 'Germany', 2)
# ('Bellingham', 'United States', 2)
# ('Belgrade', 'United States', 2)
# ('Belfast', 'United States', 2)
# ('Beersel', 'Belgium', 2)
# ('Bar Harbor', 'United States', 2)
# ('Bangkok', 'Thailand', 2)
# ('Bangalore', 'India', 2)
# ('Athens', 'Greece', 2)
# ('Amsterdam', 'Netherlands', 2)
# ('Amherst', 'United States', 2)
# ('Albany', 'United States', 2)
# ('Akron', 'United States', 2)
# ('Achel', 'Belgium', 2)
# ('atec', 'Czech Republic', 1)
# ('Zywiec', 'Poland', 1)
# ('York', 'England', 1)
# ('Yangon', 'Myanmar', 1)
# ('Yakima', 'United States', 1)
# ('Wrzburg', 'Germany', 1)
# ('Woodbridge', 'United States', 1)
# ('Wolnzach', 'Germany', 1)
# ('Woesten', 'Belgium', 1)
# ('Witnica', 'Poland', 1)
# ('Witney', 'United Kingdom', 1)
# ('Wisconsin Dells', 'United States', 1)
# ('Wisbech', 'United Kingdom', 1)
# ('Winterthur', 'Switzerland', 1)
# ('Winston-Salem', 'United States', 1)
# ('Winona', 'United States', 1)
# ('Windsor', 'United States', 1)
# ('Windhoek', 'Namibia', 1)
# ('Wilson', 'United States', 1)
# ('Willoughby', 'United States', 1)
# ('Wilkes Barre', 'United States', 1)
# ('Wieselburg', 'Austria', 1)
# ('Wien', 'Austria', 1)
# ('Whitsett', 'United States', 1)
# ('Whitewater', 'United States', 1)
# ('White River Junction', 'United States', 1)
# ('White Marsh', 'United States', 1)
# ('Wheeling', 'United States', 1)
# ('Wevelgem', 'Belgium', 1)
# ('Westvleteren', 'Belgium', 1)
# ('Westport', 'United States', 1)
# ('Weston-super-Mare', 'United Kingdom', 1)
# ('Westminster', 'United States', 1)
# ('Westmalle', 'Belgium', 1)
# ('Westerlo', 'Belgium', 1)
# ('West Yellowstone', 'United States', 1)
# ('West Philly', 'United States', 1)
# ('West Dundee', 'United States', 1)
# ('Wernigerode', 'Germany', 1)
# ('Webberville', 'United States', 1)
# ('Wdenswil', 'Switzerland', 1)
# ('Wayne', 'United States', 1)
# ('Wauwatosa', 'United States', 1)
# ('Wausau', 'United States', 1)
# ('Waukesha', 'United States', 1)
# ('Watertown', 'United States', 1)
# ('Waterloo', 'Canada', 1)
# ('Waterbury', 'United States', 1)
# ('Wasilla', 'United States', 1)
# ('Warwick', 'United States', 1)
# ('Warstein', 'Germany', 1)
# ('Warrenville', 'United States', 1)
# ('Warka', 'Poland', 1)
# ('Waltham', 'United States', 1)
# ('Walnut Creek', 'United States', 1)
# ('Wallsend', 'United Kingdom', 1)
# ('Walla Walla', 'United States', 1)
# ('Wailuku', 'United States', 1)
# ('Vysok Chlumec', 'Czech Republic', 1)
# ('Vorchdorf', 'Austria', 1)
# ('Vlezenbeek', 'Belgium', 1)
# ('Villers-devant-Orval', 'Belgium', 1)
# ('Victor', 'United States', 1)
# ('Vichte', 'Belgium', 1)
# ('Vernon', 'Canada', 1)
# ('Velk Popovice', 'Czech Republic', 1)
# ('Valparaiso', 'United States', 1)
# ('Vail', 'United States', 1)
# ('Utena', 'Lithuania', 1)
# ('Ursel', 'Belgium', 1)
# ('Urbana', 'United States', 1)
# ('Uppsala', 'Sweden', 1)
# ('Unity', 'United States', 1)
# ('Ulm', 'Germany', 1)
# ('Uji', 'Japan', 1)
# ('Udine', 'Italy', 1)
# ('Tychy', 'Poland', 1)
# ('Tustin', 'United States', 1)
# ('Tulsa', 'United States', 1)
# ('Tucson', 'United States', 1)
# ('Truckee', 'United States', 1)
# ('Trowbridge', 'United Kingdom', 1)
# ('Traunstein', 'Germany', 1)
# ('Tourpes', 'Belgium', 1)
# ('Tournai', 'Belgium', 1)
# ('Torrechiara', 'Italy', 1)
# ('Toledo', 'United States', 1)
# ('Tisvildeleje', 'Denmark', 1)
# ('Thnh Pho Ho Ch Minh', 'Viet Nam', 1)
# ('The Borders', 'United Kingdom', 1)
# ('Tettnang', 'Germany', 1)
# ('Ternat', 'Belgium', 1)
# ('Tarpon Springs', 'United States', 1)
# ('Tannersville', 'United States', 1)
# ('Takayama', 'Japan', 1)
# ('Takaka', 'New Zealand', 1)
# ('Taipei', 'Taiwan, Province of China', 1)
# ('Tahiti', 'French Polynesia', 1)
# ('Syracuse', 'United States', 1)
# ('Swansea', 'United Kingdom', 1)
# ('Superior', 'United States', 1)
# ('Sunnyside', 'United States', 1)
# ('Suisun City', 'United States', 1)
# ('Strasbourg', 'France', 1)
# ('Stoke Lacy', 'United Kingdom', 1)
# ('Stockton', 'United States', 1)
# ('Stockport', 'United Kingdom', 1)
# ('Stillwater', 'United States', 1)
# ('Stevenson', 'United States', 1)
# ('Sterling', 'United States', 1)
# ('Steinberg/Sachsen', 'Germany', 1)
# ('Steinberg-WernesgrÃ¼n, Germany', 'Germany', 1)
# ('Steenhuffel', 'Belgium', 1)
# ('State College', 'United States', 1)
# ('St. Paul', 'United States', 1)
# ("St. Mary's", 'United States', 1)
# ('St. Louis', 'United States', 1)
# ('St. John', 'United States', 1)
# ('St. Austell', 'United Kingdom', 1)
# ('St-Sylvestre-Cappel', 'France', 1)
# ('St Michaels', 'United States', 1)
# ('St Charles', 'United States', 1)
# ('Springfield', 'United States', 1)
# ('Sparta', 'United States', 1)
# ('Sparks', 'United States', 1)
# ('Soy', 'Belgium', 1)
# ('Southwold', 'United Kingdom', 1)
# ('Southampton', 'United States', 1)
# ('South Stoke', 'United Kingdom', 1)
# ('South Orange', 'United States', 1)
# ('South Barrington', 'United States', 1)
# ('Sopron', 'Hungary', 1)
# ('Sonthofen', 'Germany', 1)
# ('Sonora', 'United States', 1)
# ('Solon', 'United States', 1)
# ('Solana Beach', 'United States', 1)
# ('Socorro', 'United States', 1)
# ('Slippery Rock', 'United States', 1)
# ('Skopje', 'Macedonia, the Former Yugoslav Republic of', 1)
# ('Skegness', 'United Kingdom', 1)
# ('Sioux Falls', 'United States', 1)
# ('Sint-Ulriks-Kapelle', 'Belgium', 1)
# ('Sint-Pieters-Leeuw', 'Belgium', 1)
# ('Sint-Lievens-Esse', 'Belgium', 1)
# ('Simmerberg', 'Germany', 1)
# ('Silver Spring', 'United States', 1)
# ('Silly', 'Belgium', 1)
# ('Siletz', 'United States', 1)
# ('Shrewsbury', 'United Kingdom', 1)
# ('Shiner', 'United States', 1)
# ('Sheridan', 'United States', 1)
# ('Sheboygan', 'United States', 1)
# ('Selinsgrove', 'United States', 1)
# ('Sedona', 'United States', 1)
# ('Schwelm', 'Germany', 1)
# ('Schwbisch Gmnd', 'Germany', 1)
# ('Savannah', 'United States', 1)
# ('Saskatoon', 'Canada', 1)
# ('Saratoga Springs', 'United States', 1)
# ('Santa Barbara', 'United States', 1)
# ('Sankt-Peterburg', 'Russia', 1)
# ('Sankt-Gallen', 'Switzerland', 1)
# ('Sanctuary Cove', 'Australia', 1)
# ('San Ramon', 'United States', 1)
# ('San Rafael', 'United States', 1)
# ('San Pedro Sula', 'Honduras', 1)
# ('San Martin', 'Argentina', 1)
# ('San Leandro', 'United States', 1)
# ('San Clemente', 'United States', 1)
# ('Salzburg', 'Austria', 1)
# ('Salisbury', 'United Kingdom', 1)
# ('Salinas', 'United States', 1)
# ('Salida', 'United States', 1)
# ('Saku', 'Estonia', 1)
# ('Saint Helena', 'United States', 1)
# ('Saint Charles', 'United States', 1)
# ('Saignelgier', 'Switzerland', 1)
# ('Ruiselede', 'Belgium', 1)
# ('Royersford', 'United States', 1)
# ('Roselle Park', 'United States', 1)
# ('Rose City', 'United States', 1)
# ('Ronchin', 'France', 1)
# ('Romsey', 'United Kingdom', 1)
# ('Romakloster', 'Sweden', 1)
# ('Roeselare', 'Belgium', 1)
# ('Roermond', 'Netherlands', 1)
# ('Rocky River', 'United States', 1)
# ('Rockford', 'United States', 1)
# ('Rock Island', 'United States', 1)
# ('Rochefort', 'Belgium', 1)
# ('Riverside', 'United States', 1)
# ('River Falls', 'United States', 1)
# ('Rhinelander', 'United States', 1)
# ('Rga', 'Latvia', 1)
# ('Regency Park', 'Australia', 1)
# ('Redmond', 'United States', 1)
# ('Red Oak', 'United States', 1)
# ('Red Lodge', 'United States', 1)
# ('Red Bank', 'United States', 1)
# ('Reckendorf', 'Germany', 1)
# ('Reamstown', 'United States', 1)
# ('Reading', 'United States', 1)
# ('Ravensburg', 'Germany', 1)
# ('Rapid City', 'United States', 1)
# ('Raeren', 'Belgium', 1)
# ('Radeberg', 'Germany', 1)
# ('Quenast', 'Belgium', 1)
# ('Queenstown', 'New Zealand', 1)
# ('Purnode', 'Belgium', 1)
# ('Pullach im Isartal', 'Germany', 1)
# ('Providence', 'United States', 1)
# ('Princeton by the Sea', 'United States', 1)
# ('Princeton', 'United States', 1)
# ('Prescott', 'United States', 1)
# ('Pottsville', 'United States', 1)
# ('Ponta Grossa', 'Brazil', 1)
# ('Pont Fer', 'Mauritius', 1)
# ('Ponderay', 'United States', 1)
# ('Polson', 'United States', 1)
# ('Plze', 'Czech Republic', 1)
# ('Plover', 'United States', 1)
# ('Pleasantville', 'United States', 1)
# ('Placentia', 'United States', 1)
# ('Pipaix', 'Belgium', 1)
# ('Piozzo', 'Italy', 1)
# ('Pinedale', 'United States', 1)
# ('Picton', 'Australia', 1)
# ('Pickering', 'United Kingdom', 1)
# ('Phoenixville', 'United States', 1)
# ('Phoenix', 'United States', 1)
# ('Peterborough', 'United Kingdom', 1)
# ('Perth', 'United Kingdom', 1)
# ('Peoria', 'United States', 1)
# ('Pentlow', 'United Kingdom', 1)
# ('Penticton', 'Canada', 1)
# ('Pensacola', 'United States', 1)
# ('Pawleys Island', 'United States', 1)
# ('Patchogue', 'United States', 1)
# ('Paso Robles', 'United States', 1)
# ('Pasadena', 'United States', 1)
# ('Pardubice', 'Czech Republic', 1)
# ('Papillion', 'United States', 1)
# ('Panevys', 'Lithuania', 1)
# ('Pacific City', 'United States', 1)
# ('Pacific Beach', 'United States', 1)
# ('Oud-Turnhout', 'Belgium', 1)
# ('Oshkosh', 'United States', 1)
# ('Orkney', 'United Kingdom', 1)
# ('Opitter', 'Belgium', 1)
# ('Onuma', 'Japan', 1)
# ('Olympia', 'United States', 1)
# ('Olathe', 'United States', 1)
# ('Oconomowoc', 'United States', 1)
# ('Ocean', 'United States', 1)
# ('Oakville', 'Canada', 1)
# ('Oakland', 'United States', 1)
# ('Oak Harbor', 'United States', 1)
# ('Oak Bluffs', 'United States', 1)
# ("O'Fallon", 'United States', 1)
# ('Nrnberg', 'Germany', 1)
# ('Norwich', 'United Kingdom', 1)
# ('Northville', 'United States', 1)
# ('North Vancouver', 'Canada', 1)
# ('North Fremantle', 'Australia', 1)
# ('North Bergen', 'United States', 1)
# ('Norman', 'United States', 1)
# ('Noovice', 'Czech Republic', 1)
# ('Noblesville', 'United States', 1)
# ('Ninove', 'Belgium', 1)
# ('Niles', 'United States', 1)
# ('Nikic', 'Serbia and Montenegro', 1)
# ('Nijmegen', 'Netherlands', 1)
# ('Niagara Falls', 'Canada', 1)
# ('Newport', 'United States', 1)
# ('Newcastle-upon-Tyne', 'United Kingdom', 1)
# ('Newbridge', 'Ireland', 1)
# ('Newberg', 'United States', 1)
# ('Newark', 'United States', 1)
# ('New York Mills', 'United States', 1)
# ('New Ulm', 'United States', 1)
# ('New Hope', 'United States', 1)
# ('New Glarus', 'United States', 1)
# ('New Brunswick', 'United States', 1)
# ('New Brighton', 'United States', 1)
# ('New Albany', 'United States', 1)
# ('Neuzelle', 'Germany', 1)
# ('Neuhaus', 'Germany', 1)
# ('Nederland', 'United States', 1)
# ('Nchod', 'Czech Republic', 1)
# ('NamysÅ‚Ã³w', 'Poland', 1)
# ('Nairobi', 'Kenya', 1)
# ('Nagoya', 'Japan', 1)
# ('Myrtle Beach', 'United States', 1)
# ('Munster', 'United States', 1)
# ('Munich', 'Germany', 1)
# ('Mountain View', 'United States', 1)
# ('Mount Vernon', 'United States', 1)
# ('Mount Pleasant', 'United States', 1)
# ('Mount Joy', 'United States', 1)
# ('Mount Horeb', 'United States', 1)
# ('Moultonborough', 'United States', 1)
# ('Motten', 'Germany', 1)
# ('Motala', 'Sweden', 1)
# ('Mossautal', 'Germany', 1)
# ('Morgan Hill', 'United States', 1)
# ('Moreno Valley', 'United States', 1)
# ('Moos', 'Germany', 1)
# ('Mooresville', 'United States', 1)
# ('MontrÃ©al', 'Canada', 1)
# ('Montignies-sur-Roc', 'Belgium', 1)
# ('Monroeville', 'United States', 1)
# ('Moline', 'United States', 1)
# ('Molenbeek', 'Belgium', 1)
# ('Mnster', 'Germany', 1)
# ('Mnchengladbach', 'Germany', 1)
# ('Mission', 'Canada', 1)
# ('Mishawaka', 'United States', 1)
# ('Minocqua', 'United States', 1)
# ('Minnetonka', 'United States', 1)
# ('Mineral Point', 'United States', 1)
# ('Milton', 'United States', 1)
# ('Miltenberg', 'Germany', 1)
# ('Millmont', 'United States', 1)
# ('Millheim', 'United States', 1)
# ('Millers Falls', 'United States', 1)
# ('Mill Creek', 'United States', 1)
# ('Miesbach', 'Germany', 1)
# ('Midvale', 'United States', 1)
# ('Middletown', 'United States', 1)
# ('Middleton', 'United States', 1)
# ('Michigan City', 'United States', 1)
# ('Mexico City', 'Mexico', 1)
# ('Mexicali', 'Mexico', 1)
# ('Metuchen', 'United States', 1)
# ('Meschede', 'Germany', 1)
# ('Merchtem-Peizegem', 'Belgium', 1)
# ('Mequon', 'United States', 1)
# ('Mendoza', 'Argentina', 1)
# ('Melmerby', 'United Kingdom', 1)
# ('Melle', 'Belgium', 1)
# ('Mechelen', 'Belgium', 1)
# ('Meadville', 'United States', 1)
# ('McMinnville', 'United States', 1)
# ('McKinleyville', 'United States', 1)
# ('McHenry', 'United States', 1)
# ('Mazatln', 'Mexico', 1)
# ('Marshall', 'United States', 1)
# ('Marrero', 'United States', 1)
# ('Marquette', 'United States', 1)
# ('Marktoberdorf', 'Germany', 1)
# ('Marion', 'United States', 1)
# ('Marinette', 'United States', 1)
# ('Marina', 'United States', 1)
# ('Marblehead', 'United States', 1)
# ('Manteo', 'United States', 1)
# ('Mankato', 'United States', 1)
# ('Manitowoc', 'United States', 1)
# ('Manila', 'Philippines', 1)
# ('Manheim', 'United States', 1)
# ('Manhattan Beach', 'United States', 1)
# ('Manhasset', 'United States', 1)
# ('Mangatainoka', 'New Zealand', 1)
# ('Mammoth Lakes', 'United States', 1)
# ('Malli', 'India', 1)
# ('Maidstone', 'United Kingdom', 1)
# ('Maharashtra', 'India', 1)
# ('Macao', 'Macao', 1)
# ('Lyons', 'United States', 1)
# ('Lynnwood', 'United States', 1)
# ('Lyndonville', 'United States', 1)
# ('Luton', 'United Kingdom', 1)
# ('Lucan', 'United States', 1)
# ('Loveland', 'United States', 1)
# ('Los Angeles', 'United States', 1)
# ('Longview', 'United States', 1)
# ('Long Valley', 'United States', 1)
# ('Lombard', 'United States', 1)
# ('Lom', 'Togo', 1)
# ('Lodi', 'United States', 1)
# ('Lochristi-Hijfte', 'Belgium', 1)
# ('Llanelli', 'United Kingdom', 1)
# ('Liverpool', 'United Kingdom', 1)
# ('Littleton', 'United States', 1)
# ('Little Rock', 'United States', 1)
# ('Little River', 'Australia', 1)
# ('Lincolnville', 'United States', 1)
# ('Lincolnshire', 'United States', 1)
# ('Lieshout', 'Netherlands', 1)
# ('Lich', 'Germany', 1)
# ('Libertyville', 'United States', 1)
# ('Lewiston', 'United States', 1)
# ('Lewes', 'United Kingdom', 1)
# ('Leutkirch im AllgÃ¤u', 'Germany', 1)
# ('Leoben-Gss', 'Austria', 1)
# ('Lembeek', 'Belgium', 1)
# ('Leipzig', 'Germany', 1)
# ('Leesburg', 'United States', 1)
# ("Lee's Summit", 'United States', 1)
# ('Le Roeulx', 'Belgium', 1)
# ('Lawton', 'United States', 1)
# ('Lawrence', 'United States', 1)
# ('Laughlin', 'United States', 1)
# ('Latrobe', 'United States', 1)
# ('Las Cruces', 'United States', 1)
# ('Larkspur Landing', 'United States', 1)
# ('Lancaster', 'United States', 1)
# ('Lammi', 'Finland', 1)
# ('Lambertville', 'United States', 1)
# ('Lakewood', 'United States', 1)
# ('Lake Villa', 'United States', 1)
# ('Lake Placid', 'United States', 1)
# ('Lake Oswego', 'United States', 1)
# ('Lake Mills', 'United States', 1)
# ('Lake In The Hills', 'United States', 1)
# ('Lake Delton', 'United States', 1)
# ('Lahaska', 'United States', 1)
# ('Lahaina, Maui', 'United States', 1)
# ('Lagundo / Algund', 'Italy', 1)
# ('Lafayette', 'United States', 1)
# ('LaSalle', 'Canada', 1)
# ('LaPorte', 'United States', 1)
# ('LaConner', 'United States', 1)
# ('KÃ¸benhavn', 'Denmark', 1)
# ('KruÅ¡ovice', 'Czech Republic', 1)
# ('Kressbronn am Bodensee', 'Germany', 1)
# ('Krebs', 'United States', 1)
# ('Korschenbroich', 'Germany', 1)
# ('Koblenz', 'Germany', 1)
# ('Kobbegem', 'Belgium', 1)
# ('Knigseggwald', 'Germany', 1)
# ('Klter Hradit nad Jizerou', 'Czech Republic', 1)
# ('Klamath Falls', 'United States', 1)
# ('Klaipda', 'Lithuania', 1)
# ('Kirkland', 'United States', 1)
# ('Kingston', 'Jamaica', 1)
# ('Kiln', 'United States', 1)
# ('Killyleagh', 'Ireland', 1)
# ('Kilkenny', 'Ireland', 1)
# ('Kilegg', 'Germany', 1)
# ('Kihei', 'United States', 1)
# ('Keystone', 'United States', 1)
# ('Kerkom', 'Belgium', 1)
# ('Kerava', 'Finland', 1)
# ('Kenosha', 'United States', 1)
# ('Kempten', 'Germany', 1)
# ('Kelowna', 'Canada', 1)
# ('Kelheim', 'Germany', 1)
# ('Keene', 'United States', 1)
# ('Kbenhavn', 'Denmark', 1)
# ('Kaufbeuren', 'Germany', 1)
# ('Kassel', 'Germany', 1)
# ('Karlsruhe', 'Germany', 1)
# ('Karlovac', 'Croatia', 1)
# ('Kailua-Kona', 'United States', 1)
# ('Kahului', 'United States', 1)
# ('Juneau', 'United States', 1)
# ('Jumet', 'Belgium', 1)
# ('Jever, Germany', 'Germany', 1)
# ('Jever', 'Germany', 1)
# ('Jenlain', 'France', 1)
# ('Jauche', 'Belgium', 1)
# ('Janesville', 'United States', 1)
# ('Jalhay-Vervifontaine', 'Belgium', 1)
# ('Jacksonville', 'United States', 1)
# ('Jackson', 'United States', 1)
# ('Itterbeek', 'Belgium', 1)
# ('Ithaca', 'United States', 1)
# ('Itegem', 'Belgium', 1)
# ('Issum', 'Germany', 1)
# ('Issaquah', 'United States', 1)
# ('Isle of Skye', 'United Kingdom', 1)
# ('Ishpeming', 'United States', 1)
# ('Iron River', 'United States', 1)
# ('Irchonwelz', 'Belgium', 1)
# ('Iowa City', 'United States', 1)
# ('Inyokern', 'United States', 1)
# ('Innerleithen', 'United Kingdom', 1)
# ('Idaho Springs', 'United States', 1)
# ('Idaho Falls', 'United States', 1)
# ('Ichtegem', 'Belgium', 1)
# ('Ibaraki', 'Japan', 1)
# ('Hurbanovo', 'Slovakia', 1)
# ('Hue', 'Viet Nam', 1)
# ('Hradec Krlov', 'Czech Republic', 1)
# ('Houston', 'United States', 1)
# ('Houffalize-Achouffe', 'Belgium', 1)
# ('Horsham', 'United Kingdom', 1)
# ('Hordain', 'France', 1)
# ('Hopland', 'United States', 1)
# ('Hook Norton', 'United Kingdom', 1)
# ('Hoogstraten-Meer', 'Belgium', 1)
# ('Holyoke', 'United States', 1)
# ('Holguin', 'Cuba', 1)
# ('Hoegaarden', 'Belgium', 1)
# ('Hilo', 'United States', 1)
# ('Hillburn', 'United States', 1)
# ('Hertford', 'United Kingdom', 1)
# ('Herbertingen', 'Germany', 1)
# ('Henley-on-Thames', 'United Kingdom', 1)
# ('Henderson', 'United States', 1)
# ('Heimenkirch', 'Germany', 1)
# ('Heidelberg', 'Germany', 1)
# ('Heber City', 'United States', 1)
# ('Healdsburg', 'United States', 1)
# ('Hawkes Bay', 'New Zealand', 1)
# ('Hartford', 'United States', 1)
# ('Harrogate', 'United Kingdom', 1)
# ('Harltepool', 'United Kingdom', 1)
# ('Hamburg', 'Germany', 1)
# ('Hallein', 'Austria', 1)
# ('Halifax', 'Canada', 1)
# ('Habay-Rulles', 'Belgium', 1)
# ('Haarlem', 'Netherlands', 1)
# ('Gulpen', 'Netherlands', 1)
# ('Guelph', 'Canada', 1)
# ('Guatemala City', 'Guatemala', 1)
# ('GroÃŸostheim', 'Germany', 1)
# ('Grimstad', 'Norway', 1)
# ('Grieskirchen', 'Austria', 1)
# ('Grfelfing', 'Germany', 1)
# ('Greymouth', 'New Zealand', 1)
# ('Gresham', 'United States', 1)
# ('Greenwood', 'United States', 1)
# ('Greenwich', 'United Kingdom', 1)
# ('Greensburg', 'United States', 1)
# ('Graz', 'Austria', 1)
# ('Grand Lake', 'United States', 1)
# ('Granby', 'United States', 1)
# ('Granada', 'Spain', 1)
# ('Goze', 'Belgium', 1)
# ('Gloucester', 'United States', 1)
# ('Glenwood Springs', 'United States', 1)
# ('Glens Falls', 'United States', 1)
# ('Glendale', 'United States', 1)
# ('Glen Mills', 'United States', 1)
# ('Glen Ellyn', 'United States', 1)
# ('Glen Alpine', 'United States', 1)
# ('Glasgow', 'United Kingdom', 1)
# ('Gilroy', 'United States', 1)
# ('Germantown', 'United States', 1)
# ('Genval', 'Belgium', 1)
# ('Gaylord', 'United States', 1)
# ('Gateshead', 'United Kingdom', 1)
# ('Galesburg', 'United States', 1)
# ('Furiani', 'France', 1)
# ('Fuquay Varina', 'United States', 1)
# ('Fulton', 'United States', 1)
# ('Frstenfeldbruck', 'Germany', 1)
# ('Frisco', 'United States', 1)
# ('Fremantle', 'Australia', 1)
# ('Freising', 'Germany', 1)
# ('Freetown', 'Sierra Leone', 1)
# ('Fredrick', 'United States', 1)
# ('Frauenfeld', 'Switzerland', 1)
# ('Fraserburgh', 'United Kingdom', 1)
# ('Frankfurt/Main', 'Germany', 1)
# ('Frankfurt am Main', 'Germany', 1)
# ('Frankenmuth', 'United States', 1)
# ('Framingham', 'United States', 1)
# ('Fox', 'United States', 1)
# ('Fortworth', 'United States', 1)
# ('Fortuna', 'United States', 1)
# ('Fort Mitchell', 'United States', 1)
# ('Fort Lauderdale', 'United States', 1)
# ('Fort Bragg', 'United States', 1)
# ('Formosa', 'Canada', 1)
# ('Foothill Ranch', 'United States', 1)
# ('Flossmoor', 'United States', 1)
# ('Florence', 'United States', 1)
# ('Flensburg', 'Germany', 1)
# ('Fitchburg', 'United States', 1)
# ('Fenton', 'United States', 1)
# ('Fayetteville', 'United States', 1)
# ('Fawn Grove', 'United States', 1)
# ('Faversham', 'United Kingdom', 1)
# ('Farmville', 'United States', 1)
# ('Falmignoul', 'Belgium', 1)
# ('Falkenberg', 'Sweden', 1)
# ('Fairfield', 'United States', 1)
# ('Exeter', 'United Kingdom', 1)
# ('Evergem', 'Belgium', 1)
# ('Everett', 'United States', 1)
# ('Eureka', 'United States', 1)
# ('Ettal', 'Germany', 1)
# ('Etna', 'United States', 1)
# ('Estes Park', 'United States', 1)
# ('Esquelbecq', 'France', 1)
# ('Esen', 'Belgium', 1)
# ('Escondido', 'United States', 1)
# ('Escanaba', 'United States', 1)
# ('Ertvelde', 'Belgium', 1)
# ('Erpe-Mere', 'Belgium', 1)
# ('Erie', 'United States', 1)
# ('Erding', 'Germany', 1)
# ('Enterprise', 'United States', 1)
# ('Enschede', 'Netherlands', 1)
# ('Ennis', 'Ireland', 1)
# ('Englewood', 'United States', 1)
# ('Encinitas', 'United States', 1)
# ('Emeryville', 'United States', 1)
# ('Ellicott City', 'United States', 1)
# ('Ellezelles', 'Belgium', 1)
# ('Elk Grove', 'United States', 1)
# ('Elgin', 'United States', 1)
# ('El Dorado', 'Panama', 1)
# ('Einbeck', 'Germany', 1)
# ('Eichsttt', 'Germany', 1)
# ('Egg Harbor', 'United States', 1)
# ('Edwards', 'United States', 1)
# ('Eden Prairie', 'United States', 1)
# ('Ecaussinnes', 'Belgium', 1)
# ('Eau Claire', 'United States', 1)
# ('Easton', 'United States', 1)
# ('East Lothian', 'United Kingdom', 1)
# ('Eagle River', 'United States', 1)
# ('DÃ¼sseldorf', 'Germany', 1)
# ('Dworp', 'Belgium', 1)
# ('Duncansville', 'United States', 1)
# ('Duisburg', 'Germany', 1)
# ('Dudley', 'United Kingdom', 1)
# ('Drammen', 'Norway', 1)
# ('Downingtown', 'United States', 1)
# ('Downers Grove', 'United States', 1)
# ('Dover', 'United States', 1)
# ('Dortmund', 'Germany', 1)
# ('Dorchester', 'United Kingdom', 1)
# ('Donaueschingen', 'Germany', 1)
# ('Dommartin les Remiremont', 'France', 1)
# ('Dinant', 'Belgium', 1)
# ('Diest', 'Belgium', 1)
# ('Dexter', 'United States', 1)
# ('Dentergem', 'Belgium', 1)
# ('Denmark', 'United States', 1)
# ('Dene', 'Belgium', 1)
# ('Delta', 'Canada', 1)
# ('De Pere', 'United States', 1)
# ('Davis', 'United States', 1)
# ('Davenport', 'United States', 1)
# ('Cross Plains', 'United States', 1)
# ('Crested Butte', 'United States', 1)
# ('Corvallis', 'United States', 1)
# ('Cortland', 'United States', 1)
# ('Coronado', 'United States', 1)
# ('Corona', 'United States', 1)
# ('Cooperstown', 'United States', 1)
# ('Conroe', 'United States', 1)
# ('Coniston', 'United Kingdom', 1)
# ('Conestoga', 'United States', 1)
# ('Columbia', 'United States', 1)
# ('Colombo', 'Sri Lanka', 1)
# ('Collegeville', 'United States', 1)
# ('Cold Spring', 'United States', 1)
# ("Coeur d'Alene", 'United States', 1)
# ('Cockermouth', 'United Kingdom', 1)
# ('Clinton', 'United States', 1)
# ('Clear Lake', 'United States', 1)
# ('Clackmannan', 'United Kingdom', 1)
# ('Cinderford', 'United Kingdom', 1)
# ('Chippewa Falls', 'United States', 1)
# ('Chimay-Forges', 'Belgium', 1)
# ('Chimay', 'Belgium', 1)
# ('Chilton', 'United States', 1)
# ('Cheyenne', 'United States', 1)
# ('Cherry Hill', 'United States', 1)
# ('Chambly', 'Canada', 1)
# ('Chambersburg', 'United States', 1)
# ('Cham', 'Germany', 1)
# ('Chalfont', 'United States', 1)
# ('Cerfontaine-Silenrieux', 'Belgium', 1)
# ('Centreville', 'United States', 1)
# ('Centralia', 'United States', 1)
# ('Central City', 'United States', 1)
# ('Centerport', 'United States', 1)
# ('Cedar Rapids', 'United States', 1)
# ('Cave Junction', 'United States', 1)
# ('Casper', 'United States', 1)
# ('Carquefou', 'France', 1)
# ('Carpinteria', 'United States', 1)
# ('Carlow', 'Ireland', 1)
# ('Carleton Place', 'Canada', 1)
# ('Cardiff', 'United Kingdom', 1)
# ('Carbondale', 'United States', 1)
# ('Cannon Beach', 'United States', 1)
# ('Canning Vale', 'Australia', 1)
# ('Camperdown', 'Australia', 1)
# ('Camino', 'United States', 1)
# ('BÃ¶cs', 'Hungary', 1)
# ('Buxton', 'United Kingdom', 1)
# ('Buttenheim', 'Germany', 1)
# ('Butler', 'United States', 1)
# ('Bury St. Edmunds', 'United Kingdom', 1)
# ('Burnley', 'United Kingdom', 1)
# ('Burnaby', 'Canada', 1)
# ('Bungay', 'United Kingdom', 1)
# ('Buffalo', 'United States', 1)
# ('Budapest', 'Hungary', 1)
# ('Brzesko', 'Poland', 1)
# ('Brunehaut', 'Belgium', 1)
# ('Brooklyn Center', 'United States', 1)
# ('Bromma', 'Sweden', 1)
# ('Brno', 'Czech Republic', 1)
# ('Bristol', 'United States', 1)
# ('Bridgewater Corners', 'United States', 1)
# ('Bremen', 'Germany', 1)
# ('Brea', 'United States', 1)
# ('Boonville', 'United States', 1)
# ('Bonduel', 'United States', 1)
# ('Bolsward', 'Netherlands', 1)
# ('Bnifontaine', 'France', 1)
# ('Blumenau', 'Brazil', 1)
# ('Blue Ash', 'United States', 1)
# ('Bloomfield', 'United States', 1)
# ('Blaugies', 'Belgium', 1)
# ('Blanco', 'United States', 1)
# ('Blacksburg', 'United States', 1)
# ('Black River Falls', 'United States', 1)
# ('Bitburg', 'Germany', 1)
# ('Binche', 'Belgium', 1)
# ('Biloxi', 'United States', 1)
# ('Beznice', 'Czech Republic', 1)
# ('Bethlehem', 'United States', 1)
# ('Bethesda', 'United States', 1)
# ('Berwyn', 'United States', 1)
# ('Bernalillo', 'United States', 1)
# ('Berkeley Heights', 'United States', 1)
# ('Berkel-Enschot', 'Netherlands', 1)
# ('Bergen', 'Norway', 1)
# ('Benton Harbor', 'United States', 1)
# ('Bend', 'United States', 1)
# ('Beloit', 'United States', 1)
# ('Belmont', 'United States', 1)
# ('Bellegem', 'Belgium', 1)
# ('Bellaire', 'United States', 1)
# ('Belize City', 'Belize', 1)
# ('Bedford', 'United Kingdom', 1)
# ('Bear', 'United States', 1)
# ('Bayreuth', 'Germany', 1)
# ('Bavikhove', 'Belgium', 1)
# ('Baunatal', 'Germany', 1)
# ('Battle Creek', 'United States', 1)
# ('Batavia', 'United States', 1)
# ('Barre', 'United States', 1)
# ('Barranquilla', 'Colombia', 1)
# ('Baroda', 'United States', 1)
# ('Barcelona', 'Spain', 1)
# ('Bangor', 'United States', 1)
# ('Bakersfield', 'United States', 1)
# ('Bad Schussenried', 'Germany', 1)
# ('Bad KÃ¶stritz', 'Germany', 1)
# ('Aying', 'Germany', 1)
# ('Aurora', 'United States', 1)
# ('Augusta', 'United States', 1)
# ('Auckland', 'New Zealand', 1)
# ('Auburn', 'United States', 1)
# ('Aubel', 'Belgium', 1)
# ('Assebroek', 'Belgium', 1)
# ('Aspen', 'United States', 1)
# ('Arvada', 'United States', 1)
# ('Arlington Heights', 'United States', 1)
# ('Arlington', 'United States', 1)
# ('Arena', 'United States', 1)
# ('Arcen', 'Netherlands', 1)
# ('Arcata', 'United States', 1)
# ('Arbon', 'Switzerland', 1)
# ('Appenzell', 'Switzerland', 1)
# ('Antioch', 'United States', 1)
# ('Annapolis', 'United States', 1)
# ('Ann Arbor', 'United States', 1)
# ('Anderlecht', 'Belgium', 1)
# ('Andechs', 'Germany', 1)
# ('Anacortes', 'United States', 1)
# ('Ames', 'United States', 1)
# ('Amana', 'United States', 1)
# ('Alva', 'United Kingdom', 1)
# ('Alpirsbach', 'Germany', 1)
# ('Alpine', 'United States', 1)
# ('Alloa', 'United Kingdom', 1)
# ('Allentown', 'United States', 1)
# ('Alexandria', 'United States', 1)
# ('Aix les Bains', 'France', 1)
# ('Adelaide', 'Australia', 1)
# ('Addison', 'United States', 1)
# ('Adamstown', 'United States', 1)
# ('Abita Springs', 'United States', 1)
# ('Abingdon', 'United Kingdom', 1)
# ('Aberdeen', 'United States', 1)

# %% [markdown]
# ### 3. How many beer styles does a brewery brew on average? How many are there per country?

# %%
# per brewery
c.execute('''SELECT bw.Id, bw.name, COUNT(DISTINCT(b.style_id)) as 'cnt' FROM beers b 
                LEFT JOIN breweries bw ON b.brewery_id = bw.id 
                WHERE bw.country <> 'None'
                GROUP BY bw.id, bw.name ORDER BY 3 DESC
                ''')

for row in c.fetchall():
    print (row)
# Out:
# (858, 'Midnight Sun Brewing Co.', 33)
# (1286, 'Troegs Brewing', 29)
# (1072, 'Rogue Ales', 24)
# (157, 'Boston Beer Company', 23)
# (512, 'F.X. Matt Brewing', 23)
# (1173, 'Southern Tier Brewing Co', 22)
# (585, 'Goose Island Beer Company - Clybourn', 21)
# (100, "Bell's Brewery Inc.", 20)
# (1352, 'Weyerbacher Brewing Company', 20)
# (45, 'Appalachian Brewing Company', 19)
# (1326, 'Victory Brewing', 19)
# (44, 'Anheuser-Busch', 18)
# (441, 'Deschutes Brewery', 18)
# (960, "Otto's Pub and Brewery", 18)
# (10, 'Abita Brewing Company', 16)
# (338, 'Capital Brewery', 16)
# (459, 'Dogfish Head Craft Brewery', 16)
# (604, 'Great Divide Brewing', 16)
# (35, 'Amherst Brewing Company', 15)
# (483, 'Egan Brewing', 15)
# (812, 'Magic Hat', 15)
# (857, 'Middle Ages Brewing', 15)
# (1204, 'Stone Brewing Co.', 15)
# (385, 'Clipper City Brewing Co.', 14)
# (540, 'Flying Dog Brewery', 14)
# (590, 'Gottberg Brew Pub', 14)
# (771, 'Lancaster Brewing Co.', 14)
# (1142, 'Sierra Nevada Brewing Co.', 14)
# (551, 'Four Peaks Brewing', 13)
# (673, 'Hoppin Frog Brewery', 13)
# (907, 'New Glarus Brewing Company', 13)
# (923, 'NÃ¸gne Ã˜ - Det KompromisslÃ¸se Bryggeri A/S', 13)
# (1181, 'Sprecher Brewing', 13)
# (1250, 'The Livery', 13)
# (1260, 'Three Floyds Brewing', 13)
# (161, 'Boulevard Brewing Company', 12)
# (236, 'Breckenridge Brewery', 12)
# (1029, 'Pyramid Alehouse, Brewery and Restaurant - Berkeley', 12)
# (1243, 'Terrapin Beer Company', 12)
# (1268, 'Titletown Brewing', 12)
# (1301, 'Tyranena Brewing', 12)
# (1316, 'Upstream Brewing Old Market', 12)
# (17, 'Alaskan Brewing', 11)
# (160, 'Boulder Beer Company', 11)
# (259, 'Brooklyn Brewery', 11)
# (549, 'Founders Brewing', 11)
# (765, 'Lagunitas Brewing Company', 11)
# (905, 'New Belgium Brewing', 11)
# (976, 'Pennichuck Brewing Company', 11)
# (1031, 'Pyramid Ales Brewery', 11)
# (1038, 'Rahr & Sons Brewing Company', 11)
# (1195, 'Steamworks', 11)
# (1211, "Stoudt's Brewery", 11)
# (1307, 'Unibroue', 11)
# (1391, 'Yazoo Brewing', 11)
# (46, 'Appleton Brewing', 10)
# (47, 'Arcadia Brewing', 10)
# (56, 'Atwater Block Brewing', 10)
# (62, 'Avery Brewing Company', 10)
# (526, 'Fish Brewing Company & Fish Tail Brewpub', 10)
# (708, 'Jacob Leinenkugel Brewing Company', 10)
# (723, 'Jolly Pumpkin Artisan Ales', 10)
# (935, 'Odell Brewing', 10)
# (1009, 'Port Brewing Company', 10)
# (1059, 'River West Brewing', 10)
# (1086, 'Russian River Brewing', 10)
# (1244, 'The Alchemist', 10)
# (2, '21st Amendment Brewery Cafe', 9)
# (41, 'Anderson Valley Brewing', 9)
# (68, 'Ballast Point Brewing', 9)
# (76, 'Barley Creek Brewing', 9)
# (133, "BJ's Restaurant and Brewery", 9)
# (317, 'Bull & Bush Pub & Brewery', 9)
# (355, 'Cedar Brewing', 9)
# (384, 'Climax Brewing Copmany', 9)
# (399, 'Coors Brewing - Golden Brewery', 9)
# (412, 'Crane River Brewpub and Cafe', 9)
# (538, 'Flyers Restraunt and Brewery', 9)
# (541, 'Flying Fish Brewing Company', 9)
# (552, 'Fox River Brewing #1', 9)
# (553, 'Fratellos Restaurant and Brewery', 9)
# (562, 'Full Sail Brewing #1', 9)
# (586, 'Goose Island Beer Company - Fulton Street', 9)
# (605, 'Great Lakes Brewing', 9)
# (608, 'Green Bay Brewing', 9)
# (656, 'High Falls Brewing', 9)
# (850, 'Mercury Brewing Company', 9)
# (854, "Mickey Finn's Brewery", 9)
# (920, 'North Country Brewery', 9)
# (959, "Otter Creek Brewing & Wolaver's Organic Ales", 9)
# (1092, 'Saint Louis Brewery / Schlafy Tap Room', 9)
# (1108, 'Santa Fe Brewing Company', 9)
# (1263, 'Thunderhead Brewery', 9)
# (1346, 'Weinkeller Brewery - Berwyn', 9)
# (1379, 'Wynkoop Brewing', 9)
# (1383, 'Yards Brewing', 9)
# (25, 'Allentown Brew Works', 8)
# (39, 'Anchor Brewing', 8)
# (94, 'Bear Republic Brewery', 8)
# (241, 'BrewDog Ltd', 8)
# (314, "Bube's Brewery", 8)
# (326, 'C.B. & Potts of Cheyenne', 8)
# (328, 'Caldera Brewing', 8)
# (341, 'Captain Lawrence Brewing Company', 8)
# (437, 'Delafield Brewhaus', 8)
# (445, 'Diamond Knot Brewery & Alehouse', 8)
# (509, 'Estes Park Brewery', 8)
# (520, 'Fifty Fifty Brewing Co.', 8)
# (603, 'Great Dane Pub and Brewing #2', 8)
# (623, "Hale's Ales #3", 8)
# (634, 'Harpoon Brewery - Boston', 8)
# (658, 'Highland Brewing Company', 8)
# (725, "JT Whitney's Brewpub and Eatery", 8)
# (784, 'Liberty Steakhouse and Brewery', 8)
# (801, 'Long Trail Brewing Co', 8)
# (823, 'Manayunk Brewery and Restaurant', 8)
# (869, 'Minneapolis Town Hall Brewery', 8)
# (882, 'Moon River Brewing Company', 8)
# (888, 'Moosejaw Pizza & Dells Brewing Company', 8)
# (912, 'Niagara Falls Brewing', 8)
# (919, 'North Coast Brewing Company', 8)
# (929, 'Oak Creek Brewery', 8)
# (1015, 'Prescott Brewing Company', 8)
# (1051, 'Redhook Ale Brewery', 8)
# (1055, 'Richbrau Brewing Company', 8)
# (1099, 'Samuel Smith Old Brewery (Tadcaster)', 8)
# (1126, 'Seabright Brewery', 8)
# (1160, 'Smuttynose Brewing Co.', 8)
# (1219, "Sullivan's Black Forest Brew Haus & Grill", 8)
# (1248, 'The Church Brew Works', 8)
# (1271, 'Tommyknocker Brewery and Pub', 8)
# (1320, 'Valley Brewing Company', 8)
# (1, '(512) Brewing Company', 7)
# (71, 'Bandana Brewery', 7)
# (122, 'Big Sky Brewing', 7)
# (123, 'Big Time Brewing', 7)
# (144, 'Blue Point Brewing', 7)
# (255, 'BridgePort Brewing', 7)
# (258, 'Broad Ripple Brewing', 7)
# (296, 'Brouwerij St. Bernardus', 7)
# (319, 'Bullfrog Brewery', 7)
# (409, "Crabby Larry's Brewpub Steak & Crab House", 7)
# (426, 'Dark Horse Brewing Co.', 7)
# (463, 'Dragonmead Microbrewery', 7)
# (496, 'Elysian Brewery & Public House', 7)
# (501, 'Empyrean Brewing Company', 7)
# (504, 'Engine House #9', 7)
# (532, "Flatlander's Restaurant & Brewery", 7)
# (539, 'Flying Bison Brewing', 7)
# (588, 'Gordon Biersch Brewing', 7)
# (591, "Govnor's Public House", 7)
# (602, 'Great Dane Pub and Brewing #1', 7)
# (617, 'Grumpy Troll Restaurant and Brewery', 7)
# (624, 'Half Moon Bay Brewing', 7)
# (644, 'Heavenly Daze Brewery and Grill', 7)
# (678, 'Hopworks Urban Brewery', 7)
# (686, 'Humboldt Brewing', 7)
# (700, 'Iron Hill Brewery - Wilmingon', 7)
# (754, "Krogh's Restaurant and Brewpub", 7)
# (769, 'Lakefront Brewery', 7)
# (853, 'Michigan Brewing', 7)
# (878, 'Molson Breweries of Canada', 7)
# (908, 'New Holland Brewing Company', 7)
# (922, 'Northwoods Brewpub Grill', 7)
# (941, 'Old Hat Brewery', 7)
# (972, 'Paulaner', 7)
# (978, "Pete's Brewing", 7)
# (1030, 'Pyramid Alehouse, Brewery and Restaurant - Seattle', 7)
# (1035, 'Raccoon Lodge and Brewpub / Cascade Brewing', 7)
# (1066, 'Rock Bottom Restaurant & Brewery - Minneapolis', 7)
# (1079, 'Routh Street Brewery and Grille', 7)
# (1091, 'Saint Arnold Brewing', 7)
# (1124, 'Scuttlebutt Brewing', 7)
# (1136, 'Shipyard Brewing - Portland', 7)
# (1151, 'Skagit River Brewing', 7)
# (1158, 'Sly Fox Brewhouse and Eatery - Royersford', 7)
# (1193, 'Standing Stone Brewing Company', 7)
# (1199, "Steve and Clark's Brew Pub and Sausage Co. #2", 7)
# (1246, 'The Bruery', 7)
# (1330, 'Voodoo Brewing Co.,LLC', 7)
# (1339, 'Water Street Brewery', 7)
# (32, "America's Brewing", 6)
# (63, 'Back Road Brewery', 6)
# (101, 'Bellows Brew Crew', 6)
# (119, 'Big Ridge Brewing', 6)
# (142, 'Blue Cat Brew Pub', 6)
# (153, 'Bootleggers Steakhouse and Brewery', 6)
# (171, 'Brasserie de Brunehaut', 6)
# (235, 'Breckenridge BBQ of Omaha', 6)
# (250, 'Brewmasters Restaurant and Brewery South', 6)
# (304, 'Brouwerij Van Steenberge', 6)
# (396, "Cooper's Cave Ale Company", 6)
# (397, 'Coopers Brewery', 6)
# (398, 'Cooperstown Brewing Company', 6)
# (404, 'Coronado Brewing Company', 6)
# (407, 'Court Avenue Brewing', 6)
# (415, 'Cricket Hill', 6)
# (440, 'Denver ChopHouse and Brewery', 6)
# (447, "Dick's Brewing", 6)
# (470, 'DuClaw', 6)
# (490, 'Elk Creek Cafe and Aleworks', 6)
# (536, 'Flossmoor Station Brewery', 6)
# (563, 'Fuller, Smith & Turner PBC', 6)
# (576, 'Glen Ellyn Sports Brew', 6)
# (613, 'Greenshields Brewery and Pub', 6)
# (631, 'Hapa*s Brew Haus and Restaurant', 6)
# (651, 'Hereford & Hops Restaurant and Brewpub #1', 6)
# (652, 'Hereford & Hops Steakhouse and Brewpub #3', 6)
# (665, 'Hoffbrau Steaks Brewery #1', 6)
# (666, 'Hoffbrau Steaks Brewery #2', 6)
# (676, 'Hops Haven Brew Haus', 6)
# (705, 'Ithaca Beer Company', 6)
# (707, "Jack's Brewing", 6)
# (751, 'Kona Brewing', 6)
# (779, 'Left Hand Brewing Company', 6)
# (797, 'Live Oak Brewing', 6)
# (802, 'Long Valley Pub & Brewery', 6)
# (803, 'Lost Coast Brewery', 6)
# (827, 'Marin Brewing', 6)
# (829, 'Maritime Pacific Brewing', 6)
# (833, "Marzoni's Brick Oven & Brewing Co", 6)
# (841, 'McKenzie Brew House', 6)
# (867, 'Milwaukee Ale House', 6)
# (871, 'Minocqua Brewing Company', 6)
# (892, "Moylan's Brewery & Restaurant", 6)
# (936, "Oggi's Pizza and Brewing - Vista", 6)
# (942, 'Olde Main Brewing', 6)
# (945, 'On Tap Bistro & Brewery', 6)
# (956, 'Oskar Blues Grill and Brew', 6)
# (975, 'Penn Brewery', 6)
# (984, 'Pike Pub and Brewery', 6)
# (1004, 'Pleasanton Main Street Brewery', 6)
# (1023, 'Private Weissbierbrauerei G. Schneider & Sohn GmbH', 6)
# (1036, 'Raccoon River Brewing', 6)
# (1049, 'Red Star Brewery & Grille', 6)
# (1058, 'River Horse Brewing Company', 6)
# (1078, 'Route 66 Brewery', 6)
# (1081, 'Roy Pitz Brewing Company', 6)
# (1090, 'Sacramento Brewing Company', 6)
# (1100, 'San Diego Brewing', 6)
# (1101, 'San Marcos Brewery & Grill', 6)
# (1103, 'Sand Creek Brewing Company', 6)
# (1118, 'Schooner Brewery', 6)
# (1131, 'Sharktooth Brewing', 6)
# (1176, 'Spaten-Franziskaner-BrÃ¤u', 6)
# (1182, 'Spring House Brewing Company', 6)
# (1185, "St Peter's Brewery", 6)
# (1202, 'Stieglbrauerei zu Salzburg GmbH', 6)
# (1212, 'Stout Brothers Public House', 6)
# (1220, 'Summit Brewing', 6)
# (1232, 'Tailgate Beer', 6)
# (1251, 'The Lost Abbey', 6)
# (1265, 'Tied House Cafe & Brewery - San Jose', 6)
# (1285, 'Triumph Brewing of Princeton', 6)
# (1298, 'Two Brothers Brewing', 6)
# (1336, 'Walldorff Brew Pub', 6)
# (1340, 'Water Street Lake Country', 6)
# (1387, 'Yegua Creek Brewing - Dallas', 6)
# (1388, 'Yuengling & Son Brewing', 6)
# (4, 'Aass Brewery', 5)
# (11, 'Adnams & Co.', 5)
# (21, 'AleSmith Brewing', 5)
# (22, 'Ali`i Brewing', 5)
# (28, "Alltech's Lexington Brewing Company", 5)
# (49, 'Arthur Guinness & Son', 5)
# (75, 'Barley Brothers Brewery and Grill', 5)
# (77, 'Barley Island Brewing', 5)
# (87, 'Bavarian Barbarian Brewing Company', 5)
# (88, 'Bayerische Staatsbrauerei Weihenstephan', 5)
# (92, 'Beach Chalet Brewery', 5)
# (110, 'Bierbrouwerij De Koningshoeven', 5)
# (120, 'Big River Brewing', 5)
# (158, 'Boston Beer Works', 5)
# (230, 'Brauhaus Johann Albrecht - Konstanz', 5)
# (233, 'Brauhaus Sternen', 5)
# (247, 'Brewery Creek Brewing', 5)
# (249, 'Brewery Ommegang', 5)
# (280, 'Brouwerij der Sint-Benedictusabdij de Achelse Kluis', 5)
# (333, 'Cambridge Brewing', 5)
# (357, 'Central City Brewing Company', 5)
# (379, 'Cigar City Brewing', 5)
# (394, 'Commonwealth Brewing #1', 5)
# (455, "Dixon's Downtown Grill", 5)
# (457, 'Dockside Brewing', 5)
# (469, 'Duck-Rabbit Craft Brewery', 5)
# (476, 'East End Brewing Company', 5)
# (481, 'Eel River Brewing', 5)
# (515, 'Faultline Brewing #1', 5)
# (516, 'Faultline Brewing #2', 5)
# (522, 'Firehouse Brewing', 5)
# (523, 'Firehouse Grill & Brewery', 5)
# (527, "Fitger's Brewhouse, Brewery and Grill", 5)
# (559, 'Front Street Brewery', 5)
# (566, 'Gaslight Brewery', 5)
# (582, 'Golden Pacific Brewing', 5)
# (596, 'Granite City Food & Brewery - Saint Cloud', 5)
# (599, 'Gray Brewing', 5)
# (607, 'Great Waters Brewing Company', 5)
# (609, 'Green Flash Brewing', 5)
# (633, 'Harmon Brewing Company', 5)
# (643, 'Heartland Brewery Union Square', 5)
# (674, 'Hoppy Brewing Company', 5)
# (701, 'Iron Springs Pub & Brewery', 5)
# (721, "John Harvard's Brewhouse - Wilmington", 5)
# (731, 'Karl Strauss Brewery Gardens - Sorrento Mesa', 5)
# (742, 'Kiuchi Shuzou Goushi Kaisya', 5)
# (759, 'La Jolla Brew House', 5)
# (762, 'Labatt Ontario Breweries', 5)
# (795, 'Little Apple Brewing', 5)
# (808, 'Mad Anthony Brewing', 5)
# (809, 'Mad Crab Restaurant and Brewery', 5)
# (810, 'Mad River Brewing', 5)
# (813, 'Magnolia Pub and Brewery', 5)
# (842, 'McMenamins Mill Creek', 5)
# (847, 'Mendocino Brewing - Hopland', 5)
# (864, 'Millrose Brewing', 5)
# (868, 'Minhas Craft Brewery', 5)
# (872, 'Mishawaka Brewing', 5)
# (876, 'Mogollon Brewing Company', 5)
# (879, 'Montana Brewing', 5)
# (894, 'Mudshark Brewing', 5)
# (901, 'Nebraska Brewing Company', 5)
# (925, "O'Gara's Bar & Grill", 5)
# (926, "O'Grady's Brewery and Pub #1", 5)
# (930, 'Oaken Barrel Brewing', 5)
# (963, 'Pabst Brewing Company', 5)
# (965, 'Pacific Coast Brewing', 5)
# (966, 'Pacific Rim Brewing', 5)
# (1011, 'Porterhouse Restaurant and Brewpub', 5)
# (1039, 'Rail House Restaurant and Brewpub', 5)
# (1044, 'Real Ale Brewing Company', 5)
# (1056, 'Ridgeway Brewing', 5)
# (1062, 'Rock Art Brewery', 5)
# (1067, 'Rock Bottom Restaurant & Brewery - San Jose', 5)
# (1080, "Rowland's Calumet Brewery", 5)
# (1153, 'Slab City Brewing', 5)
# (1169, 'South Shore Brewery', 5)
# (1170, 'Southampton Publick House', 5)
# (1178, 'Spilker Ales', 5)
# (1210, 'Storm Brewing', 5)
# (1224, 'Sweetwater Brewing - Atlanta', 5)
# (1229, 'T-Bonz Gill, Grill and Brewery', 5)
# (1247, 'The Cambridge House', 5)
# (1256, 'ThirstyBear Brewing', 5)
# (1276, 'Top of the Hill Restaurant and Brewery', 5)
# (1277, 'Trade Winds Brewing', 5)
# (1280, 'Trap Rock Restaurant and Brewery', 5)
# (1296, 'Twin Rivers Brewing', 5)
# (1300, 'TwoRows Restaurant & Brewery - Dallas', 5)
# (1314, 'Upper Mississippi Brewing', 5)
# (1361, 'Widmer Brothers Brewing', 5)
# (1380, "Yakima Brewing and Malting / Grant's Ales", 5)
# (14, 'Aksarben Brewing (BOP)', 4)
# (23, 'Allagash Brewing', 4)
# (70, "Bamberger Mahr's-Bru", 4)
# (82, 'Baron Brewing Company', 4)
# (90, 'BBC Brewing Co., LLC', 4)
# (91, 'Beach Brewing', 4)
# (98, 'Belhaven Brewery', 4)
# (121, 'Big Rock Brewery', 4)
# (198, 'Brasserie McAuslan', 4)
# (205, 'Brauerei Aying Franz Inselkammer KG', 4)
# (206, 'Brauerei Beck', 4)
# (285, 'Brouwerij Huyghe', 4)
# (310, 'Brown Street Brewery', 4)
# (322, 'Burton Bridge Brewery', 4)
# (339, 'Capital City Brewing Company', 4)
# (350, 'Carolina Brewery', 4)
# (351, 'Carver Brewing Co.', 4)
# (356, 'Celis Brewery', 4)
# (358, 'Central Waters Brewing Company', 4)
# (369, 'Cervejaria Sudbrack', 4)
# (374, 'Chelsea Brewing Company', 4)
# (378, 'Chimay (Abbaye Notre Dame de Scourmont)', 4)
# (388, 'Coast Brewing', 4)
# (402, 'Copper Kettle Brewery', 4)
# (438, "Dempsey's Restaurant & Brewery", 4)
# (453, 'Dix Barbecue & Brewery', 4)
# (460, 'Dortmunder Actien Brauerei  DAB', 4)
# (462, 'Double Mountain Brewery & Taproom', 4)
# (494, 'Elliott Bay Brewery and Pub', 4)
# (521, 'Firehouse Brewery & Restaurant', 4)
# (528, "Fitzpatrick's Brewing", 4)
# (529, 'Flagstaff Brewing', 4)
# (550, 'Founders Hill Brewing', 4)
# (581, 'Golden Gate Park Brewery', 4)
# (584, 'Golden Valley Brewery and Pub', 4)
# (610, 'Green Mill Brewing - Saint Paul', 4)
# (612, 'Greene King', 4)
# (622, 'Hair of the Dog Brewing', 4)
# (641, 'Hawks Brewing', 4)
# (691, 'Independence Brew Pub', 4)
# (718, "JoBoy's Brew Pub", 4)
# (734, 'Keg Microbrewery & Restaurant', 4)
# (745, 'Klosterbrauerei Weltenburg', 4)
# (746, 'Klosterbru Bamberg', 4)
# (757, 'Kulmbacher Brauerei AG', 4)
# (763, 'LaConner Brewing', 4)
# (798, 'Loaf and Stein Brewing', 4)
# (865, 'Millstream Brewing', 4)
# (873, 'Mission Springs Brewing', 4)
# (883, 'Moonlight Brewing', 4)
# (885, "Moose's Tooth Pub and Pizzeria", 4)
# (895, "Murphy's Wagon Wheel", 4)
# (913, 'Nicolet Brewing', 4)
# (916, 'Nodding Head Brewpub', 4)
# (937, 'Ohio Brewing', 4)
# (943, 'Olde Peninsula Brewpub and Restaurant', 4)
# (947, 'Onopa Brewing', 4)
# (953, 'Orkney Brewery', 4)
# (962, 'Oyster Bar Bistro and Brewery', 4)
# (964, 'Pacific Beach Brewhouse', 4)
# (981, 'Philadelphia Brewing Co', 4)
# (985, 'Pinehurst Village Brewery', 4)
# (1002, 'Pizzeria Uno Chicago Grill & Brewery', 4)
# (1010, 'Port Washington Brewing', 4)
# (1013, 'Portsmouth Brewery', 4)
# (1014, 'Prairie Rock Brewing - Elgin', 4)
# (1019, 'Privatbrauerei Erdinger Weissbru', 4)
# (1054, 'Revolution Brewing LLC', 4)
# (1061, 'Rivertowne Pour House', 4)
# (1065, 'Rock Bottom Restaurant & Brewery - Milwaukee', 4)
# (1074, 'Roost Brewery', 4)
# (1085, 'Russell Brewing', 4)
# (1143, 'Siletz Roadhouse & Brewery', 4)
# (1147, 'Sioux Falls Brewing', 4)
# (1149, 'Sixpoint Craft Ales', 4)
# (1171, 'Southend Brewery and Smokehouse - Charleston', 4)
# (1175, 'Spanish Peaks Brewing', 4)
# (1177, 'Speakeasy Ales and Lagers', 4)
# (1179, 'Spoetzl Brewery', 4)
# (1191, 'Staatliches HofbrÃ¤uhaus in MÃ¼nchen', 4)
# (1200, 'Stevens Point Brewery', 4)
# (1236, 'Taylor Brewing', 4)
# (1237, "Taylor's Crossing Brewing", 4)
# (1238, "Taylor's Restaurant and Brewery", 4)
# (1245, 'The Blind Bat Brewery LLC', 4)
# (1253, 'The Round Barn Winery & Brewery', 4)
# (1264, 'Thunderhead Brewery #2', 4)
# (1279, 'Trailhead Brewing Company', 4)
# (1292, "Tunner's Guild Brewing Systems", 4)
# (1315, 'Upstream Brewing Company at Legacy', 4)
# (1337, 'Warsteiner Brauerei', 4)
# (1365, 'Wild River Brewing and Pizza - Cave Junction', 4)
# (1375, 'Wychwood Brewery', 4)
# (1385, 'Youngs & Company Brewery', 4)
# (1386, 'Zea Rotisserie and Brewery', 4)
# (1412, 'Cains', 4)
# (6, 'Abbaye de Maredsous', 3)
# (7, 'Abbaye Notre Dame du St Remy', 3)
# (26, 'Allguer Brauhaus AG Kempten', 3)
# (43, 'Angelic Brewing', 3)
# (57, 'August Schell Brewing', 3)
# (60, 'Augustiner-BrÃ¤u MÃ¼nchen', 3)
# (74, 'Barfer - das kleine Brauhaus', 3)
# (78, "Barley John's Brewpub", 3)
# (83, 'Barrel House Brewing Co.', 3)
# (106, 'Bethlehem Brew Works', 3)
# (113, 'Big Boss Brewing Company', 3)
# (114, 'Big Buck Brewery', 3)
# (167, "Brasserie D'Achouffe", 3)
# (202, 'Brasserie-Brouwerij Cantillon', 3)
# (204, 'Brauerei & Gasthof zur Krone', 3)
# (223, 'Brauerei und Altbierkche Pinkus Mller', 3)
# (242, "Brewer's Art", 3)
# (254, 'Bricktown Brewery', 3)
# (260, 'Broughton Ales', 3)
# (263, 'Brouwerij Abdij Saint Sixtus', 3)
# (266, 'Brouwerij Bavik - De Brabandere', 3)
# (287, 'Brouwerij Liefmans', 3)
# (288, 'Brouwerij Lindemans', 3)
# (332, "Callahan's Pub and Brewery", 3)
# (363, 'Cervecera Jerome', 3)
# (376, 'Cheshire Cat Brewery', 3)
# (390, 'Coastal Fog Brewing', 3)
# (403, 'Corner Pub', 3)
# (413, 'Crescent City Brewhouse', 3)
# (425, 'Daleside Brewery', 3)
# (428, 'de dochter van de korenaar', 3)
# (431, 'De Leyerth Brouwerijen', 3)
# (464, "Drake's Brewing", 3)
# (524, 'Firestone Walker Brewing Company', 3)
# (545, 'Fort Collins Brewery', 3)
# (568, 'Gasthaus-Brauerei Max & Moritz', 3)
# (595, 'Granite City Food & Brewery - Omaha', 3)
# (598, 'Granville Island Brewing Company', 3)
# (614, 'Grizzly Bay Brewing', 3)
# (616, 'Grolsche Bierbrouwerij', 3)
# (621, 'Hacker-Pschorr Bru', 3)
# (632, 'Harbor City Brewing', 3)
# (636, 'Harvest Moon Brewery / Cafe', 3)
# (642, 'HC Berger Brewing', 3)
# (650, 'Heller Bru Trum', 3)
# (659, 'Hirschbru Privatbrauerei Hss', 3)
# (671, 'Hop Back Brewery', 3)
# (675, 'Hops Grillhouse & Brewery - Cherry Creek', 3)
# (677, 'HopTown Brewing', 3)
# (682, 'Hubcap Brewery and Kitchen', 3)
# (689, 'Illinois Brewing', 3)
# (693, 'Indian Wells Brewing', 3)
# (698, 'Iron City Brewing Co.', 3)
# (710, 'James Page Brewing', 3)
# (712, 'Jasper Ridge Brewery', 3)
# (716, 'JJ Bitting Brewing', 3)
# (717, "Jobber's Canyon Restaurant & Brewery", 3)
# (724, "Joshua Huddy's Brew Pub and Grill", 3)
# (729, 'Kaiserdom Privatbrauerei Bamberg', 3)
# (736, "Kelmer's Brewhouse", 3)
# (744, 'Klosterbrauerei Neuzelle', 3)
# (752, 'KÃ¶stritzer Schwarzbierbrauerei', 3)
# (760, 'La Jolla Brewing', 3)
# (781, 'Legends Brewhouse & Eatery of Green Bay', 3)
# (787, 'Lift Bridge Brewery', 3)
# (794, 'Listermann Brewing Company', 3)
# (820, 'Malt Shovel Brewery', 3)
# (824, 'Manhattan Beach Brewing', 3)
# (830, 'Marquette Harbor Brewery and Restaurant', 3)
# (831, 'Marshall Brewing Company', 3)
# (836, 'Maui Brewing Co.', 3)
# (843, 'McMullen & Sons', 3)
# (844, 'Meantime Brewing Company Limited', 3)
# (863, 'Miller Brewing', 3)
# (917, "Nor'Wester Brewery and Public House", 3)
# (928, "O'Hara's Brewpub and Restaurant", 3)
# (955, 'Orlio Organic', 3)
# (974, 'Pelican Pub & Brewery', 3)
# (999, 'Pivzavod Baltika /', 3)
# (1042, "Randy's Fun Hunters Brewery Restaurant and Banquet Center", 3)
# (1043, 'RCH Brewery', 3)
# (1046, 'Red Kettle Brewing', 3)
# (1048, 'Red Oak Brewery', 3)
# (1064, 'Rock Bottom Restaurant & Brewery - Denver', 3)
# (1095, 'Salado Creek Brewing Company', 3)
# (1098, "Sam Choy's Breakfast, Lunch, Crab & Big Aloha Brewery", 3)
# (1115, 'Schloss Eggenberg', 3)
# (1116, 'Schlossbru', 3)
# (1120, 'Schussenrieder Erlebnisbrauerei', 3)
# (1128, "Selin's Grove Brewing Co.", 3)
# (1133, "Sherlock's Home", 3)
# (1134, 'Ship Inn Brewpub', 3)
# (1135, 'Shipwrecked Brew Pub', 3)
# (1146, 'Simmerberg Brusttt und Taferne', 3)
# (1168, 'South County Brewing Co.', 3)
# (1180, 'Sports City Cafe & Brewery', 3)
# (1198, 'Steinfels Back & Brau', 3)
# (1205, 'Stone Cellar Brewpub & Restaurant', 3)
# (1206, 'Stone City Brewing', 3)
# (1213, 'Strangford Lough Brewing Company Ltd', 3)
# (1216, 'Sturgeon Bay Brewing', 3)
# (1218, 'Sudwerk Privatbrauerei Hbsch', 3)
# (1221, 'Surly Brewing', 3)
# (1230, 'Tabernash Brewing', 3)
# (1255, 'Thirsty Dog Brewing', 3)
# (1258, 'Thomas Hooker Brewing', 3)
# (1281, 'Traquair House Brewery', 3)
# (1283, 'Triple Rock Brewery', 3)
# (1290, 'Tucher Bru', 3)
# (1295, 'Twin Ports Brewing', 3)
# (1321, 'Valley Forge Brewing', 3)
# (1344, 'Wdi-Bru-Huus', 3)
# (1348, 'Wells and (&) Youngs Brewing Company Ltd.', 3)
# (1354, 'Wharf Rat', 3)
# (1367, 'Williams Brothers Brewing Company', 3)
# (5, 'Abbaye de Leffe', 2)
# (15, 'Aktienbrauerei Kaufbeuren', 2)
# (19, 'Aldaris', 2)
# (29, 'Alpine Beer Company', 2)
# (40, 'Andechser Klosterbrauerei', 2)
# (50, 'Asahi Breweries', 2)
# (51, 'Asheville Pizza and Brewing Co.', 2)
# (64, 'Backcountry Brewery', 2)
# (65, 'Backwater Brewing', 2)
# (80, "Barley's Brewing #1", 2)
# (84, "Basil T's Brew Pub and Italian Grill", 2)
# (85, 'Bass Brewers', 2)
# (89, 'Bayern Brewing', 2)
# (97, 'Belfast Bay Brewing Company', 2)
# (109, 'Bierbrouwerij Bavaria', 2)
# (111, 'Bierbrouwerij St.Christoffel', 2)
# (128, 'Birrificia Le Baladin', 2)
# (130, 'Bison Brewing', 2)
# (137, 'Blackstone Restaurant & Brewery', 2)
# (156, 'BOSS Browar Witnica S.A.', 2)
# (164, 'Brasserie Artisanale de Rulles', 2)
# (170, 'Brasserie de Blaugies', 2)
# (175, "Brasserie de l'Abbaye Val-Dieu", 2)
# (176, 'Brasserie de la Senne', 2)
# (177, 'Brasserie De Saint Sylvestre', 2)
# (179, 'Brasserie de Silly', 2)
# (191, 'Brasserie Ellezelloise', 2)
# (197, 'Brasserie Lefebvre', 2)
# (208, 'Brauerei Fssla', 2)
# (212, 'Brauerei Herrenhausen', 2)
# (216, 'Brauerei Leibinger', 2)
# (221, 'Brauerei Schwelm', 2)
# (222, 'Brauerei Spezial', 2)
# (227, 'Brauhaus Brew Hall', 2)
# (246, 'Brewery Corsendonk', 2)
# (256, 'Brimstone Brewing', 2)
# (262, 'Brouwerij Abdij der Trappisten van Westmalle', 2)
# (268, 'Brouwerij Boon', 2)
# (269, 'Brouwerij Bosteels', 2)
# (272, 'Brouwerij De Dolle Brouwers', 2)
# (279, 'Brouwerij De Smedt', 2)
# (284, 'Brouwerij Het Anker', 2)
# (301, 'Brouwerij Van Eecke', 2)
# (302, 'Brouwerij van Hoegaarden', 2)
# (303, 'Brouwerij Van Honsebrouck', 2)
# (305, 'Brouwerij Verhaeghe', 2)
# (307, 'Browar Okocim', 2)
# (309, 'Browar Zywiec', 2)
# (321, 'BÃ¼rgerbrÃ¤u Wolnzach', 2)
# (329, 'Caledonian Brewing', 2)
# (344, 'Carlsberg Bryggerierne', 2)
# (345, 'Carlsberg Sverige AB', 2)
# (348, 'Carmel Brewing', 2)
# (360, 'Cervecera Cuauhtmoc-Moctezuma', 2)
# (375, 'Cherryland Brewing', 2)
# (381, 'City Brewing Company, LLC', 2)
# (389, 'Coast Range Brewing', 2)
# (401, 'Copper Eagle Brewing', 2)
# (408, 'Courthouse Pub', 2)
# (424, 'Daas', 2)
# (430, 'De Halve Maan', 2)
# (433, 'De Struise Brouwers', 2)
# (439, 'Denmark Brewing', 2)
# (442, 'Desnoes & Geddes Ltd', 2)
# (443, 'Devil Mountain Brewing', 2)
# (444, 'Diamond Bear Brewing Co.', 2)
# (448, 'Diebels Privatbrauerei', 2)
# (450, 'Dillon Dam Brewery', 2)
# (451, 'Dinkelacker-Schwaben Bru', 2)
# (465, 'Dreher Srgyrak Zrt.', 2)
# (468, 'Dubuque Brewing and Bottling', 2)
# (477, 'Eastern Shore Brewing', 2)
# (479, 'Edelweissbrauerei Farny', 2)
# (484, 'Einbecker Brauhaus AG', 2)
# (489, 'Elgood & Sons', 2)
# (497, 'Elysian Brewing - TangleTown', 2)
# (498, 'Emerson Brewing', 2)
# (499, 'Emery Pub', 2)
# (502, 'EndeHouse Brewery and Restaurant', 2)
# (508, "Esser's Cross Plains Brewery", 2)
# (511, 'Ettaler Klosterbetriebe Abteilung Brauerei & Destillerie', 2)
# (513, 'Far West Ireland Brewing', 2)
# (514, 'Fauerbach Brewing Company', 2)
# (517, 'Federation Brewery', 2)
# (530, 'Flat Branch Pub & Brewing', 2)
# (531, 'Flat Earth Brewing Company', 2)
# (534, 'Flensburger Brauerei', 2)
# (544, 'Fordham Brewing', 2)
# (546, "Foster's Australia Ltd.", 2)
# (556, 'Free State Brewing', 2)
# (557, 'Freeminer Brewery', 2)
# (569, 'Gasthof-Brauerei zum Frohsinn', 2)
# (570, 'Gatz Brauhaus', 2)
# (572, 'George Gale & Company', 2)
# (574, 'Glacial Lakes Brewing', 2)
# (579, 'Gold Crown Brewing', 2)
# (587, 'Gordash Brewing Company', 2)
# (594, 'Grand Teton Brewing #2', 2)
# (618, 'Grupo Modelo', 2)
# (619, 'Gulpener Bierbrouwerij', 2)
# (626, 'Hambleton Ales', 2)
# (628, 'Hannen Brauerei', 2)
# (635, 'Harpoon Brewery - Windsor', 2)
# (637, 'Harvey & Son (Lewes)', 2)
# (638, 'Harviestoun Brewery', 2)
# (647, 'Heineken International', 2)
# (663, 'Hofbru Kaltenhausen Salzachtal', 2)
# (668, 'Holsten-Brauerei', 2)
# (670, 'Hook Norton Brewery', 2)
# (688, 'Idaho Brewing', 2)
# (696, 'Inveralmond Brewery', 2)
# (704, 'Issaquah Brewhouse', 2)
# (706, 'Jack Russell Brewing', 2)
# (727, 'JW Lees and Co (Brewers) Ltd.', 2)
# (730, 'Kalamazoo Brewing', 2)
# (733, 'Keesmann Bru', 2)
# (739, 'Kessler Brewing', 2)
# (741, 'Kirin Brewery Company, Ltd', 2)
# (748, 'Knig Ludwig Schlobrauerei Kaltenberg', 2)
# (756, 'Kuhnhenn Brewing', 2)
# (764, 'Lafayette Brewing', 2)
# (768, 'Lake Superior Brewing', 2)
# (778, 'Left Coast Brewing', 2)
# (791, 'Lion Brewery Ceylon Ltd.', 2)
# (792, 'Lion Brewery Inc.', 2)
# (800, 'Logjam Microbrewery', 2)
# (804, 'LÃ¶wenbrÃ¤u Brauerei', 2)
# (807, 'Maclay and Co.', 2)
# (814, 'Main Street Alehouse', 2)
# (815, 'Main Street Beer Company #1', 2)
# (816, 'Main Street Brewery', 2)
# (818, 'Main Street Station Casino, Brewery and Hotel', 2)
# (819, 'Maisel Bru', 2)
# (826, 'Margaritaville Brewing Company', 2)
# (828, 'Marine Pub & Brewhouse', 2)
# (832, 'Martini-Brauerei', 2)
# (846, 'Mehana Brewing', 2)
# (851, 'Metropolitan Brewing', 2)
# (859, 'Mikkeller', 2)
# (875, 'Moab Brewery', 2)
# (877, 'Mohrenbrauerei August Huber', 2)
# (881, "Monteith's Brewing Co.", 2)
# (884, "Moorhouse's Brewery (Burnley)", 2)
# (886, 'Moosehead Breweries', 2)
# (890, 'Morland and Co.', 2)
# (891, 'Mountain Sun Pub & Brewery', 2)
# (903, 'Nethergate Brewery Co Ltd', 2)
# (933, 'Oasis Brewery Annex', 2)
# (934, 'Oconomowoc Brewing', 2)
# (940, 'Old Dominion Brewing Co.', 2)
# (944, 'Oldenberg Brewery', 2)
# (954, 'Orlando Brewing', 2)
# (961, 'Oy Sinebrychoff AB', 2)
# (969, 'Panther Brewing Company', 2)
# (971, 'Park City Brewing', 2)
# (983, 'Piece', 2)
# (990, 'Pivovar Hradec Krlov', 2)
# (1012, 'Portland Brewing', 2)
# (1024, 'Privater Brauereigasthof Greifenklau', 2)
# (1027, 'Pumphouse Brewery & Restaurant', 2)
# (1040, 'Railway Brewing', 2)
# (1041, 'Ramapo Valley Brewery', 2)
# (1047, 'Red Lodge Ales', 2)
# (1052, 'Remington Watson Smith Brewing', 2)
# (1069, 'Rocky River Brewing', 2)
# (1071, 'Roffey Brewery', 2)
# (1077, 'Rothaus Brauerei', 2)
# (1083, 'Ruppaner-Brauerei', 2)
# (1087, 'S.A. Damm', 2)
# (1089, 'Sabmiller India,', 2)
# (1093, 'Saint Somewhere Brewing Company', 2)
# (1102, 'San Miguel Corporation', 2)
# (1104, 'SandLot Brewery at Coors Field', 2)
# (1105, "Sanford's Grub and Pub", 2)
# (1107, 'Santa Cruz Brewing', 2)
# (1110, 'Sapporo Breweries - Chuo', 2)
# (1112, 'Saxer Brewing', 2)
# (1114, 'Schlobrauerei Reckendorf', 2)
# (1125, 'Sea Dog Brewing Company', 2)
# (1127, 'Second Street Brewery', 2)
# (1137, 'Shmaltz Brewing Company', 2)
# (1144, 'Silver Gulch Brewing Company', 2)
# (1148, 'Six Rivers Brewery', 2)
# (1150, 'Ska Brewing Company', 2)
# (1163, 'Snowshoe Brewing - Sonora', 2)
# (1166, 'Sonoran Brewing Company', 2)
# (1172, 'Southern Star Brewing Company', 2)
# (1186, 'St. Austell Brewery', 2)
# (1215, 'Stroh Brewery Company', 2)
# (1223, 'Sweet Water Tavern and Brewery', 2)
# (1225, 'Sweetwater Brewing - Casper', 2)
# (1226, 'Sweetwater Tavern - Centreville', 2)
# (1266, 'Timmermans', 2)
# (1273, 'Tongerlo', 2)
# (1278, 'Traffic Jam and Snug', 2)
# (1282, 'Trinity Brewing Company', 2)
# (1297, 'Twisted Pine Brewing Company', 2)
# (1303, 'Uerige Obergrige Hausbrauerei', 2)
# (1304, 'Uinta Brewing Compnay', 2)
# (1306, 'Umpqua Brewing', 2)
# (1311, 'Unionsbru Haidhausen', 2)
# (1312, 'United Breweries Limited', 2)
# (1318, 'Utah Brewers Cooperative', 2)
# (1327, 'Viking Brewing', 2)
# (1328, 'Vintage 50 Restaurant and Brew Lounge', 2)
# (1331, 'vyturio Alaus Darykla', 2)
# (1332, 'Wachusetts Brewing Company', 2)
# (1333, 'Wagner Valley Brewing', 2)
# (1334, 'Wainwright Brewing', 2)
# (1341, 'Water Tower Brewing', 2)
# (1356, 'Whitbread Beer Company', 2)
# (1358, 'White Oak Cider', 2)
# (1360, 'Whitstable Brewery', 2)
# (1364, 'Wild Onion Brewing', 2)
# (1370, 'Wisconsin Brewing', 2)
# (1381, 'Yaletown Brewing', 2)
# (1394, 'Aviator Brewing Company', 2)
# (3, '3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij', 1)
# (9, 'Aberdeen Brewing', 1)
# (12, 'Affligem Brouwerij', 1)
# (13, 'Agassiz Brewing', 1)
# (16, 'Alameda Brewhouse', 1)
# (18, 'Alaus Darykla Kalnapilis', 1)
# (27, 'Allguer Brauhaus AG Kempten, Brausttte Leuterschach', 1)
# (30, 'Alpirsbacher Klosterbru', 1)
# (31, 'Alvinne Picobrouwerij', 1)
# (33, 'American River Brewing', 1)
# (34, 'Amerisports Brew Pub', 1)
# (36, 'Amicas Pizza, Microbrews and More', 1)
# (37, 'Amstel Brouwerij', 1)
# (48, 'Arcobrau Grafliches Brauhaus', 1)
# (53, 'Athenian Brewery', 1)
# (54, 'Atlanta Brewing Company', 1)
# (55, 'Atlantic Brewing Company', 1)
# (59, 'Augusta Brewing', 1)
# (61, 'Australian Brewing Corporation', 1)
# (66, 'Bad Frog Brewery Company', 1)
# (72, 'Bar Harbor Brewing Company', 1)
# (79, "Barley's #2 Smokehouse and Brewpub", 1)
# (81, "Barley's Casino & Brewing Company", 1)
# (86, 'Bavaria', 1)
# (93, 'Beamish & Crawford', 1)
# (95, "Beck's", 1)
# (96, "Beermann's Beerwerks BrewPub", 1)
# (99, 'Belize Brewing', 1)
# (102, 'Bent River Brewing', 1)
# (103, 'Berliner Kindl Brauerei AG', 1)
# (104, 'Berliner-Kindl-Schultheiss-Brauerei', 1)
# (107, 'Bibiana Brewing', 1)
# (108, 'Biddy Early Brewery', 1)
# (112, 'Big Bang Brewery (Closed)', 1)
# (115, 'Big Buck Brewery and Steakhouse #2', 1)
# (116, "Big Dog's Brewing Company", 1)
# (117, 'Big Hole Brewing', 1)
# (118, 'Big Horn Brewing @ The RAM 2', 1)
# (124, "Bill's Tavern & Brewhouse", 1)
# (125, 'Binding Brauerei AG', 1)
# (126, 'Birra Forst', 1)
# (127, 'Birra Moretti', 1)
# (129, 'Birrificio Torrechiara', 1)
# (131, 'Bitburger Brauerei', 1)
# (132, "BJ's Pizza, Grill, and Brewery - Jantzen Beach", 1)
# (134, 'Black Sheep Brewery', 1)
# (135, 'Black Toad Brewing Company', 1)
# (136, 'Blacksburg Brewing Company', 1)
# (138, 'Blicks Brewing', 1)
# (139, 'Blitz-Weinhard Brewing', 1)
# (141, 'BluCreek Brewing Company', 1)
# (143, 'Blue Corn Caf and Brewery - Albuquerque', 1)
# (145, 'Blue Ridge Brewing', 1)
# (146, 'Bluegrass Brewing Company, Inc.', 1)
# (148, "Boddington's Brewery", 1)
# (149, 'Boiler Room Brewpub', 1)
# (150, 'Bonaventure Brewing Co', 1)
# (151, 'Bonfire Brewery', 1)
# (152, 'Boon Rawd Brewery', 1)
# (154, 'Borsodi SÃ¶rgyÃ¡r', 1)
# (155, 'Boscos Memphis Brewing', 1)
# (159, "Bottom's Up Brewing", 1)
# (162, 'Boundary Bay Brewery and Bistro', 1)
# (163, 'Brasal-Brasserie Allemande', 1)
# (165, 'Brasserie Bnifontaine', 1)
# (166, 'Brasserie Clarysse', 1)
# (168, "Brasserie d'Ecaussinnes", 1)
# (169, "Brasserie d'Orval", 1)
# (172, 'Brasserie de Cazeau', 1)
# (173, "Brasserie de l'Abbaye de Scourmont (Trappistes)", 1)
# (174, "Brasserie De L'Abbaye Des Rocs", 1)
# (178, 'Brasserie De Silenrieux', 1)
# (180, 'Brasserie de Tahiti', 1)
# (181, 'Brasserie de Vervifontaine', 1)
# (182, 'Brasserie des Cimes', 1)
# (183, 'Brasserie des Franches-Montagnes', 1)
# (184, 'Brasserie des Gants', 1)
# (185, 'Brasserie des Vosges', 1)
# (186, 'Brasserie du Benin', 1)
# (187, 'Brasserie du Bocq', 1)
# (188, 'Brasserie Dubuisson', 1)
# (189, 'Brasserie Dupont', 1)
# (190, 'Brasserie Duyck', 1)
# (192, 'Brasserie Fantme', 1)
# (193, "Brasserie Grain D'Orge", 1)
# (194, 'Brasserie La Binchoise', 1)
# (195, 'Brasserie La Caracole', 1)
# (196, 'Brasserie La Choulette', 1)
# (199, 'Brasserie Pietra', 1)
# (200, 'Brasserie Thiriez', 1)
# (203, 'Brasseries Kronenbourg', 1)
# (207, 'Brauerei C. & A. Veltins GmbH & Co.', 1)
# (209, 'Brauerei Gbr. Maisel KG', 1)
# (210, 'Brauerei Grieskirchen AG', 1)
# (211, 'Brauerei Gss', 1)
# (213, 'Brauerei Hrle', 1)
# (214, 'Brauerei Hrlimann', 1)
# (215, 'Brauerei im Fchschen', 1)
# (217, 'Brauerei Locher AG', 1)
# (218, 'Brauerei Reissdorf', 1)
# (219, 'Brauerei Schtzengarten', 1)
# (220, 'Brauerei Schumacher', 1)
# (225, 'Brauereigasthof Adler', 1)
# (226, 'Brauhaus am WaldschlÃ¶sschen', 1)
# (228, 'Brauhaus Faust', 1)
# (229, 'Brauhaus Johann Albrecht - Dsseldorf', 1)
# (231, 'Brauhaus Onuma', 1)
# (232, 'Brauhaus Sion', 1)
# (234, 'Brausttte der Steirerbrau Aktiengesellschaft', 1)
# (238, 'Brennerei-Distillerie Radermacher', 1)
# (239, 'Brew Kettle Taproom & Smokehouse BOP', 1)
# (240, 'Brew Makers', 1)
# (243, "Brewery at Martha's Vineyard", 1)
# (244, 'Brewery Belle-Vue', 1)
# (245, 'Brewery Budweiser Budvar', 1)
# (248, 'Brewery De Troch', 1)
# (251, 'Brewpub-on-the-Green', 1)
# (253, 'Brick Brewing', 1)
# (257, 'Bristol Brewing', 1)
# (261, "Brouwerij 't IJ", 1)
# (264, 'Brouwerij Alken-Maes', 1)
# (265, 'Brouwerij Artois', 1)
# (267, 'Brouwerij Bockor', 1)
# (270, 'Brouwerij De Achelse Kluis', 1)
# (271, 'Brouwerij De Block', 1)
# (273, 'Brouwerij de Gouden Boom', 1)
# (274, 'Brouwerij De Keersmaeker', 1)
# (276, 'Brouwerij De Landtsheer', 1)
# (277, 'Brouwerij De Ranke', 1)
# (278, 'Brouwerij De Regenboog', 1)
# (281, 'Brouwerij Duvel Moortgat', 1)
# (282, 'Brouwerij Duysters', 1)
# (283, 'Brouwerij Girardin', 1)
# (286, 'Brouwerij Kerkom', 1)
# (289, 'Brouwerij Nacional Balashi', 1)
# (290, 'Brouwerij Oud Beersel', 1)
# (291, 'Brouwerij Rodenbach', 1)
# (292, 'Brouwerij Roman', 1)
# (293, 'Brouwerij Sint-Jozef', 1)
# (294, 'Brouwerij Slaghmuylder', 1)
# (295, 'Brouwerij St-Feuillien', 1)
# (297, 'Brouwerij Sterkens', 1)
# (298, 'Brouwerij Strubbe', 1)
# (299, 'Brouwerij The Musketiers', 1)
# (300, 'Brouwerij Van Den Bossche', 1)
# (306, 'Browar NamysÅ‚Ã³w Sp. z o.o.', 1)
# (308, 'Browar Warka', 1)
# (312, 'Bryggeriet lfabrikken', 1)
# (313, 'BT McClintic Beer Company', 1)
# (316, 'Budjovick Mansk Pivovar', 1)
# (318, 'Bulldog Brewing', 1)
# (320, 'Bulmer Cider', 1)
# (323, 'Butte Creek Brewing', 1)
# (324, 'Butterfield Brewing #1', 1)
# (325, 'Buzzards Bay Brewing Inc.', 1)
# (330, "Calhoun's Microbrewery", 1)
# (331, 'California Cider Company', 1)
# (334, "Cameron's Brewing", 1)
# (335, 'Camerons Brewery Company', 1)
# (340, 'Capitol City Brewing #4', 1)
# (343, 'Carlow Brewing Company', 1)
# (347, 'Carlyle Brewing', 1)
# (349, 'Carolina Beer Company', 1)
# (352, 'Castle Springs Brewery', 1)
# (353, "Cat's Paw Home Brew", 1)
# (354, 'Catamount Brewing', 1)
# (359, 'Cervecera Centro Americana S.A.', 1)
# (362, 'Cervecera Hondurea', 1)
# (364, 'Cervecera Nacional', 1)
# (365, 'Cerveceria Bucanero', 1)
# (366, 'CervecerÃ\xada La Constancia', 1)
# (367, 'Cervejaria de Macau', 1)
# (368, 'Cervejaria Kaiser Brasil', 1)
# (370, 'Cervezas Alhambra', 1)
# (371, 'Chama River Brewing', 1)
# (372, 'Charles Wells Ltd.', 1)
# (373, "Charlie and Jake's Brewery and BBQ", 1)
# (377, 'Chicago Brewing', 1)
# (380, 'Circle V Brewing', 1)
# (382, "CJ's Brewery & Grill", 1)
# (383, 'Cleveland ChopHouse and Brewery', 1)
# (386, 'Clner Hofbrau Frh', 1)
# (387, "Coach's Norman", 1)
# (391, "Coeur d'Alene Brewing Company", 1)
# (392, 'Cold Spring Brewing', 1)
# (393, 'Columbia Bay Brewery Restaurant and Pub', 1)
# (395, 'Coniston Brewing', 1)
# (400, 'Copper Dragon Brewing', 1)
# (405, 'Costal Extreme Brewing Company', 1)
# (406, 'Courage Brewery', 1)
# (411, 'Craftsman Brewing', 1)
# (414, 'Crested Butte Brewery &  Pub', 1)
# (416, 'Crooked River Brewing', 1)
# (417, 'Crooked Waters Brewing', 1)
# (420, 'Cucapa Brewing Company', 1)
# (421, 'Cugino Brewing Company', 1)
# (423, 'D.L. Geary Brewing Company', 1)
# (429, 'De Friese Bierbrouwerij Us Heit', 1)
# (432, 'De Proef Brouwerij', 1)
# (434, 'Deep Creek Brewing', 1)
# (436, 'Del Mar Stuft Pizza and Brewing', 1)
# (446, 'Diamondback Brewery', 1)
# (449, 'Dieu du Ciel', 1)
# (452, 'Dirt Cheap Cigarettes and Beer', 1)
# (454, 'Dixie Brewing', 1)
# (456, 'Dock Street Beer', 1)
# (458, 'Doemens e.V.', 1)
# (461, 'Dostal Alley', 1)
# (466, 'Dry Gulch Brewing', 1)
# (467, 'Dublin Brewing', 1)
# (472, 'Duneland Brewhouse Pub and Restaurant', 1)
# (473, 'Duvel Moortgat', 1)
# (474, 'Dux de Lux', 1)
# (475, 'Eagle Brewing', 1)
# (478, "Eddie McStiff's Brewpub", 1)
# (480, 'Eder & Heylands', 1)
# (485, 'EJ Phair Brewing Company and Alehouse', 1)
# (487, 'El Toro Brewing Company', 1)
# (488, 'Eldridge, Pope and Co.', 1)
# (491, 'Elk Grove Brewery & Restaurant', 1)
# (493, 'Ellicott Mills Brewing', 1)
# (495, 'Elm City Brewing Co', 1)
# (500, "Emmett's Tavern and Brewery", 1)
# (503, 'Engel Brauerei Schwbisch Gmnd Lang', 1)
# (505, 'English Ales Brewery', 1)
# (506, 'Epic Brewing Company', 1)
# (507, 'Erie Brewing Company', 1)
# (510, 'Etna Brewing', 1)
# (519, 'Felinfoel Brewery Co Ltd', 1)
# (525, 'First Coast Brewing', 1)
# (537, 'Flour City Brewing', 1)
# (542, 'Folx-les-Caves', 1)
# (543, 'Foothills Brewing Company', 1)
# (554, 'Frederic Robinson Ltd.', 1)
# (555, 'Frederick Brewing', 1)
# (558, 'Friesisches Brauhaus zu Jever', 1)
# (560, 'Frontwaters Restaurant and Brewing', 1)
# (561, 'Frstliche Brauerei Thurn Und Taxis Regensburg', 1)
# (564, 'FÃ¼rstlich FÃ¼rstenbergische Brauerei', 1)
# (565, 'G. Heileman Brewing', 1)
# (567, 'Gasthaus & Gosebrauerei Bayerischer Bahnhof', 1)
# (571, 'George Bateman and Son Ltd.', 1)
# (573, 'Gilde Brauerei', 1)
# (575, 'Glacier Brewhouse', 1)
# (577, 'Glenwood Canyon Brewing Company', 1)
# (578, 'Gold Coast Brewery', 1)
# (580, 'Golden City Brewery', 1)
# (589, 'Gore Range Brewery', 1)
# (592, 'Grand Lake Brewing', 1)
# (593, 'Grand Teton Brewing #1', 1)
# (597, 'Granville Island Brewing', 1)
# (601, 'Great Bear Brewing', 1)
# (606, 'Great Northern Tavern and Brewery', 1)
# (611, 'Green Mountain Beverage', 1)
# (615, 'Grizzly Peak Brewing', 1)
# (620, 'Haarlems Biergenootschap Jopen', 1)
# (625, "Ham's Restaurant and Brewhouse", 1)
# (627, 'Hampshire Brewery', 1)
# (629, 'Hansa Bryggeri', 1)
# (630, 'Hanssens Artisanal', 1)
# (639, 'Hasserder Brauerei', 1)
# (640, 'Hausbrauerei Zum Schlssel', 1)
# (645, 'Heavyweight Brewing', 1)
# (646, 'Heineken HungÃ¡ria', 1)
# (649, 'Heineken Switzerland', 1)
# (653, 'Herkimer Pub & Brewery', 1)
# (654, 'Hida Takayama Brewing Agricultural Company', 1)
# (657, 'High Point Wheat Beer Company', 1)
# (660, 'Hite Brewery', 1)
# (661, 'Hochstiftliches Brauhaus in Bayern', 1)
# (662, 'Hoepfner Privatbrauerei', 1)
# (664, 'Hofbruhaus Traunstein', 1)
# (667, 'Hofmark Brauerei', 1)
# (672, 'Hoppers Seafood & Grill', 1)
# (680, 'HP Bulmer', 1)
# (681, 'Htt-Brauerei Bettenhuser', 1)
# (687, 'ICOBES b.v.b.a.', 1)
# (690, 'InBev', 1)
# (692, 'Independence Brewing Co', 1)
# (694, 'Industrias La Constancia ILC', 1)
# (699, 'Iron Hill Brewery - Newark', 1)
# (702, 'Island Brewing Company', 1)
# (703, 'Isle of Skye Brewing Company', 1)
# (709, 'Jaipur Restaurant and Brewpub', 1)
# (711, 'Jarre Creek Ranch Brewing', 1)
# (713, 'Jennings Brewery', 1)
# (714, 'Jever Brewery', 1)
# (715, 'Jinro Coors Brewing', 1)
# (719, "John Harvard's Brew House - Framingham", 1)
# (720, "John Harvard's Brew House - Harvard Square", 1)
# (722, 'John Martin sa', 1)
# (726, 'Jurupa Valley Brewing', 1)
# (728, 'Kaiser-Bru', 1)
# (732, 'Karlovacka Pivovara', 1)
# (735, 'Keihan Uji Kotsu', 1)
# (737, 'Kentucky Hemp Beer Company', 1)
# (738, 'Kenya Breweries', 1)
# (740, 'King and Barnes', 1)
# (743, 'Kleinbrouwerij de Glazen Toren', 1)
# (747, 'Knig Brauerei', 1)
# (749, 'Knigsbacher Brauerei', 1)
# (750, 'Knigsegger WalderBru', 1)
# (753, 'KrÃ¡lovskÃ½ pivovar KruÅ¡ovice', 1)
# (755, 'Kross Brewing', 1)
# (758, 'Kulmbacher Mnchshof Bru', 1)
# (766, 'Lake Louie Brewing', 1)
# (767, 'Lake Placid Pub & Brewery', 1)
# (770, 'Lammin Sahti Oy', 1)
# (772, 'Lanchester Brewing', 1)
# (774, 'Latrobe Brewing', 1)
# (776, 'Lazy Magnolia Brewing Company', 1)
# (777, 'Le Cheval Blanc', 1)
# (782, "Leinenkugel's Ballyard Brewery", 1)
# (783, 'Lewis & Clark Brewing Company', 1)
# (785, 'Licher Privatbrauerei', 1)
# (786, 'Liefmans Breweries', 1)
# (788, 'Lighthouse Brewing', 1)
# (789, 'Lightning Boy Brewery', 1)
# (790, 'Limburg Beer Company', 1)
# (793, 'Lion Nathan Australia  Hunter Street', 1)
# (796, 'Little Creatures Brewery', 1)
# (805, 'Lwenbru Munich', 1)
# (806, 'Lwenbru Zrich', 1)
# (817, 'Main Street Brewing', 1)
# (821, 'Mambo Beer', 1)
# (822, 'Mammoth Brewing', 1)
# (825, 'Marble Brewery', 1)
# (834, 'Mash House Restaurant and Brewery', 1)
# (835, 'Matilda Bay Brewing', 1)
# (837, 'Maumee Bay Brewing', 1)
# (838, "McCashin's Brewery & Malthouse", 1)
# (839, "McCoy's Public House and Brewkitchen", 1)
# (840, "McGuire's Irish Pub and Brewery - Pensacola", 1)
# (845, 'Meckatzer Lwenbru', 1)
# (848, 'Mendocino Brewing - Saratoga Springs', 1)
# (849, 'Mendocino Brewing - Ukiah', 1)
# (852, "Mia and Pia's Pizzeria and Brewhouse", 1)
# (856, 'Microbrouwerij Achilles', 1)
# (860, 'Milagro Brewery and Grill', 1)
# (861, 'Mill Creek Brewpub', 1)
# (862, 'Mill Steakhouse', 1)
# (866, "Milly's Tavern", 1)
# (874, 'Mississippi Brewing Co.', 1)
# (880, 'Monte Carlo Casino and Brewpub', 1)
# (889, 'Mordue Brewery', 1)
# (896, 'Mussel Inn', 1)
# (897, 'Myanmar Brewery and Distillery', 1)
# (898, 'Mythos Breweries S.A.', 1)
# (900, 'Namibia Breweries', 1)
# (902, 'Nelson Brewing', 1)
# (904, 'New Albanian Brewing', 1)
# (906, 'New Century Brewing Company', 1)
# (909, 'New River Brewing', 1)
# (910, 'New Road Brewhouse', 1)
# (911, 'New Zealand Breweries Limited', 1)
# (914, 'Nikenjayamochi Kadoya Honten Co.', 1)
# (918, 'Nordsj Grdsbryggeri', 1)
# (921, 'Northwest Brewwrks', 1)
# (924, "O'Fallon Brewery", 1)
# (931, 'Oakham Ales', 1)
# (932, 'Oasis Brewery and Restaurant', 1)
# (938, 'Okanagan Spring Brewery', 1)
# (939, 'Old City Brewing', 1)
# (946, 'Onion Pub & Brewery', 1)
# (948, 'Orchard Street Brewery', 1)
# (949, 'Oregon Trader Brewing', 1)
# (950, 'Oregon Trail Brewery', 1)
# (951, 'Oriental Brewery', 1)
# (957, 'Ostankinskij Pivovarennij Zavod', 1)
# (958, 'Ottakringer Brauerei AG', 1)
# (967, 'Palm Breweries', 1)
# (968, 'Palmetto Brewing', 1)
# (970, 'Paper City Brewing Company', 1)
# (973, 'Pearl Street Brewery', 1)
# (977, 'Pennsylvania Brewing', 1)
# (979, "Pete's Place", 1)
# (980, 'PH Woods Diner and Brewery', 1)
# (982, 'Phoenix Beverages Ltd', 1)
# (986, 'Pinnacle Peak Patio Steakhouse & Microbrewery', 1)
# (987, "Pint's Pub Brewery and Freehouse", 1)
# (988, 'Pivara Skopje', 1)
# (991, 'Pivovar Klter Hradit', 1)
# (992, 'Pivovar Nchod', 1)
# (993, 'Pivovar Pardubice a.s.', 1)
# (995, 'Pivovar Starobrno', 1)
# (996, 'Pivovar v Hurbanove', 1)
# (997, 'Pivovar Velk Popovice', 1)
# (998, 'Pivovary Staropramen', 1)
# (1000, 'Pizza Beer', 1)
# (1001, 'Pizza Port Brewing - Solana Beach', 1)
# (1003, 'Platte Valley Brewing', 1)
# (1005, 'Plzesk Prazdroj', 1)
# (1006, 'Plzesk Prazdroj Pivovar Radegast', 1)
# (1007, 'Pokka Beer Works', 1)
# (1008, 'Pony Express Brewing', 1)
# (1016, 'Pripps Ringnes Bryggerier', 1)
# (1017, 'Privat-Brauerei Schmucker Ober-Mossau KG', 1)
# (1018, 'Privatbrauerei Bolten', 1)
# (1020, 'Privatbrauerei Frankenheim', 1)
# (1021, 'Privatbrauerei Gaffel', 1)
# (1022, 'Privatbrauerei Hofmhl', 1)
# (1025, "Pug Ryan's Steakhouse and Brewery", 1)
# (1026, 'Pugsley Brewing LLC', 1)
# (1028, 'Pumphouse Pizza and Brewing', 1)
# (1032, 'Qingdao Brewery', 1)
# (1034, 'R&B; Brewing', 1)
# (1037, 'Radeberger Exportbierbrauerei', 1)
# (1045, 'ReaperAle', 1)
# (1050, 'RedFish New Orleans Brewhouse', 1)
# (1053, 'Restaurant Isarbru', 1)
# (1057, 'Rio Salado Brewing', 1)
# (1060, 'Rivers Effortless Dining', 1)
# (1063, 'Rock Bottom Restaurant & Brewery - Chicago', 1)
# (1068, 'Rock Bottom Restaurant & Brewery - South Denver', 1)
# (1070, 'Rockyard Brewing', 1)
# (1075, 'Roots Organic Brewing', 1)
# (1076, 'Ross Valley Brewing', 1)
# (1082, 'Rubicon Brewing', 1)
# (1084, 'Rush River Brewing', 1)
# (1088, 'SA Brain & Co. Ltd.', 1)
# (1094, 'Saku lletehas', 1)
# (1096, 'Salopian Brewery', 1)
# (1097, 'Salt Lake Brewing - Squatters', 1)
# (1106, 'Santa Barbara Brewing', 1)
# (1109, 'Santa Rosa Brewing', 1)
# (1111, 'Sarah Hughes Brewery', 1)
# (1113, "Scharer's Little Brewery", 1)
# (1117, 'SchÃ¶fferhofer', 1)
# (1119, "Schooner's Grille & Brewery", 1)
# (1121, 'Scotch Irish Brewing', 1)
# (1122, 'Scottish & Newcastle Breweries', 1)
# (1129, 'Sequoia Brewing Conoabt', 1)
# (1130, 'Shaftebury Brewing', 1)
# (1132, 'Shepherd Neame', 1)
# (1138, 'Shmaltz Enterprises', 1)
# (1140, 'Sierra Leone Brewery', 1)
# (1145, 'Silverado Brewing', 1)
# (1152, 'Skol Breweries', 1)
# (1154, 'Sleeman Brewing & Malting', 1)
# (1155, 'Sleeping Lady Brewing Company', 1)
# (1156, 'Slottskllans Bryggeri', 1)
# (1159, 'Smoky Mountain Brewing', 1)
# (1162, 'Snipes Mountain Microbrewery & Restaurant', 1)
# (1165, 'Socorro Springs Brewing', 1)
# (1167, 'South Australian Brewing', 1)
# (1183, 'Springfield Brewing', 1)
# (1184, 'St John Brewers', 1)
# (1187, 'St. Francis Abbey Brewery', 1)
# (1188, 'St. GeorgenBru Modschiedler KG', 1)
# (1190, "St. Stan's Brewing Co.", 1)
# (1192, 'Stadsbrouwerij De Hemel', 1)
# (1194, 'Steam Whistle Brewery', 1)
# (1196, 'Steamworks Brewing - Durango', 1)
# (1197, 'Steel Brewing', 1)
# (1201, "Stewart's Brewing", 1)
# (1203, 'Stillwater Artisanal Ales', 1)
# (1207, 'Stone Coast Brewing - Portland', 1)
# (1209, 'Stoney Creek Brewing Company', 1)
# (1214, 'Straub Brewery', 1)
# (1217, 'Stuttgarter Hofbru', 1)
# (1222, 'Swan Brewery', 1)
# (1228, 'T&R; Theakston', 1)
# (1233, 'Taiwan Tobacco and Wine Monopoly Board', 1)
# (1234, 'Tampa Bay Brewing', 1)
# (1235, 'Tap Room Brewing Company', 1)
# (1240, 'Tenaya Creek Restaurant and Brewery', 1)
# (1241, 'Tennent Caledonian Brewery', 1)
# (1242, 'Terminal Gravity Brewing', 1)
# (1252, 'The Narragansett Brewing Company', 1)
# (1254, 'Third Street Ale Works', 1)
# (1259, 'Thomas Kemper Brewing', 1)
# (1261, 'Three Needs Brewery and Taproom', 1)
# (1262, 'Thunder Canyon Brewery', 1)
# (1267, 'Tin Whistle Brewing', 1)
# (1269, 'Tivoli Brewing', 1)
# (1270, 'Tollemache and Cobbold Brewery', 1)
# (1272, 'Tomos Watkin and Sons Ltd.', 1)
# (1274, 'Tooheys', 1)
# (1275, "Tooth's", 1)
# (1284, 'Triumph Brewing of New Hope', 1)
# (1287, 'Tropical Beverage (International) Co., Ltd', 1)
# (1289, 'Tsingtao', 1)
# (1291, 'Tui Brewery', 1)
# (1293, 'Tuppers Hop Pocket Ale', 1)
# (1294, 'Tustin Brewing', 1)
# (1302, 'Tyskie Browary KsiÄ…Å¼Ä™ce', 1)
# (1305, 'Ukiah Brewing', 1)
# (1310, 'Union Colony Brewery', 1)
# (1313, 'Upland Brewing', 1)
# (1317, 'Ushers of Trowbridge', 1)
# (1319, 'Utenos Alus', 1)
# (1325, 'Vetterï¿½s Alt Heidelberger Brauhaus', 1)
# (1329, 'Vivungs Bryggeri', 1)
# (1338, 'Watch City Brewing', 1)
# (1342, 'Watney Brewery', 1)
# (1343, 'Watson Brothers Brewhouse', 1)
# (1345, 'Weeping Radish Restaurant and Brewery - Manteo', 1)
# (1347, 'Weissbierbrauerei Hopf', 1)
# (1349, 'WernesgrÃ¼ner Brauerei', 1)
# (1350, 'WernesgrÃ¼ner Brauerei GmbH', 1)
# (1351, 'Western Reserve Brewing', 1)
# (1353, 'WH Brakspear & Sons', 1)
# (1355, 'Whim Ales', 1)
# (1357, 'White Marsh Brewing Company', 1)
# (1359, 'White Winter Winery', 1)
# (1362, 'Wild Duck Brewing', 1)
# (1363, 'Wild Goose Brewery, LLC', 1)
# (1366, 'William Kuether Brewing', 1)
# (1368, 'Willoughby Brewing', 1)
# (1371, 'Wolf Pack Brewing', 1)
# (1372, 'Wolf Tongue Brewery', 1)
# (1373, "Woodforde's Norfolk Ales", 1)
# (1374, 'Wrzburger Hofbru AG', 1)
# (1376, 'Wychwood Brewery Company Ltd', 1)
# (1377, "Wyder's Cider", 1)
# (1378, 'Wye Valley Brewery', 1)
# (1382, 'Yamhill Brewing', 1)
# (1389, 'York Brewery', 1)
# (1390, 'Yellowstone Valley Brewing', 1)
# (1392, 'Yuksom Breweries', 1)
# (1396, 'Aspen Brewing Company', 1)
# (1397, 'Tallgrass Brewing Co.', 1)
# (1399, 'New Jersey Beer Company', 1)
# (1400, 'FINNEGANS', 1)
# (1401, 'Half Pints Brewing Company', 1)
# (1402, 'Warwick Valley Wine Co.', 1)
# (1404, 'The St. Louis Brewrey', 1)
# (1405, 'Baltika Breweries', 1)
# (1407, 'Catawba Valley Brewing Company', 1)
# (1409, 'Columbus Brewing Company', 1)
# (1410, 'Oso', 1)
# (1411, 'Element Brewing Company', 1)
# (1413, 'Wedge Brewery', 1)
# (1414, 'Black Creek Historic Brewery', 1)
# (1416, 'Brewery Vivant', 1)
# (1417, 'Oakshire', 1)
# (1419, 'Uehara Shuzou Co. Ltd. / Echigo Beer Pub', 1)
# (1420, "Devil's Canyon", 1)
# (1421, 'DC Brau', 1)
# (1422, 'Abhi Brewery', 1)
# (1423, 'Brasserie du Bouffay', 1)

# %%
# per country
c.execute('''SELECT bw.country, COUNT(DISTINCT(b.style_id)) as 'cnt' FROM beers b 
                LEFT JOIN breweries bw ON b.brewery_id = bw.id 
                WHERE bw.country <> 'None'
                GROUP BY bw.country ORDER BY 2 DESC
                ''')

for row in c.fetchall():
    print (row)
# Out:
# ('United States', 115)
# ('United Kingdom', 44)
# ('Canada', 41)
# ('Belgium', 30)
# ('Norway', 19)
# ('Germany', 19)
# ('Australia', 14)
# ('Netherlands', 12)
# ('Japan', 12)
# ('Ireland', 11)
# ('Austria', 10)
# ('Switzerland', 8)
# ('New Zealand', 8)
# ('Czech Republic', 8)
# ('Sweden', 5)
# ('Poland', 5)
# ('India', 5)
# ('France', 5)
# ('Denmark', 5)
# ('Russia', 4)
# ('Mexico', 4)
# ('England', 4)
# ('Brazil', 4)
# ('Spain', 3)
# ('Lithuania', 3)
# ('Italy', 3)
# ('Finland', 3)
# ('Argentina', 3)
# ('Thailand', 2)
# ('Sri Lanka', 2)
# ('Philippines', 2)
# ('Latvia', 2)
# ('Korea, Republic of', 2)
# ('Jamaica', 2)
# ('Hungary', 2)
# ('El Salvador', 2)
# ('Togo', 1)
# ('Taiwan, Province of China', 1)
# ('Slovakia', 1)
# ('Sierra Leone', 1)
# ('Panama', 1)
# ('Namibia', 1)
# ('Myanmar', 1)
# ('Mauritius', 1)
# ('Macedonia, the Former Yugoslav Republic of', 1)
# ('Macao', 1)
# ('Kenya', 1)
# ('Honduras', 1)
# ('Guatemala', 1)
# ('Greece', 1)
# ('French Polynesia', 1)
# ('Estonia', 1)
# ('Cuba', 1)
# ('Croatia', 1)
# ('Colombia', 1)
# ('China', 1)
# ('Belize', 1)
# ('Aruba', 1)

# %% [markdown]
# ### 4. What is the median of the alcohol content?

# %%
c.execute('''SELECT CAST(abv as decimal) abv_value FROM beers WHERE abv_value >= 0 ORDER BY abv_value LIMIT 1 OFFSET (SELECT count(*) / 2 from beers WHERE abv >= 0)''')
for row in c.fetchall():
    print (row)
# Out:
# (4,)

# %% [markdown]
# ### 5. Which beer style is mainly found in which country?

# %%
c.execute('''SELECT DISTINCT(bw.Country) FROM breweries bw WHERE bw.country <> 'None' ORDER BY bw.Country DESC
            ''')

countries = []
for row in c.fetchall():
    countries.append(row[0])
    
for country in countries:
    c.execute("SELECT '" + country + "' as 'country', s.style_name, count(b.id) as 'cnt' FROM beers b LEFT JOIN breweries bw ON b.brewery_id = bw.id " +
                "LEFT JOIN styles s ON b.style_id = s.id " +
                "WHERE s.style_name <> 'None' AND bw.country = '" + country + "' GROUP BY s.Id, s.style_name " +
                 "ORDER BY cnt DESC LIMIT 1")
    for row in c.fetchall():
        print (row)
# Out:
# ('United States', 'American-Style Pale Ale', 480)
# ('United Kingdom', 'Old Ale', 18)
# ('Thailand', 'American-Style Lager', 1)
# ('Taiwan, Province of China', 'American-Style Lager', 1)
# ('Switzerland', 'South German-Style Hefeweizen', 4)
# ('Sweden', 'Old Ale', 1)
# ('Sri Lanka', 'American-Style Stout', 1)
# ('Spain', 'Baltic-Style Porter', 3)
# ('Russia', 'American-Style Lager', 3)
# ('Poland', 'American-Style Stout', 2)
# ('Philippines', 'German-Style Schwarzbier', 1)
# ('Panama', 'American-Style Lager', 3)
# ('Norway', 'American-Style Brown Ale', 2)
# ('New Zealand', 'American-Style Pale Ale', 2)
# ('Netherlands', 'American-Style Lager', 4)
# ('Namibia', 'Traditional German-Style Bock', 1)
# ('Myanmar', 'American-Style Lager', 1)
# ('Mexico', 'American-Style Lager', 9)
# ('Macedonia, the Former Yugoslav Republic of', 'American-Style Lager', 1)
# ('Macao', 'American-Style Lager', 1)
# ('Lithuania', 'Porter', 1)
# ('Latvia', 'Traditional German-Style Bock', 1)
# ('Korea, Republic of', 'American-Style Lager', 3)
# ('Kenya', 'American-Style Lager', 1)
# ('Japan', 'American-Style Stout', 3)
# ('Jamaica', 'American-Style Stout', 2)
# ('Italy', 'Traditional German-Style Bock', 3)
# ('Ireland', 'American-Style Stout', 5)
# ('India', 'American-Style Lager', 12)
# ('Hungary', 'German-Style Pilsener', 3)
# ('Honduras', 'American-Style Lager', 1)
# ('Guatemala', 'Traditional German-Style Bock', 1)
# ('Germany', 'South German-Style Hefeweizen', 46)
# ('French Polynesia', 'American-Style Lager', 1)
# ('France', 'Old Ale', 1)
# ('Finland', 'American-Style Stout', 1)
# ('Estonia', 'American-Style Stout', 1)
# ('England', 'Old Ale', 2)
# ('El Salvador', 'American-Style Lager', 4)
# ('Denmark', 'Traditional German-Style Bock', 2)
# ('Czech Republic', 'German-Style Pilsener', 3)
# ('Cuba', 'American-Style Lager', 1)
# ('China', 'American-Style Lager', 2)
# ('Canada', 'American-Style Lager', 41)
# ('Brazil', 'German-Style Schwarzbier', 2)
# ('Belize', 'American-Style Stout', 1)
# ('Belgium', 'Belgian-Style Fruit Lambic', 39)
# ('Austria', 'South German-Style Hefeweizen', 4)
# ('Australia', 'American-Style Lager', 4)
# ('Aruba', 'German-Style Pilsener', 1)
# ('Argentina', 'American-Style Lager', 2)

# %%
# close db connection
conn.close()

# %% [markdown]
# ## 4. Visualization of the data
#
# 1. Use a heatmap to display number of beers per country and per alcohol content (to simplify: only use whole numbers of alcohol)
# 2. Use map to visualize brewery locations on a world map

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

conn = sqlite3.connect('beer.db')
df = pd.read_sql_query('''SELECT bw.country, cast(b.abv as integer) as 'alcohol', count(b.id) as 'count'
                            FROM beers b 
                            LEFT JOIN breweries bw ON b.brewery_id = bw.id 
                            WHERE cast(b.abv as integer) > 0
                            GROUP BY bw.country, cast(b.abv as integer) ORDER BY bw.country''', conn)

# close db connection
conn.close()
df.head()

heatmap1_data = pd.pivot_table(df, values='count', 
                     index=['country'], 
                     columns='alcohol')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap1_data, cmap="RdBu")

# %%
df['log_count'] = np.log(df['count'])
heatmap1_data = pd.pivot_table(df, values='log_count', 
                     index=['country'], 
                     columns='alcohol')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap1_data, cmap="RdBu")

# %% [markdown]
# Check out basemaps:
# https://basemaptutorial.readthedocs.io/en/latest/plotting_data.html
#
# Hint:
# Basemap is just one possible idea and an old one - probably you find some more& easier to install
#
# Hint2:
# Use Cartopy instead
# https://scitools.org.uk/cartopy/docs/latest/installing.html
#
# Hint3:
# Or try plotly
# https://plotly.com/python/plotly-express/
# with Scatter MapBox:
# https://plotly.com/python/scattermapbox/

# %%
# Use basemap
# to install run: conda install -c conda-forge basemap
# and maybe: conda install -c conda-forge basemap-data-hires
# a restart might also be necessary


#from mpl_toolkits.basemap import Basemap

#fig = plt.figure(figsize=(12, 9))
#m = Basemap(projection='mill',
#           llcrnrlat = -90,
#           urcrnrlat = 90,
#           llcrnrlon = -180,
#           urcrnrlon = 180,
#           resolution = 'c')

#m.drawcoastlines()

#x = breweries_geocode['longitude'].values.tolist()
#y = breweries_geocode['latitude'].values.tolist()

#m.scatter(x, y, latlon=True, marker="o", c='red', alpha=0.8, edgecolor='black')

#plt.title('Brewery Locations', fontsize=20)
#plt.show()

# %% [markdown]
# ![Basemap_Illustration_Example.png](attachment:Basemap_Illustration_Example.png)
